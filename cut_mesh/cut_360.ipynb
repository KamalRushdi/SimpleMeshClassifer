# %% [markdown]
# ### imports

# %%
import pyvista as pv
import pymeshfix
import os
import trimesh
import numpy as np

# %% [markdown]
# ##### Augmentation: mirror the mesh

# %%
def mirror_mesh(input_path):
    mesh = pv.read(input_path)
    # mirror the mesh on the Y axis
    mesh.points[:, 1] = -mesh.points[:, 1]
    mesh.save(input_path.replace(".ply", "_mirrored.ply"))
#
# meshPathes = [mesh for mesh in os.listdir("../experimentation_scripts/data_samples/train/") if mesh.endswith(".ply")]
#
# for mesh in meshPathes:
#     mesh_path = os.path.join("../experimentation_scripts/data_samples/train/", mesh)
#     mirror_mesh(mesh_path)

# %% [markdown]
# ##### Fill holes in the mesh and clean the isolated vertices function

# %%
def fill_mesh_holes_pyvista(input_path, output_path, hole_size=1000.0):
    pymeshfix.clean_from_file(input_path, output_path)
    mesh = pv.read(output_path)
    mesh = mesh.clean(tolerance=1e-6)
    mesh = mesh.triangulate()
    # Fill holes
    filled = mesh.fill_holes(hole_size)

    # Optional: clean up
    filled = filled.clean()

    # Save the result
    filled.save(output_path)

    mesh = pv.read(output_path)
    # mirror the mesh on the Y axis
    # mesh.points[:, 1] = -mesh.points[:, 1]
    # mesh.save(output_path.replace(".ply", "_mirrored.ply"))

    return filled

# %% [markdown]
# ##### preprocess the mesh and slice the back

# %%
data_path = "../experimentation_scripts/data_samples/train/2021 - 21 Pelinsu Özkan (Aktif).ply"
sliced_mesh_path = "./sliced_meshes"

# mesh_paths = [path for path in os.listdir(data_path) if path.endswith(".ply")]

mirrored_guys = True
def processMesh(meshPath: str):
    # fill the mesh using pyvista
    output_dir = os.path.join(os.path.dirname(meshPath), "filled_meshes")
    output_path = os.path.join(output_dir, os.path.splitext(os.path.basename(meshPath))[0] + ".ply")

    fill_mesh_holes_pyvista(meshPath, output_path, hole_size=10000.0)

    mesh = trimesh.load(output_path)
    center_z = (mesh.bounds[0][2] + mesh.bounds[1][2]) / 2
    # cut the mesh from with a plane on center_z
    plane_normal = [0, 0, 1]
    plane_origin = [0, 0, center_z]

    mesh = mesh.copy()
    # Slice the mesh with the plane
    back = mesh.slice_plane(plane_origin, plane_normal)
    # slice the front
    front = mesh.slice_plane(plane_origin, [0, 0, -1])

    # sliced_meshes.export(f"{sliced_mesh_path}/{"".join(base_name.split(".")[:-1])}.ply")

    return back, front

# %% [markdown]
# ##### horizontally slice function

# %%
N_SLICES = 21

def sliceMesh(mesh):
    # cut the mesh across the Z axis alonge the Y axis
    jump = abs(mesh.bounds[0][0] - mesh.bounds[1][0]) / N_SLICES
    initial = mesh.bounds[0][0]
    plane_normal = [1, 0, 0]
    plane_origin = [initial, 0, 0]
    plane_negative_normal = [-1, 0, 0]

    # new_center_x = 0
    # Slice the mesh with the plane
    slices = []
    for i in range (N_SLICES):
        sliced_meshes = mesh.slice_plane(plane_origin, plane_normal)
        plane_origin[0] = plane_origin[0] + jump
        sliced_meshes = sliced_meshes.slice_plane(plane_origin, plane_negative_normal)
        slices.append(sliced_meshes)
        # sliced_meshes.export(f"{i}.ply")
    # remove the last N_SLICES - 17
    for i in range(N_SLICES - 17):
        slices.pop()
    return slices

# slices = sliceMesh(sliced_mesh)

# %% [markdown]
# ##### point rotation function

# %%
from scipy.spatial.transform import Rotation as R
def rotate_normal_around_axis(normal, origin, axis, angle_degrees):
    axis = axis / np.linalg.norm(axis)  # ensure unit axis
    angle_rad = np.deg2rad(angle_degrees)
    rot = R.from_rotvec(angle_rad * axis)
    new_normal = rot.apply(normal)
    return new_normal

# %% [markdown]
# ##### radial slice function

# %%
N_PATCHES = 10
counter = 0
def radial_slice(mesh : trimesh.Trimesh, side = "back"):
    # cut the mesh radially
    # print(len(mesh.vertices))
    if side == "back":
        initial_z = mesh.bounds[0][2]
    elif side == "front":
        initial_z = mesh.bounds[1][2]
    else:
        raise ValueError("side must be either 'back' or 'front'")
    # print(f"Center X: {initial_z}")
    if(side == "back"):
        plane_normal = [0, 0, 1]
        plane_negative_normal = [0, 0, -1]
    elif side == "front":
        plane_normal = [0, 0, -1]
        plane_negative_normal = [0, 0, 1]
    # TODO TRY to take abs for (mesh.bounds[0][1] + mesh.bounds[1][1])
    plane_origin = np.array([0, (mesh.bounds[0][1] + mesh.bounds[1][1])/ 2, initial_z])
    axis = np.array([1, 0, 0])      # rotate around X
    # last_normal = rotate_normal_around_axis(np.array(plane_normal), np.array(plane_origin), axis, 170)
    # last_slice =  mesh.slice_plane(plane_origin, last_normal)
    # last_slice.export("last_slice.ply")


    patches_list = []

    # global counter
    for i in range(N_PATCHES):
        sliced_patches = mesh.slice_plane(plane_origin, plane_normal)
        plane_normal = rotate_normal_around_axis(np.array(plane_normal), np.array(plane_origin), axis, 180 / N_PATCHES)
        plane_negative_normal = rotate_normal_around_axis(np.array(plane_negative_normal), np.array(plane_origin), axis, 180 / N_PATCHES)
        sliced_patches = sliced_patches.slice_plane(plane_origin, plane_negative_normal)

        # sliced_patches.export(f"radial_slice_{counter}.ply")

        # counter += 1
        patches_list.append(sliced_patches)

    return patches_list

# patches = radial_slice(slices[2])

# %% [markdown]
# ##### get the normal of the patch through averaging the normals of the vertices

# %%
def get_patch_normal(patch : trimesh.Trimesh):
    if patch is None:
        print("Warning Patch is None")
    else:
        normals = np.mean(patch.vertex_normals, axis = 0)
        norm = np.linalg.norm(normals)
        if norm > 1e-6:
            normals = normals / norm
    if patch.vertex_normals.shape == (0,3):
        print(patch)
    return normals
# get_patch_normal(patches[0])

# %%
from skspatial.objects import Plane
def get_patch_normal_scikit_spatial(patch: trimesh.Trimesh):
    """
    Compute the normal of a mesh patch using scikit-spatial.

    Parameters:
    -----------
    patch : trimesh.Trimesh
        A mesh patch for which to estimate the normal

    Returns:
    --------
    numpy.ndarray
        The estimated normal vector for the patch
    """
    if patch is None:
        print("Warning: Patch is None")
        return np.array([0.0, 0.0, 1.0])  # Default normal

    # Check if the patch has enough vertices (need at least 3 points for a proper plane)
    if len(patch.vertices) < 3:
        print(f"Warning: Patch has only {len(patch.vertices)} vertices, need at least 3 for reliable PCA")
        if len(patch.vertices) == 0:
            return np.array([0.0, 0.0, 1.0])  # Default normal if no vertices
        elif len(patch.vertices) == 1 or len(patch.vertices) == 2:
            # Single point - use vertex normal if available, otherwise default
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)

    # Get vertices as points for PCA
    points = patch.vertices
    plane = Plane.best_fit(points)

    # Get the normal of the plane
    normal = plane.normal

    # Ensure the normal has unit length
    normal = normal / np.linalg.norm(normal)
    # Optional: Make sure the normal points "outward"
    # We can use the average vertex normal as a reference for consistent orientation
    if len(patch.vertex_normals) > 0:
        avg_vertex_normal = np.mean(patch.vertex_normals, axis=0)
        avg_vertex_normal = avg_vertex_normal / np.linalg.norm(avg_vertex_normal)

        # If the computed normal points in the opposite direction of the average vertex normal,
        # flip it to maintain consistent orientation
        if np.dot(normal, avg_vertex_normal) < 0:
            normal = -normal

    return normal

# %%
import numpy as np
import trimesh
from scipy import linalg

def get_patch_normal_pca(patch: trimesh.Trimesh):
    """
    Compute the normal of a mesh patch using Principal Component Analysis (PCA).

    Parameters:
    -----------
    patch : trimesh.Trimesh
        A mesh patch for which to estimate the normal

    Returns:
    --------
    numpy.ndarray
        The estimated normal vector for the patch
    """
    if patch is None:
        print("Warning: Patch is None")
        return np.array([0.0, 0.0, 1.0])  # Default normal

    # Check if the patch has enough vertices (need at least 3 points for a proper plane)
    if len(patch.vertices) < 3:
        print(f"Warning: Patch has only {len(patch.vertices)} vertices, need at least 3 for reliable PCA")
        if len(patch.vertices) == 0:
            return np.array([0.0, 0.0, 1.0])  # Default normal if no vertices
        elif len(patch.vertices) == 1 or len(patch.vertices) == 2:
            # Single point - use vertex normal if available, otherwise default
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)

    # Get vertices as points for PCA
    points = patch.vertices

    # Center the points by subtracting the mean
    points_centered = points - np.mean(points, axis=0)

    # Compute the covariance matrix
    cov_matrix = np.cov(points_centered, rowvar=False)

    # Check for numerical stability
    if np.any(np.isnan(cov_matrix)):
        print("Warning: NaN values in covariance matrix")
        if len(patch.vertex_normals) > 0:
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)
        return np.array([0.0, 0.0, 1.0])

    # Compute eigenvalues and eigenvectors
    try:
        eigenvalues, eigenvectors = linalg.eigh(cov_matrix)
    except np.linalg.LinAlgError:
        print("Warning: Eigenvalue computation failed")
        if len(patch.vertex_normals) > 0:
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)
        return np.array([0.0, 0.0, 1.0])

    # The normal is the eigenvector corresponding to the smallest eigenvalue
    # (the direction with least variance)
    normal = eigenvectors[:, 0]

    # Ensure the normal has unit length
    normal = normal / np.linalg.norm(normal)

    # Optional: Make sure the normal points "outward"
    # We can use the average vertex normal as a reference for consistent orientation
    if len(patch.vertex_normals) > 0:
        avg_vertex_normal = np.mean(patch.vertex_normals, axis=0)
        avg_vertex_normal = avg_vertex_normal / np.linalg.norm(avg_vertex_normal)

        # If the computed normal points in the opposite direction of the average vertex normal,
        # flip it to maintain consistent orientation
        if np.dot(normal, avg_vertex_normal) < 0:
            normal = -normal

    return normal

# Example usage:
# normal = get_patch_normal_pca(patches[0])

# %% [markdown]
# ##### Get the features of the mesh

# %%
def get_features(meshPath, export_output=False):
    print(meshPath)
    back, front = processMesh(meshPath)
    vertical_slices_back = sliceMesh(back)
    vertical_slices_front = sliceMesh(front)
    vertical_slices = vertical_slices_back + vertical_slices_front
    # # collection of geometries
    geometries_original = []
    geometries_features = []
    len(vertical_slices)
    all_normals = []
    for slice,i in zip(vertical_slices, range(len(vertical_slices))):
        if slice is None:
            print("Warning vertical slice is None")
            continue
        if i < 17:
            patches = radial_slice(slice, side="back")
        else:
            patches = radial_slice(slice, side="front")
        for patch in patches:
            # make the original geometry
            if export_output:
                geometry_original = trimesh.Trimesh(vertices=patch.vertices, faces=patch.faces, process=False)
                if len(patch.vertices) != 0:
                    geometry_original.vertex_normals = patch.vertex_normals
                geometries_original.append(geometry_original)

            patch_normal = get_patch_normal_scikit_spatial(patch)
            if export_output:
                # make the features geometry
                geometry_features = trimesh.Trimesh(vertices=patch.vertices, faces=patch.faces, process=False)
                like_array = np.full_like(geometry_features.vertex_normals, patch_normal)
                if len(patch.vertices) != 0:
                    geometry_features.vertex_normals = like_array
                    # geometry_features.vertex_normals = np.tile(patch_normal, (geometry_features.vertices.shape[0], 1))
                geometries_features.append(geometry_features)

            all_normals.append(patch_normal)


    if export_output:
        # export the original geometries as one unit
        merged = trimesh.util.concatenate(geometries_original)
        merged.export(meshPath.replace(".ply", "_original.ply"))
        # export the features geometries as one unit
        merged_features = trimesh.util.concatenate(geometries_features)
        merged_features.export(meshPath.replace(".ply", "_features.ply"))


    # # 0 to 9 then 170 to 179 then 10 to 19 then 180 to 189 and so on ...
    new_order = []
    mid = len(all_normals) // 2
    for i in range(len(vertical_slices_back)):
        new_order.append(all_normals[N_PATCHES*i : N_PATCHES*i+N_PATCHES])
        new_order.append(all_normals[mid+(N_PATCHES*i) : mid+(N_PATCHES*i+N_PATCHES)])

    # # save all_normals to a file
    # ordered_array = np.vstack(new_order)
    # np.savetxt("normals.txt", ordered_array, fmt="%.10f")
    #
    # # save all_normals to a file
    # old_array = np.vstack(all_normals)
    # np.savetxt("old_normals.txt", old_array, fmt="%.10f")

    all_normals = new_order
    return np.array(all_normals)

# %%
# path = "../experimentation_scripts/data_samples/train/2021 - 21 Pelinsu Özkan (Aktif).ply"
# normals = get_features(path, export_output=True)

# %%
# path = "../experimentation_scripts/data_samples/train/kerem celik.ply"
# normals = get_features(path)

# %%
meshPathes = [mesh for mesh in os.listdir("../experimentation_scripts/data_samples/train") if mesh.endswith(".ply")]

# %% [markdown]
# #### Extract features from the dataset

# %%
import pickle

features = []
for mesh in meshPathes:
    feature = get_features(os.path.join("../experimentation_scripts/data_samples/train", mesh))
    feature = np.nan_to_num(feature)
    features.append((mesh, feature))
    print(len(features))

with open("features.pkl", "wb") as f:
    pickle.dump(features, f)
# Out:
# ../experimentation_scripts/data_samples/train/ARTI_ali_riza_ersin_(+).ply
# 1
# ../experimentation_scripts/data_samples/train/2024-09-16_14-55-22_回复__visit_to_Germany.ply
# 2
# ../experimentation_scripts/data_samples/train/ARTI_Sebnem_Ela_Cengizhan_(+).ply
# 3
# ../experimentation_scripts/data_samples/train/AKTIF__azra_duru_yildiz.ply
# 4
# ../experimentation_scripts/data_samples/train/2024-07-05_18-59-35_Fwd__Fw__Patient_Data_ziad_Kareem_3_case_5724.ply
# 5
# ../experimentation_scripts/data_samples/train/2024-09-20_16-42-31_Fwd__Fw__Patient_Data_Maria_charity_1924.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 6
# ../experimentation_scripts/data_samples/train/ilkim cemal kara 140921KALECAN.ply
# 7
# ../experimentation_scripts/data_samples/train/ARTI_yigit_ali_boz_2_(+).ply
# 8
# ../experimentation_scripts/data_samples/train/KALECAN_ecrin_ada_sener-_korse.ply
# 9
# ../experimentation_scripts/data_samples/train/ARTI_ayse_beren_nebil.ply
# 10
# ../experimentation_scripts/data_samples/train/2023-10-06_10-11-52_Fw__3D_Model_Jana_sherif_21023__her_2nd_brace___no_new_xray_yet_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 11
# ../experimentation_scripts/data_samples/train/FIZIMED_ZEYNEP_BAHSI_(_AKTIF_).ply
# 12
# ../experimentation_scripts/data_samples/train/2024-01-18_18-28-46_Patient_Data.ply
# 13
# ../experimentation_scripts/data_samples/train/2024-09-13_10-55-45_Patient_Data_Estela_Soares.ply
# 14
# ../experimentation_scripts/data_samples/train/FIZIMED_AHMET_KAYA_(_AKTIF_).ply
# 15
# ../experimentation_scripts/data_samples/train/KALECAN_defne_bekar.ply
# 16
# ../experimentation_scripts/data_samples/train/KALECAN_asya_guven.ply
# 17
# ../experimentation_scripts/data_samples/train/KALECAN_deniz_sukruogullari-korse.ply
# 18
# ../experimentation_scripts/data_samples/train/ozgu ergin.ply
# 19
# ../experimentation_scripts/data_samples/train/ARTI_Eylul_Acar.ply
# 20
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Elif_Irem_Sercin.ply
# 21
# ../experimentation_scripts/data_samples/train/AKTIF_deniz_kiran.ply
# 22
# ../experimentation_scripts/data_samples/train/Tugba Naz Korkmaz 3.ply
# 23
# ../experimentation_scripts/data_samples/train/ARTI_sila_dogan.ply
# 24
# ../experimentation_scripts/data_samples/train/FIZIMED_FURKAN_OZDEN_(_AKTIF_).ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 25
# ../experimentation_scripts/data_samples/train/2024-05-15_10-24-54_14_05_24.ply
# 26
# ../experimentation_scripts/data_samples/train/ARTI_Harun_gungeldi_Arti_PO.ply
# 27
# ../experimentation_scripts/data_samples/train/2024-01-13_01-57-49_Fw__Patient_Data_Mirna_Abd_el_Ghany_4124.ply
# 28
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_59_Beyza_Sevimli_(Aktif).ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 29
# ../experimentation_scripts/data_samples/train/2023-08-25_11-28-30_Fw__3D_Model_Hana_tamer_2923__design_and_fitting_.ply
# 30
# ../experimentation_scripts/data_samples/train/2023-10-06_11-28-48_Fw__3D_Model__Juli_nashed_51023___we_revise_orthomedix_brace_._.ply
# 31
# ../experimentation_scripts/data_samples/train/2023-09-08_13-29-53_Fw__3D_Model_salma_Salah_6923.ply
# 32
# ../experimentation_scripts/data_samples/train/2021 - 21 Pelinsu Özkan (Aktif).ply
# 33
# ../experimentation_scripts/data_samples/train/AKTIF__Alya_Akalin.ply
# 34
# ../experimentation_scripts/data_samples/train/KALECAN_Ali_Ihsan_Ayanlar_KCO.ply
# 35
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Ilke_Deren_Zafer.ply
# 36
# ../experimentation_scripts/data_samples/train/2023-07-24_12-44-30_Fw__3D_Model_Omar_Hatem_7823_full_service_.ply
# 37
# ../experimentation_scripts/data_samples/train/KALECAN_ECRIN_PANCAROGLU.ply
# 38
# ../experimentation_scripts/data_samples/train/mert altınay.ply
# 39
# ../experimentation_scripts/data_samples/train/murathan ateş.ply
# 40
# ../experimentation_scripts/data_samples/train/2023-10-06_10-34-28_Fw__3D_Model_Clara__01023__free_revision_.ply
# 41
# ../experimentation_scripts/data_samples/train/KALECAN_basak_ela_ceyani-korse.ply
# 42
# ../experimentation_scripts/data_samples/train/KONFOR_sila_elmas.ply
# 43
# ../experimentation_scripts/data_samples/train/2024-08-29_08-29-13_New_patient._.ply
# 44
# ../experimentation_scripts/data_samples/train/ARTI_Sude_Kara.ply
# 45
# ../experimentation_scripts/data_samples/train/KALECAN_batuhan_okan.ply
# 46
# ../experimentation_scripts/data_samples/train/2024-05-25_13-55-46_25_05_24-3.ply
# 47
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_hilkmet_can_kaya.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 48
# ../experimentation_scripts/data_samples/train/KONFOR_Sema_nur_Gultekin.ply
# 49
# ../experimentation_scripts/data_samples/train/2024-03-01_13-48-01_Fw__Patient_Data_Lana_3324.ply
# 50
# ../experimentation_scripts/data_samples/train/KALECAN_Asel_Yildirim.ply
# 51
# ../experimentation_scripts/data_samples/train/2024-08-23_13-54-34_Fwd__Fw__Patient_Data_Malak_Mohamed_1824.ply
# 52
# ../experimentation_scripts/data_samples/train/ARTI_sila_dogru.ply
# 53
# ../experimentation_scripts/data_samples/train/ECE_ORTOPEDI_KONYA_Enes_Doruk_ECE.ply
# 54
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_ela_yuksel.ply
# 55
# ../experimentation_scripts/data_samples/train/CEYLAN_Tuana_Gursoy_(ceylan).ply
# 56
# ../experimentation_scripts/data_samples/train/Yusuf Yanmaz.ply
# 57
# ../experimentation_scripts/data_samples/train/2024-01-20_11-02-56_Fw__Patient_Data_Mohamed_Fareed_2.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 58
# ../experimentation_scripts/data_samples/train/Zeynep Naz Pınar KlinikSport.ply
# 59
# ../experimentation_scripts/data_samples/train/mustafa koc.ply
# 60
# ../experimentation_scripts/data_samples/train/KALECAN_dide_gazel_abakay.ply
# 61
# ../experimentation_scripts/data_samples/train/irem su dikmenKALECAN.ply
# 62
# ../experimentation_scripts/data_samples/train/FIZIMED_ELIZ_OZDOGAN.ply
# 63
# ../experimentation_scripts/data_samples/train/KALECAN_asel_kucukcoban.ply
# 64
# ../experimentation_scripts/data_samples/train/ECE_ORTOPEDI_KONYA_Ahmet_Talha_Saracoglu_ECE.ply
# 65
# ../experimentation_scripts/data_samples/train/tugce birinci2.ply
# 66
# ../experimentation_scripts/data_samples/train/CEYLAN_aysegul_toker.ply
# 67
# ../experimentation_scripts/data_samples/train/zeynep ilhan.ply
# 68
# ../experimentation_scripts/data_samples/train/2024-03-19_09-40-42_Patient_Data_Vitor_Romagnoli_Alves._March_19_24.ply
# 69
# ../experimentation_scripts/data_samples/train/AKTIF_emir_ay.ply
# 70
# ../experimentation_scripts/data_samples/train/2023-06-16_11-06-59_Fw__3D_Model_Mariam_Qatar__the_right_scan_4723.ply
# 71
# ../experimentation_scripts/data_samples/train/Melisa Nur Acar kalecan.ply
# 72
# ../experimentation_scripts/data_samples/train/2024-03-31_12-49-50_Fw__Patient_Data_adam_Karim_5424.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 73
# ../experimentation_scripts/data_samples/train/2024-06-07_13-48-24_Another_measurement.ply
# 74
# ../experimentation_scripts/data_samples/train/ECE_ORTOPEDI_KONYA_Eymen_Talip_Taskin.ply
# 75
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Ilke_Cemre_Kilincarslan.ply
# 76
# ../experimentation_scripts/data_samples/train/FIZIMED_ECEM_SU_KUNT_(_AKTIF_).ply
# 77
# ../experimentation_scripts/data_samples/train/Furkan Keleş.ply
# 78
# ../experimentation_scripts/data_samples/train/2023-08-14_08-32-16_Fw__3D_Model_Reem_Ibrahim_9823_.ply
# 79
# ../experimentation_scripts/data_samples/train/2024-05-25_13-49-15_25_05_24-2.ply
# 80
# ../experimentation_scripts/data_samples/train/2023-11-16_10-54-45_Fw__3D_Model_haad_Libya__31123_.ply
# 81
# ../experimentation_scripts/data_samples/train/nil yuruk.ply
# 82
# ../experimentation_scripts/data_samples/train/2023-08-14_09-07-25_Fw__3D_Model_karma_Assam_11823_full_service_by_eric_.ply
# 83
# ../experimentation_scripts/data_samples/train/AKTIF__can_efe_baki.ply
# 84
# ../experimentation_scripts/data_samples/train/2023-04-09_15-52-41_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply
# 85
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Irem_Temizel.ply
# 86
# ../experimentation_scripts/data_samples/train/DIYAMER_Yigitcan_Caglar.ply
# 87
# ../experimentation_scripts/data_samples/train/2024-05-06_10-48-52_Patient_Data_isis_Castanheira.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 88
# ../experimentation_scripts/data_samples/train/2023-11-26_09-23-30_Re__3D_Model_colored_again___51123.ply
# 89
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_13_Defne_Kaya_(Aktif).ply
# 90
# ../experimentation_scripts/data_samples/train/gözde nur maraşlı.ply
# 91
# ../experimentation_scripts/data_samples/train/AKTIF_eylul_deniz_kadas.ply
# 92
# ../experimentation_scripts/data_samples/train/Realeboha Kevin Kao.ply
# 93
# ../experimentation_scripts/data_samples/train/FIZIMED_EGE_OZKAYA_(_AKTIF_).ply
# 94
# ../experimentation_scripts/data_samples/train/AKTIF_elif_guler.ply
# 95
# ../experimentation_scripts/data_samples/train/2024-03-13_01-18-59_Fw__Patient_Data_Rosetta_6324.ply
# 96
# ../experimentation_scripts/data_samples/train/FIZIMED_KEMAL_YIGIT_TORER_(_AKTIF_).ply
# 97
# ../experimentation_scripts/data_samples/train/2024-08-07_15-17-01_Patient_Data_Raphael_Rodrigues.ply
# 98
# ../experimentation_scripts/data_samples/train/ARTIrabia gursoy.ply
# 99
# ../experimentation_scripts/data_samples/train/halim durnaKALECAN.ply
# 100
# ../experimentation_scripts/data_samples/train/tugbanaz Korkmaz.ply
# 101
# ../experimentation_scripts/data_samples/train/2024-02-02_06-48-33_Fw__moaz_1224.ply
# 102
# ../experimentation_scripts/data_samples/train/FIZIMED_EMRE_SARP_ZEYTINOGLU_2.ply
# 103
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_EGEM_DENIZLI_cem_kayman.ply
# 104
# ../experimentation_scripts/data_samples/train/Sude Durmaz (Aynur).ply
# 105
# ../experimentation_scripts/data_samples/train/2023-08-25_11-13-10_Fw__3D_Model_febronia_1st_polls_1923__just_G_code__pls____fitting_and__print_will_be_done_locally___charity_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 106
# ../experimentation_scripts/data_samples/train/ömer hamza lafcı.ply
# 107
# ../experimentation_scripts/data_samples/train/ARTI_beyza_isil_yildirim_+.ply
# 108
# ../experimentation_scripts/data_samples/train/kerem celik.ply
# 109
# ../experimentation_scripts/data_samples/train/mikail acar.ply
# 110
# ../experimentation_scripts/data_samples/train/zumra sancaktepe.ply
# 111
# ../experimentation_scripts/data_samples/train/FIZIMED_TUANA_KENDIRCI_(_AKTIF_).ply
# 112
# ../experimentation_scripts/data_samples/train/yasemin kıvrak.ply
# 113
# ../experimentation_scripts/data_samples/train/AKTIF_elif_duru_zengin.ply
# 114
# ../experimentation_scripts/data_samples/train/CEYLAN_berrak_ozturk.ply
# 115
# ../experimentation_scripts/data_samples/train/2023-12-18_10-55-26_Maria_Fernanda_new_Brace.ply
# 116
# ../experimentation_scripts/data_samples/train/AKTIF_ecenur_tuysuz.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 117
# ../experimentation_scripts/data_samples/train/2024-09-22_19-24-35_Fwd__Fw__Patient_Data_Martina_4924___pls_read_my_notes_first.ply
# 118
# ../experimentation_scripts/data_samples/train/2023-08-09_14-36-59_Patient_Iasmin_Stucki.ply
# 119
# ../experimentation_scripts/data_samples/train/AKTIF_elif_korkmaz.ply
# 120
# ../experimentation_scripts/data_samples/train/FIZIMED_AYSENAZ_BALABAN_(_AKTIF_).ply
# 121
# ../experimentation_scripts/data_samples/train/AKTIF__Belinay_Keskin.ply
# 122
# ../experimentation_scripts/data_samples/train/2024-07-05_14-34-36_Fwd__Fw__Patient_Data_Omar_zakarya_1_case_1724___will_do_new_xray.ply
# 123
# ../experimentation_scripts/data_samples/train/AKTIF__buglem_karaca.ply
# 124
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Victoria_Blatskaya.ply
# 125
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_10_Alp_Doganer_(Aktif).ply
# 126
# ../experimentation_scripts/data_samples/train/Omer faruk Yanas.ply
# 127
# ../experimentation_scripts/data_samples/train/2024-02-04_19-52-34_Fw__Patient_Data_karas_Tamer_2224_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 128
# ../experimentation_scripts/data_samples/train/CITAY_IZMIR_A_R_D_KORSE.ply
# 129
# ../experimentation_scripts/data_samples/train/2023-05-12_10-32-48_Fw__3D_Model_Hana_bahaa_revison__2523.ply
# 130
# ../experimentation_scripts/data_samples/train/FIZIMED_NISA_TUANA_YUMRUTAS_(_AKTIF_).ply
# 131
# ../experimentation_scripts/data_samples/train/ARTI_hatice_eceylan_+05_04_2022.ply
# 132
# ../experimentation_scripts/data_samples/train/2023-10-29_21-37-27_Fw__3D_Model_firial__11123_pls_print_in_USA_.ply
# 133
# ../experimentation_scripts/data_samples/train/CITAY_IZMIR_so_citay.ply
# 134
# ../experimentation_scripts/data_samples/train/esin ünlü kalecan.ply
# 135
# ../experimentation_scripts/data_samples/train/lara ada bıldır.ply
# 136
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Ayben_Armina_Temel.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 137
# ../experimentation_scripts/data_samples/train/AKTIF__asmin_cetin.ply
# 138
# ../experimentation_scripts/data_samples/train/KALECAN_ayse_barut_14-05-22.ply
# 139
# ../experimentation_scripts/data_samples/train/2024-08-03_12-33-49_New_Scans_and_order._.ply
# 140
# ../experimentation_scripts/data_samples/train/2024-06-11_13-40-00_FW__Patient_Data_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 141
# ../experimentation_scripts/data_samples/train/2023-05-12_10-45-30_Fw__3D_Model_basmala_walid_3523.ply
# 142
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_zeren_boz.ply
# 143
# ../experimentation_scripts/data_samples/train/2021 - 21 Pelinsu Özkan (Aktif)_original.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 144
# ../experimentation_scripts/data_samples/train/FIZIMED_FATMA_MOLLA_(_AKTIF_).ply
# 145
# ../experimentation_scripts/data_samples/train/2024-06-12_09-42-53_Fwd__Patient_Data_Giovana_Dantas.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 146
# ../experimentation_scripts/data_samples/train/KALECAN_adem_unal.ply
# 147
# ../experimentation_scripts/data_samples/train/fatma zumra aydın.ply
# 148
# ../experimentation_scripts/data_samples/train/2024-05-22_09-24-28_Fwd__Patient_Data.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 149
# ../experimentation_scripts/data_samples/train/AKTIF_Elif_Guler_2.ply
# 150
# ../experimentation_scripts/data_samples/train/2024-05-25_09-53-09_New_Scan_.ply
# 151
# ../experimentation_scripts/data_samples/train/nil yürük 3.ply
# 152
# ../experimentation_scripts/data_samples/train/AKTIF__Buse_Goksel.ply
# 153
# ../experimentation_scripts/data_samples/train/AKTIF__alara_hizlan.ply
# 154
# ../experimentation_scripts/data_samples/train/saliha zeynep akdemir.ply
# 155
# ../experimentation_scripts/data_samples/train/Yasemin Guney.ply
# 156
# ../experimentation_scripts/data_samples/train/AKTIF__Berra_Tilaver.ply
# 157
# ../experimentation_scripts/data_samples/train/AKTIF__ada_onur.ply
# 158
# ../experimentation_scripts/data_samples/train/Hicran Durak.ply
# 159
# ../experimentation_scripts/data_samples/train/2023-10-06_10-15-34_Fw__3D_Model_farida_sedky_31023__i_donot_need_Menna_to_be_in_the_room__or_get_close_to_her_mom___fitting_by_y_and_mariam__thx__.ply
# 160
# ../experimentation_scripts/data_samples/train/KONFOR_Meyz_Al_Ali.ply
# 161
# ../experimentation_scripts/data_samples/train/KALECAN_celal_cinar_coksoy.ply
# 162
# ../experimentation_scripts/data_samples/train/ARTI_tuncer_erdogan.ply
# 163
# ../experimentation_scripts/data_samples/train/2024-03-25_10-10-40_Fwd__Patient_Data_Lays_.ply
# 164
# ../experimentation_scripts/data_samples/train/reyyan komurcuKALECAN.ply
# 165
# ../experimentation_scripts/data_samples/train/AKTIF__Alp_Ceyhan.ply
# 166
# ../experimentation_scripts/data_samples/train/2024-09-04_09-32-55_Fwd__Patient_Data.ply
# 167
# ../experimentation_scripts/data_samples/train/Elif Sümeyye Gül.ply
# 168
# ../experimentation_scripts/data_samples/train/KALECAN_defne_yaliguluhep.ply
# 169
# ../experimentation_scripts/data_samples/train/ARTI_irem_badurlar_(+).ply
# 170
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_derya_arbabham.ply
# 171
# ../experimentation_scripts/data_samples/train/AKTIF_ecrin_nil_yavuzaslan.ply
# 172
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Lutfu_ege_bodur.ply
# 173
# ../experimentation_scripts/data_samples/train/AKTIF_evrim_yilmaz.ply
# 174
# ../experimentation_scripts/data_samples/train/melek çakırKALECAN.ply
# 175
# ../experimentation_scripts/data_samples/train/AKTIF__Aylin_guliyeva23.ply
# 176
# ../experimentation_scripts/data_samples/train/tufan emre aydın2.ply
# 177
# ../experimentation_scripts/data_samples/train/AKTIF__Ada_Serindere.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 178
# ../experimentation_scripts/data_samples/train/Ezgi karatepe.ply
# 179
# ../experimentation_scripts/data_samples/train/2024-04-10_08-58-29_Clara_s_data.ply
# 180
# ../experimentation_scripts/data_samples/train/KALECAN_DERIN_KAPLAN-KCO.ply
# 181
# ../experimentation_scripts/data_samples/train/tanem harputluKALECAN.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 182
# ../experimentation_scripts/data_samples/train/AKTIF__berfin_gunduz.ply
# 183
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan.ply
# 184
# ../experimentation_scripts/data_samples/train/ANKA_DUZCE_merve_nur_tureli.ply
# 185
# ../experimentation_scripts/data_samples/train/ARTI_ela_kilic.ply
# 186
# ../experimentation_scripts/data_samples/train/Sura Soyak 05042022.ply
# 187
# ../experimentation_scripts/data_samples/train/ARTI_Irem_macit.ply
# 188
# ../experimentation_scripts/data_samples/train/sevval nuran cavdar.ply
# 189
# ../experimentation_scripts/data_samples/train/meryem zehra demir.ply
# 190
# ../experimentation_scripts/data_samples/train/KALECAN_beray_tokatlioglu.ply
# 191
# ../experimentation_scripts/data_samples/train/2024-06-08_14-08-00_Fwd__Fw__Patient_Data_Ziad_2_3624.ply
# 192
# ../experimentation_scripts/data_samples/train/AKTIF__aysegul_benek.ply
# 193
# ../experimentation_scripts/data_samples/train/2023-08-08_09-33-25_Fw__3D_Model_omar_moataz_8823_design_and_fitting_by_eric__print_in__usa___son_of_special_force_.ply
# 194
# ../experimentation_scripts/data_samples/train/FIZIMED_ELIZ_OZDOGAN_(_AKTIF_).ply
# 195
# ../experimentation_scripts/data_samples/train/FIZIMED_AZRA_SEKER_fizimed.ply
# 196
# ../experimentation_scripts/data_samples/train/ARTI_tugba_nur_coban.ply
# 197
# ../experimentation_scripts/data_samples/train/ARTI_cafer_ali_yesiltas_arti.ply
# 198
# ../experimentation_scripts/data_samples/train/ARTI_tuana_deniz_(arti).ply
# 199
# ../experimentation_scripts/data_samples/train/2024-06-05_18-02-55_John_Tunney_patients.ply
# 200
# ../experimentation_scripts/data_samples/train/2024-05-01_06-29-16_Patient_File_-_ACMC1.ply
# 201
# ../experimentation_scripts/data_samples/train/FIZIMED_DICLENAZ_ISBILEN_(_AKTIF_).ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 202
# ../experimentation_scripts/data_samples/train/ilayda saygı.ply
# 203
# ../experimentation_scripts/data_samples/train/fatma genç-korseKALECAN.ply
# 204
# ../experimentation_scripts/data_samples/train/AKTIF_ceylin_ece_tektas.ply
# 205
# ../experimentation_scripts/data_samples/train/2024-03-13_11-20-50_Patient_Data_Malásia_.ply
# 206
# ../experimentation_scripts/data_samples/train/AKTIF__aylin_guliyeva.ply
# 207
# ../experimentation_scripts/data_samples/train/2024-03-27_14-14-06_Fw__Patient_Data_Malak_saada__2424___her_2nd_brace_in_7_month_____her__old_file___13823__.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 208
# ../experimentation_scripts/data_samples/train/Ömer Hamza Lafcı 2.ply
# 209
# ../experimentation_scripts/data_samples/train/2023-11-16_14-14-44_Fw__3D_Model_nahed_el_Amir__41123_design_only___look_at_y_notes_.ply
# 210
# ../experimentation_scripts/data_samples/train/nevanur govec.ply
# 211
# ../experimentation_scripts/data_samples/train/2024-03-27_15-08-44_Fwd__Luana_Cavalca_27_3_2024.ply
# 212
# ../experimentation_scripts/data_samples/train/Çağlar Günerkaya KCO_KALECAN.ply
# 213
# ../experimentation_scripts/data_samples/train/AKTIF__ahsen_ismetogullari.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 214
# ../experimentation_scripts/data_samples/train/zeynep saliha akdemir.ply
# 215
# ../experimentation_scripts/data_samples/train/metehan er.ply
# 216
# ../experimentation_scripts/data_samples/train/Pelin Kurtulus.ply
# 217
# ../experimentation_scripts/data_samples/train/mirac kockaya.ply
# 218
# ../experimentation_scripts/data_samples/train/inci defne yunlu.ply
# 219
# ../experimentation_scripts/data_samples/train/ARTI_tugba_nur_acar_+.ply
# 220
# ../experimentation_scripts/data_samples/train/2024-01-13_14-23-31_Re__Patient_DataTouline_1____6124.ply
# 221
# ../experimentation_scripts/data_samples/train/Toprak su demir.ply
# 222
# ../experimentation_scripts/data_samples/train/ARTI_ahmet_hosgor_(+).ply
# 223
# ../experimentation_scripts/data_samples/train/2023-08-30_18-51-11_Fw__3D_Masoud_with_poles_5923__his_2nd_brace______pervious_brace_was__from_Greece___pls__design_and_fitting_only.ply
# 224
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_EGEM_DENIZLI_ahmet_ahlat.ply
# 225
# ../experimentation_scripts/data_samples/train/AKTIF_AZRA VARDAR.ply
# 226
# ../experimentation_scripts/data_samples/train/ECE_ORTOPEDI_KONYA_Kezban_Irem_Icoz.ply
# 227
# ../experimentation_scripts/data_samples/train/2024-05-30_16-47-40_Fwd__Patient_Data.ply
# 228
# ../experimentation_scripts/data_samples/train/AKTIF__arda_gul_2.ply
# 229
# ../experimentation_scripts/data_samples/train/AKTIF_eren_hicyilmaz.ply
# 230
# ../experimentation_scripts/data_samples/train/DENIZ_OKE_Irem_Kose.ply
# 231
# ../experimentation_scripts/data_samples/train/KONFOR_Alperen__Karaca_konfor.ply
# 232
# ../experimentation_scripts/data_samples/train/LUXMED_Defne_Dagistanli_luxmed.ply
# 233
# ../experimentation_scripts/data_samples/train/2024-04-10_07-51-07_Camila_s_data.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 234
# ../experimentation_scripts/data_samples/train/2023-10-06_11-25-01_Fw__3D_Model_menna_husky_41023___her_2nd_brace_.ply
# 235
# ../experimentation_scripts/data_samples/train/AKTIF_Derya_Deniz_Varol.ply
# 236
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_40_Selen_Baydar_(Aktif).ply
# 237
# ../experimentation_scripts/data_samples/train/ARTI_meyranur_karagoz.ply
# 238
# ../experimentation_scripts/data_samples/train/mikail acar 2.ply
# 239
# ../experimentation_scripts/data_samples/train/AKTIF_ELIF_TUANA_SAVCI.ply
# 240
# ../experimentation_scripts/data_samples/train/AKTIF__arya_fakirzade.ply
# 241
# ../experimentation_scripts/data_samples/train/2023-08-14_12-02-55_Fwd__Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply
# 242
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_51_Hiranur_Sekban_(Aktif).ply
# 243
# ../experimentation_scripts/data_samples/train/ezgi nur aydemir.ply
# 244
# ../experimentation_scripts/data_samples/train/2024-08-01_10-11-30_Fwd__Patient_Data_Felipe_4.ply
# 245
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_EGEM_DENIZLI_Defne_Enli.ply
# 246
# ../experimentation_scripts/data_samples/train/AKTIF__cagla_bade_kiyak_2.ply
# 247
# ../experimentation_scripts/data_samples/train/rumeysa gocmen.ply
# 248
# ../experimentation_scripts/data_samples/train/AKTIF__Beril_Yilmazer.ply
# 249
# ../experimentation_scripts/data_samples/train/AKTIF_durudeniz_turan_2.ply
# 250
# ../experimentation_scripts/data_samples/train/eylül kutu KCO 041021KALECAN.ply
# 251
# ../experimentation_scripts/data_samples/train/sinem ünlüerKALECAN.ply
# 252
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Dersim_Toptas.ply
# 253
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_Mustafa_Elvan_egem.ply
# 254
# ../experimentation_scripts/data_samples/train/AKTIF_ege_elibol.ply
# 255
# ../experimentation_scripts/data_samples/train/ırmak tuğla.ply
# 256
# ../experimentation_scripts/data_samples/train/ARTI_emircan_tursun_(+).ply
# 257
# ../experimentation_scripts/data_samples/train/Ada Çalışkan ksKLINIKSPORT.ply
# 258
# ../experimentation_scripts/data_samples/train/AKTIF_esma_bahtiyar.ply
# 259
# ../experimentation_scripts/data_samples/train/2024-01-13_01-56-38_Fw__Patient_Data_Jana_Abd_El_Ghany_3124.ply
# 260
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_18_Azra_Yigitoglu_(Aktif).ply
# 261
# ../experimentation_scripts/data_samples/train/2024-03-15_12-54-25_150324.ply
# 262
# ../experimentation_scripts/data_samples/train/melisa nur acar 2KALECAN.ply
# 263
# ../experimentation_scripts/data_samples/train/Kaan Kubilay Çetinkaya.ply
# 264
# ../experimentation_scripts/data_samples/train/2024-03-24_08-35-01_Fw_mariam_Fouad_1424.ply
# 265
# ../experimentation_scripts/data_samples/train/2024-06-05_11-36-36_Fwd__Patient_Data_Misha_24.ply
# 266
# ../experimentation_scripts/data_samples/train/KALECAN_avsin_somer-korse.ply
# 267
# ../experimentation_scripts/data_samples/train/FIZIMED_DOGA_CIVELEK_(_fizimed_).ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 268
# ../experimentation_scripts/data_samples/train/sevval nur guzeltepe.ply
# 269
# ../experimentation_scripts/data_samples/train/AKTIF__Beren_Bay.ply
# 270
# ../experimentation_scripts/data_samples/train/Ilgar Güzel 240921KALECAN.ply
# 271
# ../experimentation_scripts/data_samples/train/2024-07-08_12-10-30_Fwd__Fw__Patient_Data_omar_Motaz_6724___his_2nd_brace.ply
# 272
# ../experimentation_scripts/data_samples/train/ECE_ORTOPEDI_KONYA_Sedef_OzCelik_ECE.ply
# 273
# ../experimentation_scripts/data_samples/train/İclal Rukiye Karaca.ply
# 274
# ../experimentation_scripts/data_samples/train/İsik Sezer Saridede.ply
# 275
# ../experimentation_scripts/data_samples/train/KONFOR_lemar_alheyek.ply
# 276
# ../experimentation_scripts/data_samples/train/Miraz Nisa Nakci.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 277
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Ela_Yuksel_2.ply
# 278
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Tuana_Celik.ply
# 279
# ../experimentation_scripts/data_samples/train/tuğba naz korkmaz 2.ply
# 280
# ../experimentation_scripts/data_samples/train/2023-08-25_11-38-13_Fw__3D_Model_nouran__4923_design_and_fitting___her_2nd_brace_in_8__month___dad_is_cardio_in_UK_.ply
# 281
# ../experimentation_scripts/data_samples/train/KARTAL YİLMAZKALECAN.ply
# 282
# ../experimentation_scripts/data_samples/train/TALA ABUGAHALİ.ply
# 283
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_23_Halim_Burak_Nilifikra_(Aktif).ply
# 284
# ../experimentation_scripts/data_samples/train/AKTIF__Ayse_Melis_Yalcin.ply
# 285
# ../experimentation_scripts/data_samples/train/ARTI_vedat_daglik_(+).ply
# 286
# ../experimentation_scripts/data_samples/train/FIZIMED_NEHIR_DURU_CELIK_(AKTIF_).ply
# 287
# ../experimentation_scripts/data_samples/train/AKTIF__Azra_Karacaoglu.ply
# 288
# ../experimentation_scripts/data_samples/train/FIZIMED_ECE_GULERSEN_(_AKTIF_).ply
# 289
# ../experimentation_scripts/data_samples/train/ARTI_Busra_Karaca_+.ply
# 290
# ../experimentation_scripts/data_samples/train/AKTIF_Elif_Korkmaz_04-23.ply
# 291
# ../experimentation_scripts/data_samples/train/2024-09-22_18-59-51_Fwd__Fw__Patient_Data_Malak_bashir_3924.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 292
# ../experimentation_scripts/data_samples/train/2023-06-22_12-38-29_Fw__3D_Model_Maya_9723__her_3rd_brace_in_2_years____are_y_S3_.ply
# 293
# ../experimentation_scripts/data_samples/train/2024-05-09_12-52-03_SA0905.ply
# 294
# ../experimentation_scripts/data_samples/train/2023-12-04_22-12-18_Fw__Patient_Data_Noha_21223__design_pls____p.ply
# 295
# ../experimentation_scripts/data_samples/train/AKTIF_Elif_Eylul_Demir.ply
# 296
# ../experimentation_scripts/data_samples/train/AKTIF_elif_naz_keles.ply
# 297
# ../experimentation_scripts/data_samples/train/AKTIF_can_seker.ply
# 298
# ../experimentation_scripts/data_samples/train/FIZIMED_ATILLA_ALLAHVERDI_(_AKTIF_).ply
# 299
# ../experimentation_scripts/data_samples/train/UMUT_azranur_yetim.ply
# 300
# ../experimentation_scripts/data_samples/train/Sadık Bilal Son 090621KALECAN.ply
# 301
# ../experimentation_scripts/data_samples/train/AKTIF__Alya_Doga_senlik.ply
# 302
# ../experimentation_scripts/data_samples/train/AKTIF__ahmet_erdem.ply
# 303
# ../experimentation_scripts/data_samples/train/2024-08-24_11-30-01_FW__Patient_Data.ply
# 304
# ../experimentation_scripts/data_samples/train/çağla bade kıyak.ply
# 305
# ../experimentation_scripts/data_samples/train/AKTIF_Dila_Zeynep_Bayat.ply
# 306
# ../experimentation_scripts/data_samples/train/2024-05-27_10-11-43_Fwd__Fw__Patient_Data_Silvia_1624.ply
# 307
# ../experimentation_scripts/data_samples/train/FIZIMED_ECRIN_CAPACI_(_AKTIF_).ply
# 308
# ../experimentation_scripts/data_samples/train/AKTIF__Alya_Dua_Senlik_2.ply
# 309
# ../experimentation_scripts/data_samples/train/2024-06-15_08-44-25_Fwd__Fw__Patient_Data_Jana_Mohamed_4624.ply
# 310
# ../experimentation_scripts/data_samples/train/ARTI_yigit_ali_boz.ply
# 311
# ../experimentation_scripts/data_samples/train/2024-09-15_13-33-28_Fwd__Fw__Patient_Data_Noor_10824.ply
# 312
# ../experimentation_scripts/data_samples/train/Hatice Duman.ply
# 313
# ../experimentation_scripts/data_samples/train/AKTIF__beyza_atak.ply
# 314
# ../experimentation_scripts/data_samples/train/CIGDEM_DR_Arda_Yalcindag.ply
# 315
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_48_Ilyas_Kadir_Saribas_(Aktif).ply
# 316
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_39_Kemal_Efe_Alakavuk_(Aktif).ply
# 317
# ../experimentation_scripts/data_samples/train/2021 - 21 Pelinsu Özkan (Aktif)_features.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 318
# ../experimentation_scripts/data_samples/train/CEYLAN_sude_gul_guvenc.ply
# 319
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_nehir_acar.ply
# 320
# ../experimentation_scripts/data_samples/train/2023-08-06_12-54-34_Fwd__Fw__3D_Model_jumana_aish_4823___full_service.ply
# 321
# ../experimentation_scripts/data_samples/train/AKTIF_elif_guler3.ply
# 322
# ../experimentation_scripts/data_samples/train/Eda Ozturk KALECAN.ply
# 323
# ../experimentation_scripts/data_samples/train/şura soyak.ply
# 324
# ../experimentation_scripts/data_samples/train/AKTIF_Ebrar_Kazan.ply
# 325
# ../experimentation_scripts/data_samples/train/SIFA_ORTOPEDI_D_BAKIR.ply
# 326
# ../experimentation_scripts/data_samples/train/ayse zehra say 3.ply
# 327
# ../experimentation_scripts/data_samples/train/2024-07-25_14-52-35_Fwd__Patient_Data_Olívia_Rocha_2.ply
# 328
# ../experimentation_scripts/data_samples/train/Yağmur Sena Çalışkan.ply
# 329
# ../experimentation_scripts/data_samples/train/AKTIF__Can_Seker_2.ply
# 330
# ../experimentation_scripts/data_samples/train/Melis Kargaci.ply
# 331
# ../experimentation_scripts/data_samples/train/kartal yìlmaz-korseKALECAN.ply
# 332
# ../experimentation_scripts/data_samples/train/AKTIF_ceylin_arslan.ply
# 333
# ../experimentation_scripts/data_samples/train/AKTIF_Duru_Deniz_Turan.ply
# 334
# ../experimentation_scripts/data_samples/train/2023-09-13_11-33-13_Re__3D_Model_sajda_3923_design_and_fitting_.ply
# 335
# ../experimentation_scripts/data_samples/train/2023-11-25_13-52-28_Fwd__Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 336
# ../experimentation_scripts/data_samples/train/jouman elsalti.ply
# 337
# ../experimentation_scripts/data_samples/train/KALECAN_ayse_azra_temiz.ply
# 338
# ../experimentation_scripts/data_samples/train/sinem topcu.ply
# 339
# ../experimentation_scripts/data_samples/train/AKTIF_elif_nisa_celebi.ply
# 340
# ../experimentation_scripts/data_samples/train/fatma alhac avad.ply
# 341
# ../experimentation_scripts/data_samples/train/AKTIF_defne_sisli.ply
# 342
# ../experimentation_scripts/data_samples/train/ARTI_kivanc_yasar_(+).ply
# 343
# ../experimentation_scripts/data_samples/train/tufan emre aydin.ply
# 344
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_Safiye_Berra_Sirinal.ply
# 345
# ../experimentation_scripts/data_samples/train/KALECAN_azra_aydin.ply
# 346
# ../experimentation_scripts/data_samples/train/2024-07-31_11-00-51_Fwd__Patient_Data_Gabriel.ply
# 347
# ../experimentation_scripts/data_samples/train/2024-08-23_13-59-22_Fwd__Fw__Patient_Data_Login_Ihab_case_5824.ply
# 348
# ../experimentation_scripts/data_samples/train/melisa nur acar-korseKALECAN.ply
# 349
# ../experimentation_scripts/data_samples/train/AKTIF__arda_gul.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 350
# ../experimentation_scripts/data_samples/train/ARTI_Ecrin_Cagan.ply
# 351
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_6_Arda_Darici(Aktif).ply
# 352
# ../experimentation_scripts/data_samples/train/2024-05-27_10-11-25_Fwd__Fw__Patient_Data_engy_melad_2624.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 353
# ../experimentation_scripts/data_samples/train/2024-06-05_11-50-56_Fwd__Beatriz_Savegnago_Ganzala_4_6_2024.ply
# 354
# ../experimentation_scripts/data_samples/train/Nisanur Salman.ply
# 355
# ../experimentation_scripts/data_samples/train/2023-07-13_18-56-27_Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 356
# ../experimentation_scripts/data_samples/train/AKTIF__Alp_Doganer.ply
# 357
# ../experimentation_scripts/data_samples/train/CEYLAN_uveys_sevim.ply
# 358
# ../experimentation_scripts/data_samples/train/2024-01-20_11-06-02_Fw__Patient_Data_Mohamed_Fareed_with_images_from_old_brace_.ply
# 359
# ../experimentation_scripts/data_samples/train/2024-05-01_15-20-12_01_05_24-3rd_Scan.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 360
# ../experimentation_scripts/data_samples/train/nil yürük 2.ply
# 361
# ../experimentation_scripts/data_samples/train/FIZIMED_EMRE_SARP_ZEYTINOGLU_(_AKTIF_).ply
# 362
# ../experimentation_scripts/data_samples/train/FIZIMED_Ela_Mollavelioglu_FIZIMED.ply
# 363
# ../experimentation_scripts/data_samples/train/2024-04-08_01-42-27_Fw__Patient_Data_yousef_3_____7424__design_only____fitting_by_me_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 364
# ../experimentation_scripts/data_samples/train/AKTIF__aydan_yagmur_kose.ply
# 365
# ../experimentation_scripts/data_samples/train/KALECAN_batuhan_kasap.ply
# 366
# ../experimentation_scripts/data_samples/train/2023-11-25_13-46-11_Fwd__Fw__3D_Model_kisha_Nadine.ply
# 367
# ../experimentation_scripts/data_samples/train/2024-01-07_13-18-49_Fw__3D_Model_yehia_2nd_scan___2124.ply
# 368
# ../experimentation_scripts/data_samples/train/AKTIF__Ada_Nil_Cekem_082021.ply
# 369
# ../experimentation_scripts/data_samples/train/nevanur govec 2.ply
# 370
# ../experimentation_scripts/data_samples/train/ANKARA_GAZI_ELIF_TUANA_SAVCI.ply
# 371
# ../experimentation_scripts/data_samples/train/2024-02-28_12-48-34_Re__Patient_Data_hanin_Sameh_1324.ply
# 372
# ../experimentation_scripts/data_samples/train/2023-10-06_11-34-09_Fw__3D_Model_haya_morsi_001023_revison_.ply
# 373
# ../experimentation_scripts/data_samples/train/hatice ceylin doğan.ply
# 374
# ../experimentation_scripts/data_samples/train/2024-05-09_09-39-28_Data_patient_Esther.ply
# 375
# ../experimentation_scripts/data_samples/train/2024-07-01_09-52-11_Patient_Data_Heloísa_Goncalves.ply
# 376
# ../experimentation_scripts/data_samples/train/FIZIMED_SEZIN_IDER_(_AKTIF_).ply
# 377
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_EGEM_DENIZLI_Arda_Cihan.ply
# 378
# ../experimentation_scripts/data_samples/train/2024-03-01_10-27-03_Fw__Patient_Data_hafsa__2324_.ply
# 379
# ../experimentation_scripts/data_samples/train/AKTIF_AZRA_VARDAR_2.ply
# 380
# ../experimentation_scripts/data_samples/train/Hatice Betül Bağcı.ply
# 381
# ../experimentation_scripts/data_samples/train/2023-05-12_11-25-01_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply
# 382
# ../experimentation_scripts/data_samples/train/FIZIMED_ZEYNEP_AKDENIZ_(_AKTIF_).ply
# 383
# ../experimentation_scripts/data_samples/train/2024-03-31_12-43-00_Fw__Patient_Data_Arwa_Ahmed__3424.ply
# 384
# ../experimentation_scripts/data_samples/train/2023-06-17_01-22-25_Fw__3D_Model_Clara_John_7723.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 385
# ../experimentation_scripts/data_samples/train/Muhammed Ali tekinerKALECAN.ply
# 386
# ../experimentation_scripts/data_samples/train/pakize Akkurt.ply
# 387
# ../experimentation_scripts/data_samples/train/2023-06-25_19-00-59_Fw__3D_Model_Mariam_Romany_10723__she_will__do_new_xray_this_week_.ply
# 388
# ../experimentation_scripts/data_samples/train/tugce birinci.ply
# 389
# ../experimentation_scripts/data_samples/train/AKTIF_elif_korkmaz_2.ply
# 390
# ../experimentation_scripts/data_samples/train/2024-07-05_15-51-08_Fwd__Fw__Patient_Data_Mariam_Ahmed_3724.ply
# 391
# ../experimentation_scripts/data_samples/train/ARTI_naz_yagmur_ustuncan.ply
# 392
# ../experimentation_scripts/data_samples/train/AKTIF_eren_aktas.ply
# 393
# ../experimentation_scripts/data_samples/train/leyla gunes.ply
# 394
# ../experimentation_scripts/data_samples/train/2024-09-22_19-00-33_Fwd__Fw__Patient_Data_Adam_2924.ply
# 395
# ../experimentation_scripts/data_samples/train/AKTIF__Arda_Deniz_Oda.ply
# 396
# ../experimentation_scripts/data_samples/train/ANKARA_GAZI_MAHMUT_ESAT_HARACA.ply
# 397
# ../experimentation_scripts/data_samples/train/AKTIF__Ahsen_Aykac.ply
# 398
# ../experimentation_scripts/data_samples/train/2024-03-31_12-47-04_Fw__Patient_Data_1__Dan_Haytham_4424__her_4th_brace_.ply
# 399
# ../experimentation_scripts/data_samples/train/Nehir Murat 2.ply
# 400
# ../experimentation_scripts/data_samples/train/Nazlı Nehir Kaymakcilar.ply
# 401
# ../experimentation_scripts/data_samples/train/2024-06-20_10-13-09_Fwd__Patient_Data_Isabela_Mihitarian.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 402
# ../experimentation_scripts/data_samples/train/ARTI_Defne_Aygun.ply
# 403
# ../experimentation_scripts/data_samples/train/2024-07-05_15-24-55_Fwd__Maria_Eduarda_Rohde_de_Oliveira_5_07_2024.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 404
# ../experimentation_scripts/data_samples/train/Eymen yılmaz.ply
# 405
# ../experimentation_scripts/data_samples/train/2024-06-21_10-57-26_Fwd__Fw__Patient_Data_Ibrahim_Mohamed_2___5624.ply
# 406
# ../experimentation_scripts/data_samples/train/FIZIMED_ALI_BURAK_KARACASOY_(_AKTIF_).ply
# 407
# ../experimentation_scripts/data_samples/train/karan aleviKALECAN.ply
# 408
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Alara_Hizlan_2.ply
# 409
# ../experimentation_scripts/data_samples/train/2023-07-13_13-59-58_Fw__3D_Model_jumana_aish_4823___full_service_.ply
# 410
# ../experimentation_scripts/data_samples/train/2024-09-30_13-16-09_Fwd__Fw__Patient_Data_jouly_Maged_5924.ply
# 411
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_17_Elif_Naz_Yildiz_(Aktif).ply
# 412
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_Zeynep_Saliha_Akdemir2.ply
# 413
# ../experimentation_scripts/data_samples/train/AKTIF_Deniz_Cavus.ply
# 414
# ../experimentation_scripts/data_samples/train/2023-06-17_01-26-13_Fw__3D_Model_joudi_emad_8723__pls_cheack_the_quality_of_xray_.ply
# 415
# ../experimentation_scripts/data_samples/train/2024-08-23_13-54-54_Fwd__Fw__Patient_Data_Malak_Rabee_1_case___2824.ply
# 416
# ../experimentation_scripts/data_samples/train/2024-10-02_09-56-42_John_Tunney_call.ply
# 417
# ../experimentation_scripts/data_samples/train/hande turan.ply
# 418
# ../experimentation_scripts/data_samples/train/2024-03-09_13-53-46_Fw__Patient_Data_basmala_essam_4324_another_charity.ply
# 419
# ../experimentation_scripts/data_samples/train/AKTIF__beyca_babacan_+2cm.ply
# 420
# ../experimentation_scripts/data_samples/train/KONFOR_sila_cakmak.ply
# 421
# ../experimentation_scripts/data_samples/train/AKTIF_Defne_Kazanci.ply
# 422
# ../experimentation_scripts/data_samples/train/KALECAN_Beyza_Hatice_Ildir_KCO.ply
# 423
# ../experimentation_scripts/data_samples/train/2023-06-16_12-03-55_Fw__3D_Model_jana_Amir_6723.ply
# 424
# ../experimentation_scripts/data_samples/train/Elif Uzun KCOKALECAN.ply
# 425
# ../experimentation_scripts/data_samples/train/2023-10-06_09-49-49_Fw__3D_Model_ziad_11023__i_will_send_another_2_scans_for_him___i__donot_have_new_xray_yet___.ply
# 426
# ../experimentation_scripts/data_samples/train/ARTI_Ece_Imdat_+.ply
# 427
# ../experimentation_scripts/data_samples/train/2023-08-05_11-02-03_FW__Re__Nicole.ply
# 428
# ../experimentation_scripts/data_samples/train/MEHMET EMİN ÖZKAN.ply
# 429
# ../experimentation_scripts/data_samples/train/muge denktas.ply
# 430
# ../experimentation_scripts/data_samples/train/Sebnem Yenici.ply
# 431
# ../experimentation_scripts/data_samples/train/ANKARA_GAZI_NISANUR_ORHAN.ply
# 432
# ../experimentation_scripts/data_samples/train/2023-08-14_11-13-16_Fw__3D_Model_Rawan_Magdy_12823_from_Greece__her_2nd_brace___father_is__oncologist___full_service_by_you___proritty_fly_to_saudia_end_of_aug.ply
# 433
# ../experimentation_scripts/data_samples/train/2024-05-01_15-16-32_01_05_24.ply
# 434
# ../experimentation_scripts/data_samples/train/2024-03-09_13-57-09_Fw__Patient_Data_karma_walked__5324_.ply
# 435
# ../experimentation_scripts/data_samples/train/Zeynep Erva sercan.ply
# 436
# ../experimentation_scripts/data_samples/train/2024-01-27_11-09-21_Fwd__3D_Andressa_moura_Batista.ply
# 437
# ../experimentation_scripts/data_samples/train/ANKARA_GAZI_BADE_DENIZ.ply
# 438
# ../experimentation_scripts/data_samples/train/Rüyanur Özfırat.ply
# 439
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_54_Nisagul_Yalcin_(Aktif).ply
# 440
# ../experimentation_scripts/data_samples/train/2024-09-02_20-14-12_Fwd__Fw__Patient_Data_sara_Ahmed_Kena_9824.ply
# 441
# ../experimentation_scripts/data_samples/train/selim erol gurbuzKALECAN.ply
# 442
# ../experimentation_scripts/data_samples/train/talya ersagun-korseKALECAN.ply
# 443
# ../experimentation_scripts/data_samples/train/AKTIF__ayse_zehra_say.ply
# 444
# ../experimentation_scripts/data_samples/train/ARTI_masal_duymaz.ply
# 445
# ../experimentation_scripts/data_samples/train/2024-08-20_11-29-00_FW__Patient_Data.ply
# 446
# ../experimentation_scripts/data_samples/train/2024-09-11_13-32-44_FW__Patient_Data.ply
# 447
# ../experimentation_scripts/data_samples/train/FIZIMED_DOGA_GUNEN_(_AKTIF_).ply
# 448
# ../experimentation_scripts/data_samples/train/2024-07-08_10-27-11_Fwd__Patient_Data_Martina_Ortiz_Aguilera.ply
# 449
# ../experimentation_scripts/data_samples/train/mina azra inci.ply
# 450
# ../experimentation_scripts/data_samples/train/AKTIF_ELA_NUR_PAMUKCU.ply
# 451
# ../experimentation_scripts/data_samples/train/irem demir-korseKALECAN.ply
# 452
# ../experimentation_scripts/data_samples/train/2023-08-14_08-38-41_Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply
# 453
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_Humeyra_ciftci.ply
# 454
# ../experimentation_scripts/data_samples/train/AKTIF__ayse_nihal_yazili.ply
# 455
# ../experimentation_scripts/data_samples/train/KALECAN_dogukan_ata_2.ply
# 456
# ../experimentation_scripts/data_samples/train/FIZIMED_UTKU_RAFET_TAS_(_AKTIF_).ply
# 457
# ../experimentation_scripts/data_samples/train/saida Huseyinova.ply
# 458
# ../experimentation_scripts/data_samples/train/AKTIF__Acelya_Acar.ply
# 459
# ../experimentation_scripts/data_samples/train/şeyma yaşar 1.ply
# 460
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_30_Alperen_Adali_(Aktif).ply
# 461
# ../experimentation_scripts/data_samples/train/EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan_2.ply
# 462
# ../experimentation_scripts/data_samples/train/KALECAN_aylin_bayir-korse.ply
# 463
# ../experimentation_scripts/data_samples/train/ARTI_sumeyye_ecem_akay_(+).ply
# 464
# ../experimentation_scripts/data_samples/train/LIV_HOSPITAL_gulser_unlui.ply
# 465
# ../experimentation_scripts/data_samples/train/furkan sefer.ply
# 466
# ../experimentation_scripts/data_samples/train/irem dundar.ply
# 467
# ../experimentation_scripts/data_samples/train/KALECAN_Ceyda_Sare_Kaplan_100621.ply
# 468
# ../experimentation_scripts/data_samples/train/2023-07-13_12-48-18_Fw__3D_Model_Malak_samir_0823_charity___i_print_it_at_home___very__grateful_for__free_design_.ply
# 469
# ../experimentation_scripts/data_samples/train/2023-09-11_20-58-46_Fw__3D_Model_Joudi_moh_with_polls__7923___her_2nd_brace_with_us___no__period_.ply
# 470
# ../experimentation_scripts/data_samples/train/Nazli Belis Çavuş.ply
# 471
# ../experimentation_scripts/data_samples/train/KONFOR_muhammed_demlahi.ply
# 472
# ../experimentation_scripts/data_samples/train/Furkan Sarı KALECAN.ply
# 473
# ../experimentation_scripts/data_samples/train/2024-07-05_15-52-18_Fwd__Fw__Patient_Data_Nour_Maysara_1_____2724.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 474
# ../experimentation_scripts/data_samples/train/2023-05-12_10-34-17_this_is_hana_baha_file_2123_that_was_send_on_december_30_2022_.ply
# 475
# ../experimentation_scripts/data_samples/train/KALECAN_alina_sterkhova.ply
# 476
# ../experimentation_scripts/data_samples/train/2024-08-19_10-02-26_Pacient_Savine_data_s.ply
# 477
# ../experimentation_scripts/data_samples/train/2024-08-23_13-55-10_Fwd__Fw__Patient_Data_Farida_Katat_case_4824___she_had_2_braces__before_last_one_was_6823.ply
# 478
# ../experimentation_scripts/data_samples/train/2024-07-03_15-12-40_Patient_Data.ply
# 479
# ../experimentation_scripts/data_samples/train/2024-06-08_08-48-14_08_06_2024.ply
# 480
# ../experimentation_scripts/data_samples/train/FIZIMED_ELANUR_TOPCU_(_AKTIF_).ply
# 481
# ../experimentation_scripts/data_samples/train/kerem sekman.ply
# 482
# ../experimentation_scripts/data_samples/train/2024-08-24_16-33-37_Fwd__Fw__Patient_Data_Rital_Ibrahim_6824.ply
# 483
# ../experimentation_scripts/data_samples/train/FIZIMED_ELIF_OZBAY_(_AKTIF_).ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 484
# ../experimentation_scripts/data_samples/train/AKTIF_2021_-_47_Ahmet_Can_Kahraman_(Aktif).ply
# 485
# ../experimentation_scripts/data_samples/train/AKTIF_ela_nur_pamukcu_2.ply
# 486
# ../experimentation_scripts/data_samples/train/FIZIMED_INCI_DIKICI.ply
# 487
# ../experimentation_scripts/data_samples/train/FIZIMED_muhammed_emin_bicakci.ply
# 488
# ../experimentation_scripts/data_samples/train/KALECAN_Ceren_Akinci_KCO_051021.ply
# 489
# ../experimentation_scripts/data_samples/train/2023-06-02_10-00-20_Fw__3D_Model_kisha_Nadine_1723_.ply
# 490
# ../experimentation_scripts/data_samples/train/AKTIF_yagmur cekic.ply
# 491
# ../experimentation_scripts/data_samples/train/KONFOR_Maria_konfor.ply
# 492
# ../experimentation_scripts/data_samples/train/AKTIF_Duru_Eda_Morgil.ply
# 493
# ../experimentation_scripts/data_samples/train/2023-08-14_11-50-24_Fw__3D_Model_Malk_Saadi_13823___print_in_USA_.ply
# 494
# ../experimentation_scripts/data_samples/train/2023-12-04_13-34-05_Fw__Patient_Data_engy_bassam__12123____pls_design_only__today_or__tomorrow___thx_.ply
# 495
# ../experimentation_scripts/data_samples/train/serra aysel-korseKALECAN.ply
# 496
# ../experimentation_scripts/data_samples/train/nisa sert.ply
# 497
# ../experimentation_scripts/data_samples/train/ECE_ORTOPEDI_KONYA_Yusa_Ozdemir.ply
# 498
# ../experimentation_scripts/data_samples/train/kerem çeliker-korseKALECAN.ply
# 499
# ../experimentation_scripts/data_samples/train/FIZIMED_CEVHER_FIRAT_(_AKTIF_).ply
# 500
# ../experimentation_scripts/data_samples/train/2024-09-09_05-30-23_FW__Patient_Data-_Gaya.ply
# 501
# ../experimentation_scripts/data_samples/train/2021 - 32 Ömer Albayrak (Aktif).ply
# 502
# ../experimentation_scripts/data_samples/train/2024-06-11_14-12-03_Possibly_K5__please_check_rotation.ply
# 503
# ../experimentation_scripts/data_samples/train/2024-08-31_07-49-09_Fwd__Fw__Patient_Data_mariam_George___8824.ply
# 504
# ../experimentation_scripts/data_samples/train/KALECAN_DURU_YAHCI-KORSE.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 505
# ../experimentation_scripts/data_samples/train/AKTIF_Eslem_Horuz.ply
# 506
# ../experimentation_scripts/data_samples/train/Peral akcalı.ply
# 507
# ../experimentation_scripts/data_samples/train/2024-08-23_14-00-38_Fwd__Fw__Patient_Data_Jana_Abd_El_Ghany_1_case___3824_she_had_a_brace__before___3124.ply
# 508
# ../experimentation_scripts/data_samples/train/İrem Hilal Barucu.ply
# 509
# ../experimentation_scripts/data_samples/train/AKTIF_erva_agiralioglu.ply
# 510
# ../experimentation_scripts/data_samples/train/KONFOR_ali_yusuf.ply
# 511
# ../experimentation_scripts/data_samples/train/2024-04-30_09-56-39_Patient_Data_Maysa_B_de_Oliveira.ply
# 512
# ../experimentation_scripts/data_samples/train/2023-07-13_13-24-24_Fw__3D_Model_gana_tamer__3823__full_service_.ply
# 513
# ../experimentation_scripts/data_samples/train/FIZIMED_INCI_SU_KALDIRIM_(_AKTIF_).ply
# 514
# ../experimentation_scripts/data_samples/train/2023-07-13_12-44-10_Fw__3D_Model_Mona_Ashraf__1823___just_design_pls___we_do_fitting_.ply
# 515

# %%
# features[17] = (features[17][0], np.nan_to_num(features[17][1]))

# %%
features[293][1]
# Out:
# array([[ 0.92169089, -0.18970858,  0.33837339],
#        [ 0.91654831, -0.26474387,  0.29974968],
#        [ 0.9972228 , -0.02924626, -0.06849336],
#        ...,
#        [-0.36513398, -0.29573545,  0.8827331 ],
#        [-0.18337747, -0.39080699,  0.9020214 ],
#        [-0.0984984 , -0.87036112,  0.48246201]], shape=(340, 3))

# %%
print(len(features[100][1]))
# Out:
# 340

# %%
print(features[0][0])
# Out:
# ARTI_ali_riza_ersin_(+).ply

# %%
# iterate over features and count how many features[i][1][j] == [0, 0, 1]
# also change the order for example horizantal slice 1 should be numbered from 0 to 19 not
# 0 to 9 and 170 to 179 for the first horizantal slice
# order matters

# also try different origin points for rotation (now you are using the center of each horizontal slice)
# altrenative is to have the center of the whole back slice and the center of the whole front slice as the plane origin this way all vertical slices will be rotated around the same point (it would be [avg x, avg y, avg z] of the back slice for back and [avg x, avg y, avg z] of the front slice for front)

# it is like a rod crossing the entire mesh

# another is to have one that is the center of the entire mesh and use it for both back and front slices

# %%
counter = 0
total = 0
for i in range(len(features)):
    for j in range(len(features[i][1])):
        if np.array_equal(features[i][1][j], np.array([0, 0, 1])) or np.array_equal(features[i][1][j], np.array([0, 0, -1])):
            # print(f"features[{i}][1][{j}] == [0, 0, 1]")
            # features[i][1][j] = np.array([0, 0, -1])
            # print(f"features[{i}][1][{j}] == [0, 0, -1]")
            counter += 1
        else:
            total += 1
print(counter)
print(total)
percentage = counter / (counter + total) * 100
print(percentage)
# Out:
# 146
# 174274
# 0.08370599701869051

# %%
meshPathes
# Out:
# ['ARTI_ali_riza_ersin_(+).ply',
#  '2024-09-16_14-55-22_回复__visit_to_Germany.ply',
#  'ARTI_Sebnem_Ela_Cengizhan_(+).ply',
#  'AKTIF__azra_duru_yildiz.ply',
#  '2024-07-05_18-59-35_Fwd__Fw__Patient_Data_ziad_Kareem_3_case_5724.ply',
#  '2024-09-20_16-42-31_Fwd__Fw__Patient_Data_Maria_charity_1924.ply',
#  'ilkim cemal kara 140921KALECAN.ply',
#  'ARTI_yigit_ali_boz_2_(+).ply',
#  'KALECAN_ecrin_ada_sener-_korse.ply',
#  'ARTI_ayse_beren_nebil.ply',
#  '2023-10-06_10-11-52_Fw__3D_Model_Jana_sherif_21023__her_2nd_brace___no_new_xray_yet_.ply',
#  'FIZIMED_ZEYNEP_BAHSI_(_AKTIF_).ply',
#  '2024-01-18_18-28-46_Patient_Data.ply',
#  '2024-09-13_10-55-45_Patient_Data_Estela_Soares.ply',
#  'FIZIMED_AHMET_KAYA_(_AKTIF_).ply',
#  'KALECAN_defne_bekar.ply',
#  'KALECAN_asya_guven.ply',
#  'KALECAN_deniz_sukruogullari-korse.ply',
#  'ozgu ergin.ply',
#  'ARTI_Eylul_Acar.ply',
#  'LIV_HOSPITAL_Elif_Irem_Sercin.ply',
#  'AKTIF_deniz_kiran.ply',
#  'Tugba Naz Korkmaz 3.ply',
#  'ARTI_sila_dogan.ply',
#  'FIZIMED_FURKAN_OZDEN_(_AKTIF_).ply',
#  '2024-05-15_10-24-54_14_05_24.ply',
#  'ARTI_Harun_gungeldi_Arti_PO.ply',
#  '2024-01-13_01-57-49_Fw__Patient_Data_Mirna_Abd_el_Ghany_4124.ply',
#  'AKTIF_2021_-_59_Beyza_Sevimli_(Aktif).ply',
#  '2023-08-25_11-28-30_Fw__3D_Model_Hana_tamer_2923__design_and_fitting_.ply',
#  '2023-10-06_11-28-48_Fw__3D_Model__Juli_nashed_51023___we_revise_orthomedix_brace_._.ply',
#  '2023-09-08_13-29-53_Fw__3D_Model_salma_Salah_6923.ply',
#  '2021 - 21 Pelinsu Özkan (Aktif).ply',
#  'AKTIF__Alya_Akalin.ply',
#  'KALECAN_Ali_Ihsan_Ayanlar_KCO.ply',
#  'LIV_HOSPITAL_Ilke_Deren_Zafer.ply',
#  '2023-07-24_12-44-30_Fw__3D_Model_Omar_Hatem_7823_full_service_.ply',
#  'KALECAN_ECRIN_PANCAROGLU.ply',
#  'mert altınay.ply',
#  'murathan ateş.ply',
#  '2023-10-06_10-34-28_Fw__3D_Model_Clara__01023__free_revision_.ply',
#  'KALECAN_basak_ela_ceyani-korse.ply',
#  'KONFOR_sila_elmas.ply',
#  '2024-08-29_08-29-13_New_patient._.ply',
#  'ARTI_Sude_Kara.ply',
#  'KALECAN_batuhan_okan.ply',
#  '2024-05-25_13-55-46_25_05_24-3.ply',
#  'EGEM_DENIZLI_hilkmet_can_kaya.ply',
#  'KONFOR_Sema_nur_Gultekin.ply',
#  '2024-03-01_13-48-01_Fw__Patient_Data_Lana_3324.ply',
#  'KALECAN_Asel_Yildirim.ply',
#  '2024-08-23_13-54-34_Fwd__Fw__Patient_Data_Malak_Mohamed_1824.ply',
#  'ARTI_sila_dogru.ply',
#  'ECE_ORTOPEDI_KONYA_Enes_Doruk_ECE.ply',
#  'LIV_HOSPITAL_ela_yuksel.ply',
#  'CEYLAN_Tuana_Gursoy_(ceylan).ply',
#  'Yusuf Yanmaz.ply',
#  '2024-01-20_11-02-56_Fw__Patient_Data_Mohamed_Fareed_2.ply',
#  'Zeynep Naz Pınar KlinikSport.ply',
#  'mustafa koc.ply',
#  'KALECAN_dide_gazel_abakay.ply',
#  'irem su dikmenKALECAN.ply',
#  'FIZIMED_ELIZ_OZDOGAN.ply',
#  'KALECAN_asel_kucukcoban.ply',
#  'ECE_ORTOPEDI_KONYA_Ahmet_Talha_Saracoglu_ECE.ply',
#  'tugce birinci2.ply',
#  'CEYLAN_aysegul_toker.ply',
#  'zeynep ilhan.ply',
#  '2024-03-19_09-40-42_Patient_Data_Vitor_Romagnoli_Alves._March_19_24.ply',
#  'AKTIF_emir_ay.ply',
#  '2023-06-16_11-06-59_Fw__3D_Model_Mariam_Qatar__the_right_scan_4723.ply',
#  'Melisa Nur Acar kalecan.ply',
#  '2024-03-31_12-49-50_Fw__Patient_Data_adam_Karim_5424.ply',
#  '2024-06-07_13-48-24_Another_measurement.ply',
#  'ECE_ORTOPEDI_KONYA_Eymen_Talip_Taskin.ply',
#  'LIV_HOSPITAL_Ilke_Cemre_Kilincarslan.ply',
#  'FIZIMED_ECEM_SU_KUNT_(_AKTIF_).ply',
#  'Furkan Keleş.ply',
#  '2023-08-14_08-32-16_Fw__3D_Model_Reem_Ibrahim_9823_.ply',
#  '2024-05-25_13-49-15_25_05_24-2.ply',
#  '2023-11-16_10-54-45_Fw__3D_Model_haad_Libya__31123_.ply',
#  'nil yuruk.ply',
#  '2023-08-14_09-07-25_Fw__3D_Model_karma_Assam_11823_full_service_by_eric_.ply',
#  'AKTIF__can_efe_baki.ply',
#  '2023-04-09_15-52-41_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply',
#  'LIV_HOSPITAL_Irem_Temizel.ply',
#  'DIYAMER_Yigitcan_Caglar.ply',
#  '2024-05-06_10-48-52_Patient_Data_isis_Castanheira.ply',
#  '2023-11-26_09-23-30_Re__3D_Model_colored_again___51123.ply',
#  'AKTIF_2021_-_13_Defne_Kaya_(Aktif).ply',
#  'gözde nur maraşlı.ply',
#  'AKTIF_eylul_deniz_kadas.ply',
#  'Realeboha Kevin Kao.ply',
#  'FIZIMED_EGE_OZKAYA_(_AKTIF_).ply',
#  'AKTIF_elif_guler.ply',
#  '2024-03-13_01-18-59_Fw__Patient_Data_Rosetta_6324.ply',
#  'FIZIMED_KEMAL_YIGIT_TORER_(_AKTIF_).ply',
#  '2024-08-07_15-17-01_Patient_Data_Raphael_Rodrigues.ply',
#  'ARTIrabia gursoy.ply',
#  'halim durnaKALECAN.ply',
#  'tugbanaz Korkmaz.ply',
#  '2024-02-02_06-48-33_Fw__moaz_1224.ply',
#  'FIZIMED_EMRE_SARP_ZEYTINOGLU_2.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_cem_kayman.ply',
#  'Sude Durmaz (Aynur).ply',
#  '2023-08-25_11-13-10_Fw__3D_Model_febronia_1st_polls_1923__just_G_code__pls____fitting_and__print_will_be_done_locally___charity_.ply',
#  'ömer hamza lafcı.ply',
#  'ARTI_beyza_isil_yildirim_+.ply',
#  'kerem celik.ply',
#  'mikail acar.ply',
#  'zumra sancaktepe.ply',
#  'FIZIMED_TUANA_KENDIRCI_(_AKTIF_).ply',
#  'yasemin kıvrak.ply',
#  'AKTIF_elif_duru_zengin.ply',
#  'CEYLAN_berrak_ozturk.ply',
#  '2023-12-18_10-55-26_Maria_Fernanda_new_Brace.ply',
#  'AKTIF_ecenur_tuysuz.ply',
#  '2024-09-22_19-24-35_Fwd__Fw__Patient_Data_Martina_4924___pls_read_my_notes_first.ply',
#  '2023-08-09_14-36-59_Patient_Iasmin_Stucki.ply',
#  'AKTIF_elif_korkmaz.ply',
#  'FIZIMED_AYSENAZ_BALABAN_(_AKTIF_).ply',
#  'AKTIF__Belinay_Keskin.ply',
#  '2024-07-05_14-34-36_Fwd__Fw__Patient_Data_Omar_zakarya_1_case_1724___will_do_new_xray.ply',
#  'AKTIF__buglem_karaca.ply',
#  'LIV_HOSPITAL_Victoria_Blatskaya.ply',
#  'AKTIF_2021_-_10_Alp_Doganer_(Aktif).ply',
#  'Omer faruk Yanas.ply',
#  '2024-02-04_19-52-34_Fw__Patient_Data_karas_Tamer_2224_.ply',
#  'CITAY_IZMIR_A_R_D_KORSE.ply',
#  '2023-05-12_10-32-48_Fw__3D_Model_Hana_bahaa_revison__2523.ply',
#  'FIZIMED_NISA_TUANA_YUMRUTAS_(_AKTIF_).ply',
#  'ARTI_hatice_eceylan_+05_04_2022.ply',
#  '2023-10-29_21-37-27_Fw__3D_Model_firial__11123_pls_print_in_USA_.ply',
#  'CITAY_IZMIR_so_citay.ply',
#  'esin ünlü kalecan.ply',
#  'lara ada bıldır.ply',
#  'LIV_HOSPITAL_Ayben_Armina_Temel.ply',
#  'AKTIF__asmin_cetin.ply',
#  'KALECAN_ayse_barut_14-05-22.ply',
#  '2024-08-03_12-33-49_New_Scans_and_order._.ply',
#  '2024-06-11_13-40-00_FW__Patient_Data_.ply',
#  '2023-05-12_10-45-30_Fw__3D_Model_basmala_walid_3523.ply',
#  'LIV_HOSPITAL_zeren_boz.ply',
#  'FIZIMED_FATMA_MOLLA_(_AKTIF_).ply',
#  '2024-06-12_09-42-53_Fwd__Patient_Data_Giovana_Dantas.ply',
#  'KALECAN_adem_unal.ply',
#  'fatma zumra aydın.ply',
#  '2024-05-22_09-24-28_Fwd__Patient_Data.ply',
#  'AKTIF_Elif_Guler_2.ply',
#  '2024-05-25_09-53-09_New_Scan_.ply',
#  'nil yürük 3.ply',
#  'AKTIF__Buse_Goksel.ply',
#  'AKTIF__alara_hizlan.ply',
#  'saliha zeynep akdemir.ply',
#  'Yasemin Guney.ply',
#  'AKTIF__Berra_Tilaver.ply',
#  'AKTIF__ada_onur.ply',
#  'Hicran Durak.ply',
#  '2023-10-06_10-15-34_Fw__3D_Model_farida_sedky_31023__i_donot_need_Menna_to_be_in_the_room__or_get_close_to_her_mom___fitting_by_y_and_mariam__thx__.ply',
#  'KONFOR_Meyz_Al_Ali.ply',
#  'KALECAN_celal_cinar_coksoy.ply',
#  'ARTI_tuncer_erdogan.ply',
#  '2024-03-25_10-10-40_Fwd__Patient_Data_Lays_.ply',
#  'reyyan komurcuKALECAN.ply',
#  'AKTIF__Alp_Ceyhan.ply',
#  '2024-09-04_09-32-55_Fwd__Patient_Data.ply',
#  'Elif Sümeyye Gül.ply',
#  'KALECAN_defne_yaliguluhep.ply',
#  'ARTI_irem_badurlar_(+).ply',
#  'LIV_HOSPITAL_derya_arbabham.ply',
#  'AKTIF_ecrin_nil_yavuzaslan.ply',
#  'LIV_HOSPITAL_Lutfu_ege_bodur.ply',
#  'AKTIF_evrim_yilmaz.ply',
#  'melek çakırKALECAN.ply',
#  'AKTIF__Aylin_guliyeva23.ply',
#  'tufan emre aydın2.ply',
#  'AKTIF__Ada_Serindere.ply',
#  'Ezgi karatepe.ply',
#  '2024-04-10_08-58-29_Clara_s_data.ply',
#  'KALECAN_DERIN_KAPLAN-KCO.ply',
#  'tanem harputluKALECAN.ply',
#  'AKTIF__berfin_gunduz.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan.ply',
#  'ANKA_DUZCE_merve_nur_tureli.ply',
#  'ARTI_ela_kilic.ply',
#  'Sura Soyak 05042022.ply',
#  'ARTI_Irem_macit.ply',
#  'sevval nuran cavdar.ply',
#  'meryem zehra demir.ply',
#  'KALECAN_beray_tokatlioglu.ply',
#  '2024-06-08_14-08-00_Fwd__Fw__Patient_Data_Ziad_2_3624.ply',
#  'AKTIF__aysegul_benek.ply',
#  '2023-08-08_09-33-25_Fw__3D_Model_omar_moataz_8823_design_and_fitting_by_eric__print_in__usa___son_of_special_force_.ply',
#  'FIZIMED_ELIZ_OZDOGAN_(_AKTIF_).ply',
#  'FIZIMED_AZRA_SEKER_fizimed.ply',
#  'ARTI_tugba_nur_coban.ply',
#  'ARTI_cafer_ali_yesiltas_arti.ply',
#  'ARTI_tuana_deniz_(arti).ply',
#  '2024-06-05_18-02-55_John_Tunney_patients.ply',
#  '2024-05-01_06-29-16_Patient_File_-_ACMC1.ply',
#  'FIZIMED_DICLENAZ_ISBILEN_(_AKTIF_).ply',
#  'ilayda saygı.ply',
#  'fatma genç-korseKALECAN.ply',
#  'AKTIF_ceylin_ece_tektas.ply',
#  '2024-03-13_11-20-50_Patient_Data_Malásia_.ply',
#  'AKTIF__aylin_guliyeva.ply',
#  '2024-03-27_14-14-06_Fw__Patient_Data_Malak_saada__2424___her_2nd_brace_in_7_month_____her__old_file___13823__.ply',
#  'Ömer Hamza Lafcı 2.ply',
#  '2023-11-16_14-14-44_Fw__3D_Model_nahed_el_Amir__41123_design_only___look_at_y_notes_.ply',
#  'nevanur govec.ply',
#  '2024-03-27_15-08-44_Fwd__Luana_Cavalca_27_3_2024.ply',
#  'Çağlar Günerkaya KCO_KALECAN.ply',
#  'AKTIF__ahsen_ismetogullari.ply',
#  'zeynep saliha akdemir.ply',
#  'metehan er.ply',
#  'Pelin Kurtulus.ply',
#  'mirac kockaya.ply',
#  'inci defne yunlu.ply',
#  'ARTI_tugba_nur_acar_+.ply',
#  '2024-01-13_14-23-31_Re__Patient_DataTouline_1____6124.ply',
#  'Toprak su demir.ply',
#  'ARTI_ahmet_hosgor_(+).ply',
#  '2023-08-30_18-51-11_Fw__3D_Masoud_with_poles_5923__his_2nd_brace______pervious_brace_was__from_Greece___pls__design_and_fitting_only.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_ahmet_ahlat.ply',
#  'AKTIF_AZRA VARDAR.ply',
#  'ECE_ORTOPEDI_KONYA_Kezban_Irem_Icoz.ply',
#  '2024-05-30_16-47-40_Fwd__Patient_Data.ply',
#  'AKTIF__arda_gul_2.ply',
#  'AKTIF_eren_hicyilmaz.ply',
#  'DENIZ_OKE_Irem_Kose.ply',
#  'KONFOR_Alperen__Karaca_konfor.ply',
#  'LUXMED_Defne_Dagistanli_luxmed.ply',
#  '2024-04-10_07-51-07_Camila_s_data.ply',
#  '2023-10-06_11-25-01_Fw__3D_Model_menna_husky_41023___her_2nd_brace_.ply',
#  'AKTIF_Derya_Deniz_Varol.ply',
#  'AKTIF_2021_-_40_Selen_Baydar_(Aktif).ply',
#  'ARTI_meyranur_karagoz.ply',
#  'mikail acar 2.ply',
#  'AKTIF_ELIF_TUANA_SAVCI.ply',
#  'AKTIF__arya_fakirzade.ply',
#  '2023-08-14_12-02-55_Fwd__Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply',
#  'AKTIF_2021_-_51_Hiranur_Sekban_(Aktif).ply',
#  'ezgi nur aydemir.ply',
#  '2024-08-01_10-11-30_Fwd__Patient_Data_Felipe_4.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_Defne_Enli.ply',
#  'AKTIF__cagla_bade_kiyak_2.ply',
#  'rumeysa gocmen.ply',
#  'AKTIF__Beril_Yilmazer.ply',
#  'AKTIF_durudeniz_turan_2.ply',
#  'eylül kutu KCO 041021KALECAN.ply',
#  'sinem ünlüerKALECAN.ply',
#  'LIV_HOSPITAL_Dersim_Toptas.ply',
#  'EGEM_DENIZLI_Mustafa_Elvan_egem.ply',
#  'AKTIF_ege_elibol.ply',
#  'ırmak tuğla.ply',
#  'ARTI_emircan_tursun_(+).ply',
#  'Ada Çalışkan ksKLINIKSPORT.ply',
#  'AKTIF_esma_bahtiyar.ply',
#  '2024-01-13_01-56-38_Fw__Patient_Data_Jana_Abd_El_Ghany_3124.ply',
#  'AKTIF_2021_-_18_Azra_Yigitoglu_(Aktif).ply',
#  '2024-03-15_12-54-25_150324.ply',
#  'melisa nur acar 2KALECAN.ply',
#  'Kaan Kubilay Çetinkaya.ply',
#  '2024-03-24_08-35-01_Fw_mariam_Fouad_1424.ply',
#  '2024-06-05_11-36-36_Fwd__Patient_Data_Misha_24.ply',
#  'KALECAN_avsin_somer-korse.ply',
#  'FIZIMED_DOGA_CIVELEK_(_fizimed_).ply',
#  'sevval nur guzeltepe.ply',
#  'AKTIF__Beren_Bay.ply',
#  'Ilgar Güzel 240921KALECAN.ply',
#  '2024-07-08_12-10-30_Fwd__Fw__Patient_Data_omar_Motaz_6724___his_2nd_brace.ply',
#  'ECE_ORTOPEDI_KONYA_Sedef_OzCelik_ECE.ply',
#  'İclal Rukiye Karaca.ply',
#  'İsik Sezer Saridede.ply',
#  'KONFOR_lemar_alheyek.ply',
#  'Miraz Nisa Nakci.ply',
#  'LIV_HOSPITAL_Ela_Yuksel_2.ply',
#  'LIV_HOSPITAL_Tuana_Celik.ply',
#  'tuğba naz korkmaz 2.ply',
#  '2023-08-25_11-38-13_Fw__3D_Model_nouran__4923_design_and_fitting___her_2nd_brace_in_8__month___dad_is_cardio_in_UK_.ply',
#  'KARTAL YİLMAZKALECAN.ply',
#  'TALA ABUGAHALİ.ply',
#  'AKTIF_2021_-_23_Halim_Burak_Nilifikra_(Aktif).ply',
#  'AKTIF__Ayse_Melis_Yalcin.ply',
#  'ARTI_vedat_daglik_(+).ply',
#  'FIZIMED_NEHIR_DURU_CELIK_(AKTIF_).ply',
#  'AKTIF__Azra_Karacaoglu.ply',
#  'FIZIMED_ECE_GULERSEN_(_AKTIF_).ply',
#  'ARTI_Busra_Karaca_+.ply',
#  'AKTIF_Elif_Korkmaz_04-23.ply',
#  '2024-09-22_18-59-51_Fwd__Fw__Patient_Data_Malak_bashir_3924.ply',
#  '2023-06-22_12-38-29_Fw__3D_Model_Maya_9723__her_3rd_brace_in_2_years____are_y_S3_.ply',
#  '2024-05-09_12-52-03_SA0905.ply',
#  '2023-12-04_22-12-18_Fw__Patient_Data_Noha_21223__design_pls____p.ply',
#  'AKTIF_Elif_Eylul_Demir.ply',
#  'AKTIF_elif_naz_keles.ply',
#  'AKTIF_can_seker.ply',
#  'FIZIMED_ATILLA_ALLAHVERDI_(_AKTIF_).ply',
#  'UMUT_azranur_yetim.ply',
#  'Sadık Bilal Son 090621KALECAN.ply',
#  'AKTIF__Alya_Doga_senlik.ply',
#  'AKTIF__ahmet_erdem.ply',
#  '2024-08-24_11-30-01_FW__Patient_Data.ply',
#  'çağla bade kıyak.ply',
#  'AKTIF_Dila_Zeynep_Bayat.ply',
#  '2024-05-27_10-11-43_Fwd__Fw__Patient_Data_Silvia_1624.ply',
#  'FIZIMED_ECRIN_CAPACI_(_AKTIF_).ply',
#  'AKTIF__Alya_Dua_Senlik_2.ply',
#  '2024-06-15_08-44-25_Fwd__Fw__Patient_Data_Jana_Mohamed_4624.ply',
#  'ARTI_yigit_ali_boz.ply',
#  '2024-09-15_13-33-28_Fwd__Fw__Patient_Data_Noor_10824.ply',
#  'Hatice Duman.ply',
#  'AKTIF__beyza_atak.ply',
#  'CIGDEM_DR_Arda_Yalcindag.ply',
#  'AKTIF_2021_-_48_Ilyas_Kadir_Saribas_(Aktif).ply',
#  'AKTIF_2021_-_39_Kemal_Efe_Alakavuk_(Aktif).ply',
#  'CEYLAN_sude_gul_guvenc.ply',
#  'EGEM_DENIZLI_nehir_acar.ply',
#  '2023-08-06_12-54-34_Fwd__Fw__3D_Model_jumana_aish_4823___full_service.ply',
#  'AKTIF_elif_guler3.ply',
#  'Eda Ozturk KALECAN.ply',
#  'şura soyak.ply',
#  'AKTIF_Ebrar_Kazan.ply',
#  'SIFA_ORTOPEDI_D_BAKIR.ply',
#  'ayse zehra say 3.ply',
#  '2024-07-25_14-52-35_Fwd__Patient_Data_Olívia_Rocha_2.ply',
#  'Yağmur Sena Çalışkan.ply',
#  'AKTIF__Can_Seker_2.ply',
#  'Melis Kargaci.ply',
#  'kartal yìlmaz-korseKALECAN.ply',
#  'AKTIF_ceylin_arslan.ply',
#  'AKTIF_Duru_Deniz_Turan.ply',
#  '2023-09-13_11-33-13_Re__3D_Model_sajda_3923_design_and_fitting_.ply',
#  '2023-11-25_13-52-28_Fwd__Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much.ply',
#  'jouman elsalti.ply',
#  'KALECAN_ayse_azra_temiz.ply',
#  'sinem topcu.ply',
#  'AKTIF_elif_nisa_celebi.ply',
#  'fatma alhac avad.ply',
#  'AKTIF_defne_sisli.ply',
#  'ARTI_kivanc_yasar_(+).ply',
#  'tufan emre aydin.ply',
#  'EGEM_DENIZLI_Safiye_Berra_Sirinal.ply',
#  'KALECAN_azra_aydin.ply',
#  '2024-07-31_11-00-51_Fwd__Patient_Data_Gabriel.ply',
#  '2024-08-23_13-59-22_Fwd__Fw__Patient_Data_Login_Ihab_case_5824.ply',
#  'melisa nur acar-korseKALECAN.ply',
#  'AKTIF__arda_gul.ply',
#  'ARTI_Ecrin_Cagan.ply',
#  'AKTIF_2021_-_6_Arda_Darici(Aktif).ply',
#  '2024-05-27_10-11-25_Fwd__Fw__Patient_Data_engy_melad_2624.ply',
#  '2024-06-05_11-50-56_Fwd__Beatriz_Savegnago_Ganzala_4_6_2024.ply',
#  'Nisanur Salman.ply',
#  '2023-07-13_18-56-27_Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much_.ply',
#  'AKTIF__Alp_Doganer.ply',
#  'CEYLAN_uveys_sevim.ply',
#  '2024-01-20_11-06-02_Fw__Patient_Data_Mohamed_Fareed_with_images_from_old_brace_.ply',
#  '2024-05-01_15-20-12_01_05_24-3rd_Scan.ply',
#  'nil yürük 2.ply',
#  'FIZIMED_EMRE_SARP_ZEYTINOGLU_(_AKTIF_).ply',
#  'FIZIMED_Ela_Mollavelioglu_FIZIMED.ply',
#  '2024-04-08_01-42-27_Fw__Patient_Data_yousef_3_____7424__design_only____fitting_by_me_.ply',
#  'AKTIF__aydan_yagmur_kose.ply',
#  'KALECAN_batuhan_kasap.ply',
#  '2023-11-25_13-46-11_Fwd__Fw__3D_Model_kisha_Nadine.ply',
#  '2024-01-07_13-18-49_Fw__3D_Model_yehia_2nd_scan___2124.ply',
#  'AKTIF__Ada_Nil_Cekem_082021.ply',
#  'nevanur govec 2.ply',
#  'ANKARA_GAZI_ELIF_TUANA_SAVCI.ply',
#  '2024-02-28_12-48-34_Re__Patient_Data_hanin_Sameh_1324.ply',
#  '2023-10-06_11-34-09_Fw__3D_Model_haya_morsi_001023_revison_.ply',
#  'hatice ceylin doğan.ply',
#  '2024-05-09_09-39-28_Data_patient_Esther.ply',
#  '2024-07-01_09-52-11_Patient_Data_Heloísa_Goncalves.ply',
#  'FIZIMED_SEZIN_IDER_(_AKTIF_).ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_Arda_Cihan.ply',
#  '2024-03-01_10-27-03_Fw__Patient_Data_hafsa__2324_.ply',
#  'AKTIF_AZRA_VARDAR_2.ply',
#  'Hatice Betül Bağcı.ply',
#  '2023-05-12_11-25-01_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply',
#  'FIZIMED_ZEYNEP_AKDENIZ_(_AKTIF_).ply',
#  '2024-03-31_12-43-00_Fw__Patient_Data_Arwa_Ahmed__3424.ply',
#  '2023-06-17_01-22-25_Fw__3D_Model_Clara_John_7723.ply',
#  'Muhammed Ali tekinerKALECAN.ply',
#  'pakize Akkurt.ply',
#  '2023-06-25_19-00-59_Fw__3D_Model_Mariam_Romany_10723__she_will__do_new_xray_this_week_.ply',
#  'tugce birinci.ply',
#  'AKTIF_elif_korkmaz_2.ply',
#  '2024-07-05_15-51-08_Fwd__Fw__Patient_Data_Mariam_Ahmed_3724.ply',
#  'ARTI_naz_yagmur_ustuncan.ply',
#  'AKTIF_eren_aktas.ply',
#  'leyla gunes.ply',
#  '2024-09-22_19-00-33_Fwd__Fw__Patient_Data_Adam_2924.ply',
#  'AKTIF__Arda_Deniz_Oda.ply',
#  'ANKARA_GAZI_MAHMUT_ESAT_HARACA.ply',
#  'AKTIF__Ahsen_Aykac.ply',
#  '2024-03-31_12-47-04_Fw__Patient_Data_1__Dan_Haytham_4424__her_4th_brace_.ply',
#  'Nehir Murat 2.ply',
#  'Nazlı Nehir Kaymakcilar.ply',
#  '2024-06-20_10-13-09_Fwd__Patient_Data_Isabela_Mihitarian.ply',
#  'ARTI_Defne_Aygun.ply',
#  '2024-07-05_15-24-55_Fwd__Maria_Eduarda_Rohde_de_Oliveira_5_07_2024.ply',
#  'Eymen yılmaz.ply',
#  '2024-06-21_10-57-26_Fwd__Fw__Patient_Data_Ibrahim_Mohamed_2___5624.ply',
#  'FIZIMED_ALI_BURAK_KARACASOY_(_AKTIF_).ply',
#  'karan aleviKALECAN.ply',
#  'LIV_HOSPITAL_Alara_Hizlan_2.ply',
#  '2023-07-13_13-59-58_Fw__3D_Model_jumana_aish_4823___full_service_.ply',
#  '2024-09-30_13-16-09_Fwd__Fw__Patient_Data_jouly_Maged_5924.ply',
#  'AKTIF_2021_-_17_Elif_Naz_Yildiz_(Aktif).ply',
#  'LIV_HOSPITAL_Zeynep_Saliha_Akdemir2.ply',
#  'AKTIF_Deniz_Cavus.ply',
#  '2023-06-17_01-26-13_Fw__3D_Model_joudi_emad_8723__pls_cheack_the_quality_of_xray_.ply',
#  '2024-08-23_13-54-54_Fwd__Fw__Patient_Data_Malak_Rabee_1_case___2824.ply',
#  '2024-10-02_09-56-42_John_Tunney_call.ply',
#  'hande turan.ply',
#  '2024-03-09_13-53-46_Fw__Patient_Data_basmala_essam_4324_another_charity.ply',
#  'AKTIF__beyca_babacan_+2cm.ply',
#  'KONFOR_sila_cakmak.ply',
#  'AKTIF_Defne_Kazanci.ply',
#  'KALECAN_Beyza_Hatice_Ildir_KCO.ply',
#  '2023-06-16_12-03-55_Fw__3D_Model_jana_Amir_6723.ply',
#  'Elif Uzun KCOKALECAN.ply',
#  '2023-10-06_09-49-49_Fw__3D_Model_ziad_11023__i_will_send_another_2_scans_for_him___i__donot_have_new_xray_yet___.ply',
#  'ARTI_Ece_Imdat_+.ply',
#  '2023-08-05_11-02-03_FW__Re__Nicole.ply',
#  'MEHMET EMİN ÖZKAN.ply',
#  'muge denktas.ply',
#  'Sebnem Yenici.ply',
#  'ANKARA_GAZI_NISANUR_ORHAN.ply',
#  '2023-08-14_11-13-16_Fw__3D_Model_Rawan_Magdy_12823_from_Greece__her_2nd_brace___father_is__oncologist___full_service_by_you___proritty_fly_to_saudia_end_of_aug.ply',
#  '2024-05-01_15-16-32_01_05_24.ply',
#  '2024-03-09_13-57-09_Fw__Patient_Data_karma_walked__5324_.ply',
#  'Zeynep Erva sercan.ply',
#  '2024-01-27_11-09-21_Fwd__3D_Andressa_moura_Batista.ply',
#  'ANKARA_GAZI_BADE_DENIZ.ply',
#  'Rüyanur Özfırat.ply',
#  'AKTIF_2021_-_54_Nisagul_Yalcin_(Aktif).ply',
#  '2024-09-02_20-14-12_Fwd__Fw__Patient_Data_sara_Ahmed_Kena_9824.ply',
#  'selim erol gurbuzKALECAN.ply',
#  'talya ersagun-korseKALECAN.ply',
#  'AKTIF__ayse_zehra_say.ply',
#  'ARTI_masal_duymaz.ply',
#  '2024-08-20_11-29-00_FW__Patient_Data.ply',
#  '2024-09-11_13-32-44_FW__Patient_Data.ply',
#  'FIZIMED_DOGA_GUNEN_(_AKTIF_).ply',
#  '2024-07-08_10-27-11_Fwd__Patient_Data_Martina_Ortiz_Aguilera.ply',
#  'mina azra inci.ply',
#  'AKTIF_ELA_NUR_PAMUKCU.ply',
#  'irem demir-korseKALECAN.ply',
#  '2023-08-14_08-38-41_Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply',
#  'EGEM_DENIZLI_Humeyra_ciftci.ply',
#  'AKTIF__ayse_nihal_yazili.ply',
#  'KALECAN_dogukan_ata_2.ply',
#  'FIZIMED_UTKU_RAFET_TAS_(_AKTIF_).ply',
#  'saida Huseyinova.ply',
#  'AKTIF__Acelya_Acar.ply',
#  'şeyma yaşar 1.ply',
#  'AKTIF_2021_-_30_Alperen_Adali_(Aktif).ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan_2.ply',
#  'KALECAN_aylin_bayir-korse.ply',
#  'ARTI_sumeyye_ecem_akay_(+).ply',
#  'LIV_HOSPITAL_gulser_unlui.ply',
#  'furkan sefer.ply',
#  'irem dundar.ply',
#  'KALECAN_Ceyda_Sare_Kaplan_100621.ply',
#  '2023-07-13_12-48-18_Fw__3D_Model_Malak_samir_0823_charity___i_print_it_at_home___very__grateful_for__free_design_.ply',
#  '2023-09-11_20-58-46_Fw__3D_Model_Joudi_moh_with_polls__7923___her_2nd_brace_with_us___no__period_.ply',
#  'Nazli Belis Çavuş.ply',
#  'KONFOR_muhammed_demlahi.ply',
#  'Furkan Sarı KALECAN.ply',
#  '2024-07-05_15-52-18_Fwd__Fw__Patient_Data_Nour_Maysara_1_____2724.ply',
#  '2023-05-12_10-34-17_this_is_hana_baha_file_2123_that_was_send_on_december_30_2022_.ply',
#  'KALECAN_alina_sterkhova.ply',
#  '2024-08-19_10-02-26_Pacient_Savine_data_s.ply',
#  '2024-08-23_13-55-10_Fwd__Fw__Patient_Data_Farida_Katat_case_4824___she_had_2_braces__before_last_one_was_6823.ply',
#  '2024-07-03_15-12-40_Patient_Data.ply',
#  '2024-06-08_08-48-14_08_06_2024.ply',
#  'FIZIMED_ELANUR_TOPCU_(_AKTIF_).ply',
#  'kerem sekman.ply',
#  '2024-08-24_16-33-37_Fwd__Fw__Patient_Data_Rital_Ibrahim_6824.ply',
#  'FIZIMED_ELIF_OZBAY_(_AKTIF_).ply',
#  'AKTIF_2021_-_47_Ahmet_Can_Kahraman_(Aktif).ply',
#  'AKTIF_ela_nur_pamukcu_2.ply',
#  'FIZIMED_INCI_DIKICI.ply',
#  'FIZIMED_muhammed_emin_bicakci.ply',
#  'KALECAN_Ceren_Akinci_KCO_051021.ply',
#  '2023-06-02_10-00-20_Fw__3D_Model_kisha_Nadine_1723_.ply',
#  'AKTIF_yagmur cekic.ply',
#  'KONFOR_Maria_konfor.ply',
#  'AKTIF_Duru_Eda_Morgil.ply',
#  '2023-08-14_11-50-24_Fw__3D_Model_Malk_Saadi_13823___print_in_USA_.ply',
#  '2023-12-04_13-34-05_Fw__Patient_Data_engy_bassam__12123____pls_design_only__today_or__tomorrow___thx_.ply',
#  'serra aysel-korseKALECAN.ply',
#  'nisa sert.ply',
#  'ECE_ORTOPEDI_KONYA_Yusa_Ozdemir.ply',
#  'kerem çeliker-korseKALECAN.ply',
#  'FIZIMED_CEVHER_FIRAT_(_AKTIF_).ply',
#  '2024-09-09_05-30-23_FW__Patient_Data-_Gaya.ply',
#  '2021 - 32 Ömer Albayrak (Aktif).ply',
#  '2024-06-11_14-12-03_Possibly_K5__please_check_rotation.ply',
#  '2024-08-31_07-49-09_Fwd__Fw__Patient_Data_mariam_George___8824.ply',
#  'KALECAN_DURU_YAHCI-KORSE.ply',
#  'AKTIF_Eslem_Horuz.ply',
#  'Peral akcalı.ply',
#  '2024-08-23_14-00-38_Fwd__Fw__Patient_Data_Jana_Abd_El_Ghany_1_case___3824_she_had_a_brace__before___3124.ply',
#  'İrem Hilal Barucu.ply',
#  'AKTIF_erva_agiralioglu.ply',
#  'KONFOR_ali_yusuf.ply',
#  '2024-04-30_09-56-39_Patient_Data_Maysa_B_de_Oliveira.ply',
#  '2023-07-13_13-24-24_Fw__3D_Model_gana_tamer__3823__full_service_.ply',
#  'FIZIMED_INCI_SU_KALDIRIM_(_AKTIF_).ply',
#  '2023-07-13_12-44-10_Fw__3D_Model_Mona_Ashraf__1823___just_design_pls___we_do_fitting_.ply']
