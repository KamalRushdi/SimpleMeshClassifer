# %% [markdown]
# ### imports

# %%
import pyvista as pv
import pymeshfix
import os
import trimesh
import numpy as np

# %% [markdown]
# ##### Augmentation: mirror the mesh

# %%
def mirror_mesh(input_path):
    mesh = pv.read(input_path)
    # mirror the mesh on the Y axis
    mesh.points[:, 1] = -mesh.points[:, 1]
    mesh.save(input_path.replace(".ply", "_mirrored.ply"))
#
# meshPathes = [mesh for mesh in os.listdir("../experimentation_scripts/data_samples/train/") if mesh.endswith(".ply")]
#
# for mesh in meshPathes:
#     mesh_path = os.path.join("../experimentation_scripts/data_samples/train/", mesh)
#     mirror_mesh(mesh_path)

# %% [markdown]
# ##### Fill holes in the mesh and clean the isolated vertices function

# %%
def fill_mesh_holes_pyvista(input_path, output_path, hole_size=1000.0):
    pymeshfix.clean_from_file(input_path, output_path)
    mesh = pv.read(output_path)
    mesh = mesh.clean(tolerance=1e-6)
    mesh = mesh.triangulate()
    # Fill holes
    filled = mesh.fill_holes(hole_size)

    # Optional: clean up
    filled = filled.clean()

    # Save the result
    filled.save(output_path)

    mesh = pv.read(output_path)
    # mirror the mesh on the Y axis
    # mesh.points[:, 1] = -mesh.points[:, 1]
    # mesh.save(output_path.replace(".ply", "_mirrored.ply"))

    return filled

# %% [markdown]
# ##### preprocess the mesh and slice the back

# %%
data_path = "../experimentation_scripts/data_samples/train/2021 - 21 Pelinsu Özkan (Aktif).ply"
sliced_mesh_path = "./sliced_meshes"

# mesh_paths = [path for path in os.listdir(data_path) if path.endswith(".ply")]

mirrored_guys = True
def processMesh(meshPath: str):
    # fill the mesh using pyvista
    output_dir = os.path.join(os.path.dirname(meshPath), "filled_meshes")
    output_path = os.path.join(output_dir, os.path.splitext(os.path.basename(meshPath))[0] + ".ply")

    fill_mesh_holes_pyvista(meshPath, output_path, hole_size=10000.0)

    mesh = trimesh.load(output_path)
    center_z = (mesh.bounds[0][2] + mesh.bounds[1][2]) / 2
    # cut the mesh from with a plane on center_z
    plane_normal = [0, 0, 1]
    plane_origin = [0, 0, center_z]

    # Slice the mesh with the plane
    sliced_meshes = mesh.slice_plane(plane_origin, plane_normal)
    print(type(sliced_meshes))
    # sliced_meshes.export(f"{sliced_mesh_path}/{"".join(base_name.split(".")[:-1])}.ply")
    return sliced_meshes
mesh = processMesh(data_path)
# Out:
# <class 'trimesh.base.Trimesh'>

# %% [markdown]
# ##### horizontally slice function

# %%
N_SLICES = 21

def sliceMesh(mesh):
    # cut the mesh across the Z axis alonge the Y axis
    jump = abs(mesh.bounds[0][0] - mesh.bounds[1][0]) / N_SLICES
    initial = mesh.bounds[0][0]
    plane_normal = [1, 0, 0]
    plane_origin = [initial, 0, 0]
    plane_negative_normal = [-1, 0, 0]

    # new_center_x = 0
    # Slice the mesh with the plane
    slices = []
    for i in range (N_SLICES):
        sliced_meshes = mesh.slice_plane(plane_origin, plane_normal)
        plane_origin[0] = plane_origin[0] + jump
        sliced_meshes = sliced_meshes.slice_plane(plane_origin, plane_negative_normal)
        slices.append(sliced_meshes)
        # sliced_meshes.export(f"{i}.ply")
    # remove the last N_SLICES - 17
    for i in range(N_SLICES - 17):
        slices.pop()
    return slices

# slices = sliceMesh(sliced_mesh)

# %% [markdown]
# ##### point rotation function

# %%
from scipy.spatial.transform import Rotation as R
def rotate_normal_around_axis(normal, origin, axis, angle_degrees):
    axis = axis / np.linalg.norm(axis)  # ensure unit axis
    angle_rad = np.deg2rad(angle_degrees)
    rot = R.from_rotvec(angle_rad * axis)
    new_normal = rot.apply(normal)
    return new_normal

# %% [markdown]
# ##### radial slice function

# %%
N_PATCHES = 10
def radial_slice(mesh : trimesh.Trimesh):
    # cut the mesh radially
    # print(len(mesh.vertices))
    initial_z = mesh.bounds[0][2]
    # print(f"Center X: {initial_z}")
    plane_normal = [0, 0, 1]
    plane_negative_normal = [0, 0, -1]
    # TODO TRY to take abs for (mesh.bounds[0][1] + mesh.bounds[1][1])
    plane_origin = np.array([0, (mesh.bounds[0][1] + mesh.bounds[1][1])/ 2, initial_z])
    axis = np.array([1, 0, 0])      # rotate around X
    # last_normal = rotate_normal_around_axis(np.array(plane_normal), np.array(plane_origin), axis, 170)
    # last_slice =  mesh.slice_plane(plane_origin, last_normal)
    # last_slice.export("last_slice.ply")


    patches_list = []

    for i in range(N_PATCHES):
        sliced_patches = mesh.slice_plane(plane_origin, plane_normal)
        plane_normal = rotate_normal_around_axis(np.array(plane_normal), np.array(plane_origin), axis, 180 / N_PATCHES)
        plane_negative_normal = rotate_normal_around_axis(np.array(plane_negative_normal), np.array(plane_origin), axis, 180 / N_PATCHES)
        sliced_patches = sliced_patches.slice_plane(plane_origin, plane_negative_normal)
        # sliced_patches.export(f"radial_slice_{i}.ply")
        patches_list.append(sliced_patches)

    return patches_list

# patches = radial_slice(slices[2])

# %%
counter = 0

# %% [markdown]
# ##### get the normal of the patch through averaging the normals of the vertices

# %%
def get_patch_normal(patch : trimesh.Trimesh):
    if patch is None:
        print("Warning Patch is None")
    else:
        normals = np.mean(patch.vertex_normals, axis = 0)
        norm = np.linalg.norm(normals)
        if norm > 1e-6:
            normals = normals / norm
    if patch.vertex_normals.shape == (0,3):
        print(patch)
    return normals
# get_patch_normal(patches[0])

# %%
from skspatial.objects import Plane
def get_patch_normal_scikit_spatial(patch: trimesh.Trimesh):
    """
    Compute the normal of a mesh patch using scikit-spatial.

    Parameters:
    -----------
    patch : trimesh.Trimesh
        A mesh patch for which to estimate the normal

    Returns:
    --------
    numpy.ndarray
        The estimated normal vector for the patch
    """
    if patch is None:
        print("Warning: Patch is None")
        return np.array([0.0, 0.0, 1.0])  # Default normal

    # Check if the patch has enough vertices (need at least 3 points for a proper plane)
    if len(patch.vertices) < 3:
        print(f"Warning: Patch has only {len(patch.vertices)} vertices, need at least 3 for reliable PCA")
        if len(patch.vertices) == 0:
            return np.array([0.0, 0.0, 1.0])  # Default normal if no vertices
        elif len(patch.vertices) == 1 or len(patch.vertices) == 2:
            # Single point - use vertex normal if available, otherwise default
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)

    # Get vertices as points for PCA
    points = patch.vertices
    plane = Plane.best_fit(points)

    # Get the normal of the plane
    normal = plane.normal

    # Ensure the normal has unit length
    normal = normal / np.linalg.norm(normal)
    # Optional: Make sure the normal points "outward"
    # We can use the average vertex normal as a reference for consistent orientation
    if len(patch.vertex_normals) > 0:
        avg_vertex_normal = np.mean(patch.vertex_normals, axis=0)
        avg_vertex_normal = avg_vertex_normal / np.linalg.norm(avg_vertex_normal)

        # If the computed normal points in the opposite direction of the average vertex normal,
        # flip it to maintain consistent orientation
        if np.dot(normal, avg_vertex_normal) < 0:
            normal = -normal

    return normal

# %%
import numpy as np
import trimesh
from scipy import linalg

def get_patch_normal_pca(patch: trimesh.Trimesh):
    """
    Compute the normal of a mesh patch using Principal Component Analysis (PCA).

    Parameters:
    -----------
    patch : trimesh.Trimesh
        A mesh patch for which to estimate the normal

    Returns:
    --------
    numpy.ndarray
        The estimated normal vector for the patch
    """
    if patch is None:
        print("Warning: Patch is None")
        return np.array([0.0, 0.0, 1.0])  # Default normal

    # Check if the patch has enough vertices (need at least 3 points for a proper plane)
    if len(patch.vertices) < 3:
        print(f"Warning: Patch has only {len(patch.vertices)} vertices, need at least 3 for reliable PCA")
        if len(patch.vertices) == 0:
            return np.array([0.0, 0.0, 1.0])  # Default normal if no vertices
        elif len(patch.vertices) == 1 or len(patch.vertices) == 2:
            # Single point - use vertex normal if available, otherwise default
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)

    # Get vertices as points for PCA
    points = patch.vertices

    # Center the points by subtracting the mean
    points_centered = points - np.mean(points, axis=0)

    # Compute the covariance matrix
    cov_matrix = np.cov(points_centered, rowvar=False)

    # Check for numerical stability
    if np.any(np.isnan(cov_matrix)):
        print("Warning: NaN values in covariance matrix")
        if len(patch.vertex_normals) > 0:
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)
        return np.array([0.0, 0.0, 1.0])

    # Compute eigenvalues and eigenvectors
    try:
        eigenvalues, eigenvectors = linalg.eigh(cov_matrix)
    except np.linalg.LinAlgError:
        print("Warning: Eigenvalue computation failed")
        if len(patch.vertex_normals) > 0:
            avg_normal = np.mean(patch.vertex_normals, axis=0)
            return avg_normal / np.linalg.norm(avg_normal)
        return np.array([0.0, 0.0, 1.0])

    # The normal is the eigenvector corresponding to the smallest eigenvalue
    # (the direction with least variance)
    normal = eigenvectors[:, 0]

    # Ensure the normal has unit length
    normal = normal / np.linalg.norm(normal)

    # Optional: Make sure the normal points "outward"
    # We can use the average vertex normal as a reference for consistent orientation
    if len(patch.vertex_normals) > 0:
        avg_vertex_normal = np.mean(patch.vertex_normals, axis=0)
        avg_vertex_normal = avg_vertex_normal / np.linalg.norm(avg_vertex_normal)

        # If the computed normal points in the opposite direction of the average vertex normal,
        # flip it to maintain consistent orientation
        if np.dot(normal, avg_vertex_normal) < 0:
            normal = -normal

    return normal


# Example usage:
# normal = get_patch_normal_pca(patches[0])

# %% [markdown]
# ##### Get the features of the mesh

# %%
def get_features(meshPath, export_output=False):
    print(meshPath)
    back_slice = processMesh(meshPath)
    vertical_slices = sliceMesh(back_slice)

    # # collection of geometries
    geometries_original = []
    geometries_features = []

    all_normals = []
    for slice in vertical_slices:
        if slice is None:
            print("Warning vertical slice is None")
            continue
        patches = radial_slice(slice)
        for patch in patches:
            # make the original geometry
            if export_output:
                geometry_original = trimesh.Trimesh(vertices=patch.vertices, faces=patch.faces, process=False)
                geometry_original.vertex_normals = patch.vertex_normals
                geometries_original.append(geometry_original)

            patch_normal = get_patch_normal_scikit_spatial(patch)
            if export_output:
                # make the features geometry
                geometry_features = trimesh.Trimesh(vertices=patch.vertices, faces=patch.faces, process=False)
                like_array = np.full_like(geometry_features.vertex_normals, patch_normal)
                geometry_features.vertex_normals = like_array
                # geometry_features.vertex_normals = np.tile(patch_normal, (geometry_features.vertices.shape[0], 1))
                geometries_features.append(geometry_features)

            all_normals.append(patch_normal)

    if export_output:
        # export the original geometries as one unit
        merged = trimesh.util.concatenate(geometries_original)
        merged.export(meshPath.replace(".ply", "_original.ply"))
        # export the features geometries as one unit
        merged_features = trimesh.util.concatenate(geometries_features)
        merged_features.export(meshPath.replace(".ply", "_features.ply"))

    return np.array(all_normals)

# %%
# path = "../experimentation_scripts/data_samples/train/2021 - 21 Pelinsu Özkan (Aktif).ply"
# normals = get_features(path, export_output=False)

# %%
# path = "../experimentation_scripts/data_samples/train/kerem celik.ply"
# normals = get_features(path)

# %%
meshPathes = [mesh for mesh in os.listdir("../experimentation_scripts/data_samples/corrupted") if mesh.endswith(".ply")]

# %% [markdown]
# #### Extract features from the dataset

# %%
import pickle

features = []
for mesh in meshPathes:
    feature = get_features(os.path.join("../experimentation_scripts/data_samples/corrupted", mesh))
    feature = np.nan_to_num(feature)
    features.append((mesh, feature))
    print(len(features))

with open("features.pkl", "wb") as f:
    pickle.dump(features, f)
# Out:
# ../experimentation_scripts/data_samples/corrupted/ARTI_ali_riza_ersin_(+).ply
# 1
# ../experimentation_scripts/data_samples/corrupted/2024-09-16_14-55-22_回复__visit_to_Germany.ply
# 2
# ../experimentation_scripts/data_samples/corrupted/ARTI_Sebnem_Ela_Cengizhan_(+).ply
# 3
# ../experimentation_scripts/data_samples/corrupted/AKTIF__azra_duru_yildiz.ply
# 4
# ../experimentation_scripts/data_samples/corrupted/2024-07-05_18-59-35_Fwd__Fw__Patient_Data_ziad_Kareem_3_case_5724.ply
# 5
# ../experimentation_scripts/data_samples/corrupted/2024-09-20_16-42-31_Fwd__Fw__Patient_Data_Maria_charity_1924.ply
# 6
# ../experimentation_scripts/data_samples/corrupted/ilkim cemal kara 140921KALECAN.ply
# 7
# ../experimentation_scripts/data_samples/corrupted/ARTI_yigit_ali_boz_2_(+).ply
# 8
# ../experimentation_scripts/data_samples/corrupted/KALECAN_ecrin_ada_sener-_korse.ply
# 9
# ../experimentation_scripts/data_samples/corrupted/ARTI_ayse_beren_nebil.ply
# 10
# ../experimentation_scripts/data_samples/corrupted/2023-10-06_10-11-52_Fw__3D_Model_Jana_sherif_21023__her_2nd_brace___no_new_xray_yet_.ply
# 11
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ZEYNEP_BAHSI_(_AKTIF_).ply
# 12
# ../experimentation_scripts/data_samples/corrupted/2024-01-18_18-28-46_Patient_Data.ply
# 13
# ../experimentation_scripts/data_samples/corrupted/2024-09-13_10-55-45_Patient_Data_Estela_Soares.ply
# 14
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_AHMET_KAYA_(_AKTIF_).ply
# 15
# ../experimentation_scripts/data_samples/corrupted/KALECAN_defne_bekar.ply
# 16
# ../experimentation_scripts/data_samples/corrupted/KALECAN_asya_guven.ply
# 17
# ../experimentation_scripts/data_samples/corrupted/KALECAN_deniz_sukruogullari-korse.ply
# 18
# ../experimentation_scripts/data_samples/corrupted/ozgu ergin.ply
# 19
# ../experimentation_scripts/data_samples/corrupted/ARTI_Eylul_Acar.ply
# 20
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Elif_Irem_Sercin.ply
# 21
# ../experimentation_scripts/data_samples/corrupted/AKTIF_deniz_kiran.ply
# 22
# ../experimentation_scripts/data_samples/corrupted/Tugba Naz Korkmaz 3.ply
# 23
# ../experimentation_scripts/data_samples/corrupted/ARTI_sila_dogan.ply
# 24
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_FURKAN_OZDEN_(_AKTIF_).ply
# 25
# ../experimentation_scripts/data_samples/corrupted/2024-05-15_10-24-54_14_05_24.ply
# 26
# ../experimentation_scripts/data_samples/corrupted/ARTI_Harun_gungeldi_Arti_PO.ply
# 27
# ../experimentation_scripts/data_samples/corrupted/2024-01-13_01-57-49_Fw__Patient_Data_Mirna_Abd_el_Ghany_4124.ply
# 28
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_59_Beyza_Sevimli_(Aktif).ply
# 29
# ../experimentation_scripts/data_samples/corrupted/2023-08-25_11-28-30_Fw__3D_Model_Hana_tamer_2923__design_and_fitting_.ply
# 30
# ../experimentation_scripts/data_samples/corrupted/2023-10-06_11-28-48_Fw__3D_Model__Juli_nashed_51023___we_revise_orthomedix_brace_._.ply
# 31
# ../experimentation_scripts/data_samples/corrupted/2023-09-08_13-29-53_Fw__3D_Model_salma_Salah_6923.ply
# 32
# ../experimentation_scripts/data_samples/corrupted/2021 - 21 Pelinsu Özkan (Aktif).ply
# 33
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Alya_Akalin.ply
# 34
# ../experimentation_scripts/data_samples/corrupted/KALECAN_Ali_Ihsan_Ayanlar_KCO.ply
# 35
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Ilke_Deren_Zafer.ply
# 36
# ../experimentation_scripts/data_samples/corrupted/2023-07-24_12-44-30_Fw__3D_Model_Omar_Hatem_7823_full_service_.ply
# 37
# ../experimentation_scripts/data_samples/corrupted/KALECAN_ECRIN_PANCAROGLU.ply
# 38
# ../experimentation_scripts/data_samples/corrupted/mert altınay.ply
# 39
# ../experimentation_scripts/data_samples/corrupted/murathan ateş.ply
# 40
# ../experimentation_scripts/data_samples/corrupted/2023-10-06_10-34-28_Fw__3D_Model_Clara__01023__free_revision_.ply
# 41
# ../experimentation_scripts/data_samples/corrupted/KALECAN_basak_ela_ceyani-korse.ply
# 42
# ../experimentation_scripts/data_samples/corrupted/KONFOR_sila_elmas.ply
# 43
# ../experimentation_scripts/data_samples/corrupted/2024-08-29_08-29-13_New_patient._.ply
# 44
# ../experimentation_scripts/data_samples/corrupted/ARTI_Sude_Kara.ply
# 45
# ../experimentation_scripts/data_samples/corrupted/KALECAN_batuhan_okan.ply
# 46
# ../experimentation_scripts/data_samples/corrupted/2024-05-25_13-55-46_25_05_24-3.ply
# 47
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_hilkmet_can_kaya.ply
# 48
# ../experimentation_scripts/data_samples/corrupted/KONFOR_Sema_nur_Gultekin.ply
# 49
# ../experimentation_scripts/data_samples/corrupted/2024-03-01_13-48-01_Fw__Patient_Data_Lana_3324.ply
# 50
# ../experimentation_scripts/data_samples/corrupted/KALECAN_Asel_Yildirim.ply
# 51
# ../experimentation_scripts/data_samples/corrupted/2024-08-23_13-54-34_Fwd__Fw__Patient_Data_Malak_Mohamed_1824.ply
# 52
# ../experimentation_scripts/data_samples/corrupted/ARTI_sila_dogru.ply
# 53
# ../experimentation_scripts/data_samples/corrupted/ECE_ORTOPEDI_KONYA_Enes_Doruk_ECE.ply
# 54
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_ela_yuksel.ply
# 55
# ../experimentation_scripts/data_samples/corrupted/CEYLAN_Tuana_Gursoy_(ceylan).ply
# 56
# ../experimentation_scripts/data_samples/corrupted/Yusuf Yanmaz.ply
# 57
# ../experimentation_scripts/data_samples/corrupted/2024-01-20_11-02-56_Fw__Patient_Data_Mohamed_Fareed_2.ply
# 58
# ../experimentation_scripts/data_samples/corrupted/Zeynep Naz Pınar KlinikSport.ply
# 59
# ../experimentation_scripts/data_samples/corrupted/mustafa koc.ply
# 60
# ../experimentation_scripts/data_samples/corrupted/KALECAN_dide_gazel_abakay.ply
# 61
# ../experimentation_scripts/data_samples/corrupted/irem su dikmenKALECAN.ply
# 62
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ELIZ_OZDOGAN.ply
# 63
# ../experimentation_scripts/data_samples/corrupted/KALECAN_asel_kucukcoban.ply
# 64
# ../experimentation_scripts/data_samples/corrupted/ECE_ORTOPEDI_KONYA_Ahmet_Talha_Saracoglu_ECE.ply
# 65
# ../experimentation_scripts/data_samples/corrupted/tugce birinci2.ply
# 66
# ../experimentation_scripts/data_samples/corrupted/CEYLAN_aysegul_toker.ply
# 67
# ../experimentation_scripts/data_samples/corrupted/zeynep ilhan.ply
# 68
# ../experimentation_scripts/data_samples/corrupted/2024-03-19_09-40-42_Patient_Data_Vitor_Romagnoli_Alves._March_19_24.ply
# 69
# ../experimentation_scripts/data_samples/corrupted/AKTIF_emir_ay.ply
# 70
# ../experimentation_scripts/data_samples/corrupted/2023-06-16_11-06-59_Fw__3D_Model_Mariam_Qatar__the_right_scan_4723.ply
# 71
# ../experimentation_scripts/data_samples/corrupted/Melisa Nur Acar kalecan.ply
# 72
# ../experimentation_scripts/data_samples/corrupted/2024-03-31_12-49-50_Fw__Patient_Data_adam_Karim_5424.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 73
# ../experimentation_scripts/data_samples/corrupted/2024-06-07_13-48-24_Another_measurement.ply
# 74
# ../experimentation_scripts/data_samples/corrupted/ECE_ORTOPEDI_KONYA_Eymen_Talip_Taskin.ply
# 75
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Ilke_Cemre_Kilincarslan.ply
# 76
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ECEM_SU_KUNT_(_AKTIF_).ply
# 77
# ../experimentation_scripts/data_samples/corrupted/Furkan Keleş.ply
# 78
# ../experimentation_scripts/data_samples/corrupted/2023-08-14_08-32-16_Fw__3D_Model_Reem_Ibrahim_9823_.ply
# 79
# ../experimentation_scripts/data_samples/corrupted/2024-05-25_13-49-15_25_05_24-2.ply
# 80
# ../experimentation_scripts/data_samples/corrupted/2023-11-16_10-54-45_Fw__3D_Model_haad_Libya__31123_.ply
# 81
# ../experimentation_scripts/data_samples/corrupted/nil yuruk.ply
# 82
# ../experimentation_scripts/data_samples/corrupted/2023-08-14_09-07-25_Fw__3D_Model_karma_Assam_11823_full_service_by_eric_.ply
# 83
# ../experimentation_scripts/data_samples/corrupted/AKTIF__can_efe_baki.ply
# 84
# ../experimentation_scripts/data_samples/corrupted/2023-04-09_15-52-41_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply
# 85
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Irem_Temizel.ply
# 86
# ../experimentation_scripts/data_samples/corrupted/DIYAMER_Yigitcan_Caglar.ply
# 87
# ../experimentation_scripts/data_samples/corrupted/2024-05-06_10-48-52_Patient_Data_isis_Castanheira.ply
# 88
# ../experimentation_scripts/data_samples/corrupted/2023-11-26_09-23-30_Re__3D_Model_colored_again___51123.ply
# 89
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_13_Defne_Kaya_(Aktif).ply
# 90
# ../experimentation_scripts/data_samples/corrupted/gözde nur maraşlı.ply
# 91
# ../experimentation_scripts/data_samples/corrupted/AKTIF_eylul_deniz_kadas.ply
# 92
# ../experimentation_scripts/data_samples/corrupted/Realeboha Kevin Kao.ply
# 93
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_EGE_OZKAYA_(_AKTIF_).ply
# 94
# ../experimentation_scripts/data_samples/corrupted/AKTIF_elif_guler.ply
# 95
# ../experimentation_scripts/data_samples/corrupted/2024-03-13_01-18-59_Fw__Patient_Data_Rosetta_6324.ply
# 96
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_KEMAL_YIGIT_TORER_(_AKTIF_).ply
# 97
# ../experimentation_scripts/data_samples/corrupted/2024-08-07_15-17-01_Patient_Data_Raphael_Rodrigues.ply
# 98
# ../experimentation_scripts/data_samples/corrupted/ARTIrabia gursoy.ply
# 99
# ../experimentation_scripts/data_samples/corrupted/halim durnaKALECAN.ply
# 100
# ../experimentation_scripts/data_samples/corrupted/tugbanaz Korkmaz.ply
# 101
# ../experimentation_scripts/data_samples/corrupted/2024-02-02_06-48-33_Fw__moaz_1224.ply
# 102
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_EMRE_SARP_ZEYTINOGLU_2.ply
# 103
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_EGEM_DENIZLI_cem_kayman.ply
# 104
# ../experimentation_scripts/data_samples/corrupted/Sude Durmaz (Aynur).ply
# 105
# ../experimentation_scripts/data_samples/corrupted/2023-08-25_11-13-10_Fw__3D_Model_febronia_1st_polls_1923__just_G_code__pls____fitting_and__print_will_be_done_locally___charity_.ply
# 106
# ../experimentation_scripts/data_samples/corrupted/ömer hamza lafcı.ply
# 107
# ../experimentation_scripts/data_samples/corrupted/ARTI_beyza_isil_yildirim_+.ply
# 108
# ../experimentation_scripts/data_samples/corrupted/kerem celik.ply
# 109
# ../experimentation_scripts/data_samples/corrupted/mikail acar.ply
# 110
# ../experimentation_scripts/data_samples/corrupted/zumra sancaktepe.ply
# 111
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_TUANA_KENDIRCI_(_AKTIF_).ply
# 112
# ../experimentation_scripts/data_samples/corrupted/yasemin kıvrak.ply
# 113
# ../experimentation_scripts/data_samples/corrupted/AKTIF_elif_duru_zengin.ply
# 114
# ../experimentation_scripts/data_samples/corrupted/CEYLAN_berrak_ozturk.ply
# 115
# ../experimentation_scripts/data_samples/corrupted/2023-12-18_10-55-26_Maria_Fernanda_new_Brace.ply
# 116
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ecenur_tuysuz.ply
# 117
# ../experimentation_scripts/data_samples/corrupted/2024-09-22_19-24-35_Fwd__Fw__Patient_Data_Martina_4924___pls_read_my_notes_first.ply
# 118
# ../experimentation_scripts/data_samples/corrupted/2023-08-09_14-36-59_Patient_Iasmin_Stucki.ply
# 119
# ../experimentation_scripts/data_samples/corrupted/AKTIF_elif_korkmaz.ply
# 120
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_AYSENAZ_BALABAN_(_AKTIF_).ply
# 121
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Belinay_Keskin.ply
# 122
# ../experimentation_scripts/data_samples/corrupted/2024-07-05_14-34-36_Fwd__Fw__Patient_Data_Omar_zakarya_1_case_1724___will_do_new_xray.ply
# 123
# ../experimentation_scripts/data_samples/corrupted/AKTIF__buglem_karaca.ply
# 124
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Victoria_Blatskaya.ply
# 125
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_10_Alp_Doganer_(Aktif).ply
# 126
# ../experimentation_scripts/data_samples/corrupted/Omer faruk Yanas.ply
# 127
# ../experimentation_scripts/data_samples/corrupted/2024-02-04_19-52-34_Fw__Patient_Data_karas_Tamer_2224_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 128
# ../experimentation_scripts/data_samples/corrupted/CITAY_IZMIR_A_R_D_KORSE.ply
# 129
# ../experimentation_scripts/data_samples/corrupted/2023-05-12_10-32-48_Fw__3D_Model_Hana_bahaa_revison__2523.ply
# 130
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_NISA_TUANA_YUMRUTAS_(_AKTIF_).ply
# 131
# ../experimentation_scripts/data_samples/corrupted/ARTI_hatice_eceylan_+05_04_2022.ply
# 132
# ../experimentation_scripts/data_samples/corrupted/2023-10-29_21-37-27_Fw__3D_Model_firial__11123_pls_print_in_USA_.ply
# 133
# ../experimentation_scripts/data_samples/corrupted/CITAY_IZMIR_so_citay.ply
# 134
# ../experimentation_scripts/data_samples/corrupted/esin ünlü kalecan.ply
# 135
# ../experimentation_scripts/data_samples/corrupted/lara ada bıldır.ply
# 136
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Ayben_Armina_Temel.ply
# 137
# ../experimentation_scripts/data_samples/corrupted/AKTIF__asmin_cetin.ply
# 138
# ../experimentation_scripts/data_samples/corrupted/KALECAN_ayse_barut_14-05-22.ply
# 139
# ../experimentation_scripts/data_samples/corrupted/2024-08-03_12-33-49_New_Scans_and_order._.ply
# 140
# ../experimentation_scripts/data_samples/corrupted/2024-06-11_13-40-00_FW__Patient_Data_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 141
# ../experimentation_scripts/data_samples/corrupted/2023-05-12_10-45-30_Fw__3D_Model_basmala_walid_3523.ply
# 142
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_zeren_boz.ply
# 143
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_FATMA_MOLLA_(_AKTIF_).ply
# 144
# ../experimentation_scripts/data_samples/corrupted/2024-06-12_09-42-53_Fwd__Patient_Data_Giovana_Dantas.ply
# 145
# ../experimentation_scripts/data_samples/corrupted/KALECAN_adem_unal.ply
# 146
# ../experimentation_scripts/data_samples/corrupted/fatma zumra aydın.ply
# 147
# ../experimentation_scripts/data_samples/corrupted/2024-05-22_09-24-28_Fwd__Patient_Data.ply
# 148
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Elif_Guler_2.ply
# 149
# ../experimentation_scripts/data_samples/corrupted/2024-05-25_09-53-09_New_Scan_.ply
# 150
# ../experimentation_scripts/data_samples/corrupted/nil yürük 3.ply
# 151
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Buse_Goksel.ply
# 152
# ../experimentation_scripts/data_samples/corrupted/AKTIF__alara_hizlan.ply
# 153
# ../experimentation_scripts/data_samples/corrupted/saliha zeynep akdemir.ply
# 154
# ../experimentation_scripts/data_samples/corrupted/Yasemin Guney.ply
# 155
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Berra_Tilaver.ply
# 156
# ../experimentation_scripts/data_samples/corrupted/AKTIF__ada_onur.ply
# 157
# ../experimentation_scripts/data_samples/corrupted/Hicran Durak.ply
# 158
# ../experimentation_scripts/data_samples/corrupted/2023-10-06_10-15-34_Fw__3D_Model_farida_sedky_31023__i_donot_need_Menna_to_be_in_the_room__or_get_close_to_her_mom___fitting_by_y_and_mariam__thx__.ply
# 159
# ../experimentation_scripts/data_samples/corrupted/KONFOR_Meyz_Al_Ali.ply
# 160
# ../experimentation_scripts/data_samples/corrupted/KALECAN_celal_cinar_coksoy.ply
# 161
# ../experimentation_scripts/data_samples/corrupted/ARTI_tuncer_erdogan.ply
# 162
# ../experimentation_scripts/data_samples/corrupted/2024-03-25_10-10-40_Fwd__Patient_Data_Lays_.ply
# 163
# ../experimentation_scripts/data_samples/corrupted/reyyan komurcuKALECAN.ply
# 164
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Alp_Ceyhan.ply
# 165
# ../experimentation_scripts/data_samples/corrupted/2024-09-04_09-32-55_Fwd__Patient_Data.ply
# 166
# ../experimentation_scripts/data_samples/corrupted/Elif Sümeyye Gül.ply
# 167
# ../experimentation_scripts/data_samples/corrupted/KALECAN_defne_yaliguluhep.ply
# 168
# ../experimentation_scripts/data_samples/corrupted/ARTI_irem_badurlar_(+).ply
# 169
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_derya_arbabham.ply
# 170
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ecrin_nil_yavuzaslan.ply
# 171
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Lutfu_ege_bodur.ply
# 172
# ../experimentation_scripts/data_samples/corrupted/AKTIF_evrim_yilmaz.ply
# 173
# ../experimentation_scripts/data_samples/corrupted/melek çakırKALECAN.ply
# 174
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Aylin_guliyeva23.ply
# 175
# ../experimentation_scripts/data_samples/corrupted/tufan emre aydın2.ply
# 176
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Ada_Serindere.ply
# 177
# ../experimentation_scripts/data_samples/corrupted/Ezgi karatepe.ply
# 178
# ../experimentation_scripts/data_samples/corrupted/2024-04-10_08-58-29_Clara_s_data.ply
# 179
# ../experimentation_scripts/data_samples/corrupted/KALECAN_DERIN_KAPLAN-KCO.ply
# 180
# ../experimentation_scripts/data_samples/corrupted/tanem harputluKALECAN.ply
# 181
# ../experimentation_scripts/data_samples/corrupted/AKTIF__berfin_gunduz.ply
# 182
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan.ply
# 183
# ../experimentation_scripts/data_samples/corrupted/ANKA_DUZCE_merve_nur_tureli.ply
# 184
# ../experimentation_scripts/data_samples/corrupted/ARTI_ela_kilic.ply
# 185
# ../experimentation_scripts/data_samples/corrupted/Sura Soyak 05042022.ply
# 186
# ../experimentation_scripts/data_samples/corrupted/ARTI_Irem_macit.ply
# 187
# ../experimentation_scripts/data_samples/corrupted/sevval nuran cavdar.ply
# 188
# ../experimentation_scripts/data_samples/corrupted/meryem zehra demir.ply
# 189
# ../experimentation_scripts/data_samples/corrupted/KALECAN_beray_tokatlioglu.ply
# 190
# ../experimentation_scripts/data_samples/corrupted/2024-06-08_14-08-00_Fwd__Fw__Patient_Data_Ziad_2_3624.ply
# 191
# ../experimentation_scripts/data_samples/corrupted/AKTIF__aysegul_benek.ply
# 192
# ../experimentation_scripts/data_samples/corrupted/2023-08-08_09-33-25_Fw__3D_Model_omar_moataz_8823_design_and_fitting_by_eric__print_in__usa___son_of_special_force_.ply
# 193
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ELIZ_OZDOGAN_(_AKTIF_).ply
# 194
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_AZRA_SEKER_fizimed.ply
# 195
# ../experimentation_scripts/data_samples/corrupted/ARTI_tugba_nur_coban.ply
# 196
# ../experimentation_scripts/data_samples/corrupted/ARTI_cafer_ali_yesiltas_arti.ply
# 197
# ../experimentation_scripts/data_samples/corrupted/ARTI_tuana_deniz_(arti).ply
# 198
# ../experimentation_scripts/data_samples/corrupted/2024-06-05_18-02-55_John_Tunney_patients.ply
# 199
# ../experimentation_scripts/data_samples/corrupted/2024-05-01_06-29-16_Patient_File_-_ACMC1.ply
# 200
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_DICLENAZ_ISBILEN_(_AKTIF_).ply
# 201
# ../experimentation_scripts/data_samples/corrupted/ilayda saygı.ply
# 202
# ../experimentation_scripts/data_samples/corrupted/fatma genç-korseKALECAN.ply
# 203
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ceylin_ece_tektas.ply
# 204
# ../experimentation_scripts/data_samples/corrupted/2024-03-13_11-20-50_Patient_Data_Malásia_.ply
# 205
# ../experimentation_scripts/data_samples/corrupted/AKTIF__aylin_guliyeva.ply
# 206
# ../experimentation_scripts/data_samples/corrupted/2024-03-27_14-14-06_Fw__Patient_Data_Malak_saada__2424___her_2nd_brace_in_7_month_____her__old_file___13823__.ply
# 207
# ../experimentation_scripts/data_samples/corrupted/Ömer Hamza Lafcı 2.ply
# 208
# ../experimentation_scripts/data_samples/corrupted/2023-11-16_14-14-44_Fw__3D_Model_nahed_el_Amir__41123_design_only___look_at_y_notes_.ply
# 209
# ../experimentation_scripts/data_samples/corrupted/nevanur govec.ply
# 210
# ../experimentation_scripts/data_samples/corrupted/2024-03-27_15-08-44_Fwd__Luana_Cavalca_27_3_2024.ply
# 211
# ../experimentation_scripts/data_samples/corrupted/Çağlar Günerkaya KCO_KALECAN.ply
# 212
# ../experimentation_scripts/data_samples/corrupted/AKTIF__ahsen_ismetogullari.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 213
# ../experimentation_scripts/data_samples/corrupted/zeynep saliha akdemir.ply
# 214
# ../experimentation_scripts/data_samples/corrupted/metehan er.ply
# 215
# ../experimentation_scripts/data_samples/corrupted/Pelin Kurtulus.ply
# 216
# ../experimentation_scripts/data_samples/corrupted/mirac kockaya.ply
# 217
# ../experimentation_scripts/data_samples/corrupted/inci defne yunlu.ply
# 218
# ../experimentation_scripts/data_samples/corrupted/ARTI_tugba_nur_acar_+.ply
# 219
# ../experimentation_scripts/data_samples/corrupted/2024-01-13_14-23-31_Re__Patient_DataTouline_1____6124.ply
# 220
# ../experimentation_scripts/data_samples/corrupted/Toprak su demir.ply
# 221
# ../experimentation_scripts/data_samples/corrupted/ARTI_ahmet_hosgor_(+).ply
# 222
# ../experimentation_scripts/data_samples/corrupted/2023-08-30_18-51-11_Fw__3D_Masoud_with_poles_5923__his_2nd_brace______pervious_brace_was__from_Greece___pls__design_and_fitting_only.ply
# 223
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_EGEM_DENIZLI_ahmet_ahlat.ply
# 224
# ../experimentation_scripts/data_samples/corrupted/AKTIF_AZRA VARDAR.ply
# 225
# ../experimentation_scripts/data_samples/corrupted/ECE_ORTOPEDI_KONYA_Kezban_Irem_Icoz.ply
# 226
# ../experimentation_scripts/data_samples/corrupted/2024-05-30_16-47-40_Fwd__Patient_Data.ply
# 227
# ../experimentation_scripts/data_samples/corrupted/AKTIF__arda_gul_2.ply
# 228
# ../experimentation_scripts/data_samples/corrupted/AKTIF_eren_hicyilmaz.ply
# 229
# ../experimentation_scripts/data_samples/corrupted/DENIZ_OKE_Irem_Kose.ply
# 230
# ../experimentation_scripts/data_samples/corrupted/KONFOR_Alperen__Karaca_konfor.ply
# 231
# ../experimentation_scripts/data_samples/corrupted/LUXMED_Defne_Dagistanli_luxmed.ply
# 232
# ../experimentation_scripts/data_samples/corrupted/2024-04-10_07-51-07_Camila_s_data.ply
# 233
# ../experimentation_scripts/data_samples/corrupted/2023-10-06_11-25-01_Fw__3D_Model_menna_husky_41023___her_2nd_brace_.ply
# 234
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Derya_Deniz_Varol.ply
# 235
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_40_Selen_Baydar_(Aktif).ply
# 236
# ../experimentation_scripts/data_samples/corrupted/ARTI_meyranur_karagoz.ply
# 237
# ../experimentation_scripts/data_samples/corrupted/mikail acar 2.ply
# 238
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ELIF_TUANA_SAVCI.ply
# 239
# ../experimentation_scripts/data_samples/corrupted/AKTIF__arya_fakirzade.ply
# 240
# ../experimentation_scripts/data_samples/corrupted/2023-08-14_12-02-55_Fwd__Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply
# 241
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_51_Hiranur_Sekban_(Aktif).ply
# 242
# ../experimentation_scripts/data_samples/corrupted/ezgi nur aydemir.ply
# 243
# ../experimentation_scripts/data_samples/corrupted/2024-08-01_10-11-30_Fwd__Patient_Data_Felipe_4.ply
# 244
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_EGEM_DENIZLI_Defne_Enli.ply
# 245
# ../experimentation_scripts/data_samples/corrupted/AKTIF__cagla_bade_kiyak_2.ply
# 246
# ../experimentation_scripts/data_samples/corrupted/rumeysa gocmen.ply
# 247
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Beril_Yilmazer.ply
# 248
# ../experimentation_scripts/data_samples/corrupted/AKTIF_durudeniz_turan_2.ply
# 249
# ../experimentation_scripts/data_samples/corrupted/eylül kutu KCO 041021KALECAN.ply
# 250
# ../experimentation_scripts/data_samples/corrupted/sinem ünlüerKALECAN.ply
# 251
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Dersim_Toptas.ply
# 252
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_Mustafa_Elvan_egem.ply
# 253
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ege_elibol.ply
# 254
# ../experimentation_scripts/data_samples/corrupted/ırmak tuğla.ply
# 255
# ../experimentation_scripts/data_samples/corrupted/ARTI_emircan_tursun_(+).ply
# 256
# ../experimentation_scripts/data_samples/corrupted/Ada Çalışkan ksKLINIKSPORT.ply
# 257
# ../experimentation_scripts/data_samples/corrupted/AKTIF_esma_bahtiyar.ply
# 258
# ../experimentation_scripts/data_samples/corrupted/2024-01-13_01-56-38_Fw__Patient_Data_Jana_Abd_El_Ghany_3124.ply
# 259
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_18_Azra_Yigitoglu_(Aktif).ply
# 260
# ../experimentation_scripts/data_samples/corrupted/2024-03-15_12-54-25_150324.ply
# 261
# ../experimentation_scripts/data_samples/corrupted/melisa nur acar 2KALECAN.ply
# 262
# ../experimentation_scripts/data_samples/corrupted/Kaan Kubilay Çetinkaya.ply
# 263
# ../experimentation_scripts/data_samples/corrupted/2024-03-24_08-35-01_Fw_mariam_Fouad_1424.ply
# 264
# ../experimentation_scripts/data_samples/corrupted/2024-06-05_11-36-36_Fwd__Patient_Data_Misha_24.ply
# 265
# ../experimentation_scripts/data_samples/corrupted/KALECAN_avsin_somer-korse.ply
# 266
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_DOGA_CIVELEK_(_fizimed_).ply
# 267
# ../experimentation_scripts/data_samples/corrupted/sevval nur guzeltepe.ply
# 268
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Beren_Bay.ply
# 269
# ../experimentation_scripts/data_samples/corrupted/Ilgar Güzel 240921KALECAN.ply
# 270
# ../experimentation_scripts/data_samples/corrupted/2024-07-08_12-10-30_Fwd__Fw__Patient_Data_omar_Motaz_6724___his_2nd_brace.ply
# 271
# ../experimentation_scripts/data_samples/corrupted/ECE_ORTOPEDI_KONYA_Sedef_OzCelik_ECE.ply
# 272
# ../experimentation_scripts/data_samples/corrupted/İclal Rukiye Karaca.ply
# 273
# ../experimentation_scripts/data_samples/corrupted/İsik Sezer Saridede.ply
# 274
# ../experimentation_scripts/data_samples/corrupted/KONFOR_lemar_alheyek.ply
# 275
# ../experimentation_scripts/data_samples/corrupted/Miraz Nisa Nakci.ply
# 276
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Ela_Yuksel_2.ply
# 277
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Tuana_Celik.ply
# 278
# ../experimentation_scripts/data_samples/corrupted/tuğba naz korkmaz 2.ply
# 279
# ../experimentation_scripts/data_samples/corrupted/2023-08-25_11-38-13_Fw__3D_Model_nouran__4923_design_and_fitting___her_2nd_brace_in_8__month___dad_is_cardio_in_UK_.ply
# 280
# ../experimentation_scripts/data_samples/corrupted/KARTAL YİLMAZKALECAN.ply
# 281
# ../experimentation_scripts/data_samples/corrupted/TALA ABUGAHALİ.ply
# 282
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_23_Halim_Burak_Nilifikra_(Aktif).ply
# 283
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Ayse_Melis_Yalcin.ply
# 284
# ../experimentation_scripts/data_samples/corrupted/ARTI_vedat_daglik_(+).ply
# 285
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_NEHIR_DURU_CELIK_(AKTIF_).ply
# 286
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Azra_Karacaoglu.ply
# 287
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ECE_GULERSEN_(_AKTIF_).ply
# 288
# ../experimentation_scripts/data_samples/corrupted/ARTI_Busra_Karaca_+.ply
# 289
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Elif_Korkmaz_04-23.ply
# 290
# ../experimentation_scripts/data_samples/corrupted/2024-09-22_18-59-51_Fwd__Fw__Patient_Data_Malak_bashir_3924.ply
# 291
# ../experimentation_scripts/data_samples/corrupted/2023-06-22_12-38-29_Fw__3D_Model_Maya_9723__her_3rd_brace_in_2_years____are_y_S3_.ply
# 292
# ../experimentation_scripts/data_samples/corrupted/2024-05-09_12-52-03_SA0905.ply
# 293
# ../experimentation_scripts/data_samples/corrupted/2023-12-04_22-12-18_Fw__Patient_Data_Noha_21223__design_pls____p.ply
# 294
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Elif_Eylul_Demir.ply
# 295
# ../experimentation_scripts/data_samples/corrupted/AKTIF_elif_naz_keles.ply
# 296
# ../experimentation_scripts/data_samples/corrupted/AKTIF_can_seker.ply
# 297
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ATILLA_ALLAHVERDI_(_AKTIF_).ply
# 298
# ../experimentation_scripts/data_samples/corrupted/UMUT_azranur_yetim.ply
# 299
# ../experimentation_scripts/data_samples/corrupted/Sadık Bilal Son 090621KALECAN.ply
# 300
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Alya_Doga_senlik.ply
# 301
# ../experimentation_scripts/data_samples/corrupted/AKTIF__ahmet_erdem.ply
# 302
# ../experimentation_scripts/data_samples/corrupted/2024-08-24_11-30-01_FW__Patient_Data.ply
# 303
# ../experimentation_scripts/data_samples/corrupted/çağla bade kıyak.ply
# 304
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Dila_Zeynep_Bayat.ply
# 305
# ../experimentation_scripts/data_samples/corrupted/2024-05-27_10-11-43_Fwd__Fw__Patient_Data_Silvia_1624.ply
# 306
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ECRIN_CAPACI_(_AKTIF_).ply
# 307
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Alya_Dua_Senlik_2.ply
# 308
# ../experimentation_scripts/data_samples/corrupted/2024-06-15_08-44-25_Fwd__Fw__Patient_Data_Jana_Mohamed_4624.ply
# 309
# ../experimentation_scripts/data_samples/corrupted/ARTI_yigit_ali_boz.ply
# 310
# ../experimentation_scripts/data_samples/corrupted/2024-09-15_13-33-28_Fwd__Fw__Patient_Data_Noor_10824.ply
# 311
# ../experimentation_scripts/data_samples/corrupted/Hatice Duman.ply
# 312
# ../experimentation_scripts/data_samples/corrupted/AKTIF__beyza_atak.ply
# 313
# ../experimentation_scripts/data_samples/corrupted/CIGDEM_DR_Arda_Yalcindag.ply
# 314
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_48_Ilyas_Kadir_Saribas_(Aktif).ply
# 315
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_39_Kemal_Efe_Alakavuk_(Aktif).ply
# 316
# ../experimentation_scripts/data_samples/corrupted/CEYLAN_sude_gul_guvenc.ply
# 317
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_nehir_acar.ply
# 318
# ../experimentation_scripts/data_samples/corrupted/2023-08-06_12-54-34_Fwd__Fw__3D_Model_jumana_aish_4823___full_service.ply
# 319
# ../experimentation_scripts/data_samples/corrupted/AKTIF_elif_guler3.ply
# 320
# ../experimentation_scripts/data_samples/corrupted/Eda Ozturk KALECAN.ply
# 321
# ../experimentation_scripts/data_samples/corrupted/şura soyak.ply
# 322
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Ebrar_Kazan.ply
# 323
# ../experimentation_scripts/data_samples/corrupted/SIFA_ORTOPEDI_D_BAKIR.ply
# 324
# ../experimentation_scripts/data_samples/corrupted/ayse zehra say 3.ply
# 325
# ../experimentation_scripts/data_samples/corrupted/2024-07-25_14-52-35_Fwd__Patient_Data_Olívia_Rocha_2.ply
# 326
# ../experimentation_scripts/data_samples/corrupted/Yağmur Sena Çalışkan.ply
# 327
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Can_Seker_2.ply
# 328
# ../experimentation_scripts/data_samples/corrupted/Melis Kargaci.ply
# 329
# ../experimentation_scripts/data_samples/corrupted/kartal yìlmaz-korseKALECAN.ply
# 330
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ceylin_arslan.ply
# 331
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Duru_Deniz_Turan.ply
# 332
# ../experimentation_scripts/data_samples/corrupted/2023-09-13_11-33-13_Re__3D_Model_sajda_3923_design_and_fitting_.ply
# 333
# ../experimentation_scripts/data_samples/corrupted/2023-11-25_13-52-28_Fwd__Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much.ply
# 334
# ../experimentation_scripts/data_samples/corrupted/jouman elsalti.ply
# 335
# ../experimentation_scripts/data_samples/corrupted/KALECAN_ayse_azra_temiz.ply
# 336
# ../experimentation_scripts/data_samples/corrupted/sinem topcu.ply
# 337
# ../experimentation_scripts/data_samples/corrupted/AKTIF_elif_nisa_celebi.ply
# 338
# ../experimentation_scripts/data_samples/corrupted/fatma alhac avad.ply
# 339
# ../experimentation_scripts/data_samples/corrupted/AKTIF_defne_sisli.ply
# 340
# ../experimentation_scripts/data_samples/corrupted/ARTI_kivanc_yasar_(+).ply
# 341
# ../experimentation_scripts/data_samples/corrupted/tufan emre aydin.ply
# 342
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_Safiye_Berra_Sirinal.ply
# 343
# ../experimentation_scripts/data_samples/corrupted/KALECAN_azra_aydin.ply
# 344
# ../experimentation_scripts/data_samples/corrupted/2024-07-31_11-00-51_Fwd__Patient_Data_Gabriel.ply
# 345
# ../experimentation_scripts/data_samples/corrupted/2024-08-23_13-59-22_Fwd__Fw__Patient_Data_Login_Ihab_case_5824.ply
# 346
# ../experimentation_scripts/data_samples/corrupted/melisa nur acar-korseKALECAN.ply
# 347
# ../experimentation_scripts/data_samples/corrupted/AKTIF__arda_gul.ply
# 348
# ../experimentation_scripts/data_samples/corrupted/ARTI_Ecrin_Cagan.ply
# 349
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_6_Arda_Darici(Aktif).ply
# 350
# ../experimentation_scripts/data_samples/corrupted/2024-05-27_10-11-25_Fwd__Fw__Patient_Data_engy_melad_2624.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 351
# ../experimentation_scripts/data_samples/corrupted/2024-06-05_11-50-56_Fwd__Beatriz_Savegnago_Ganzala_4_6_2024.ply
# 352
# ../experimentation_scripts/data_samples/corrupted/Nisanur Salman.ply
# 353
# ../experimentation_scripts/data_samples/corrupted/2023-07-13_18-56-27_Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much_.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 354
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Alp_Doganer.ply
# 355
# ../experimentation_scripts/data_samples/corrupted/CEYLAN_uveys_sevim.ply
# 356
# ../experimentation_scripts/data_samples/corrupted/2024-01-20_11-06-02_Fw__Patient_Data_Mohamed_Fareed_with_images_from_old_brace_.ply
# 357
# ../experimentation_scripts/data_samples/corrupted/2024-05-01_15-20-12_01_05_24-3rd_Scan.ply
# 358
# ../experimentation_scripts/data_samples/corrupted/nil yürük 2.ply
# 359
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_EMRE_SARP_ZEYTINOGLU_(_AKTIF_).ply
# 360
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_Ela_Mollavelioglu_FIZIMED.ply
# 361
# ../experimentation_scripts/data_samples/corrupted/2024-04-08_01-42-27_Fw__Patient_Data_yousef_3_____7424__design_only____fitting_by_me_.ply
# 362
# ../experimentation_scripts/data_samples/corrupted/AKTIF__aydan_yagmur_kose.ply
# 363
# ../experimentation_scripts/data_samples/corrupted/KALECAN_batuhan_kasap.ply
# 364
# ../experimentation_scripts/data_samples/corrupted/2023-11-25_13-46-11_Fwd__Fw__3D_Model_kisha_Nadine.ply
# 365
# ../experimentation_scripts/data_samples/corrupted/2024-01-07_13-18-49_Fw__3D_Model_yehia_2nd_scan___2124.ply
# 366
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Ada_Nil_Cekem_082021.ply
# 367
# ../experimentation_scripts/data_samples/corrupted/nevanur govec 2.ply
# 368
# ../experimentation_scripts/data_samples/corrupted/ANKARA_GAZI_ELIF_TUANA_SAVCI.ply
# 369
# ../experimentation_scripts/data_samples/corrupted/2024-02-28_12-48-34_Re__Patient_Data_hanin_Sameh_1324.ply
# 370
# ../experimentation_scripts/data_samples/corrupted/2023-10-06_11-34-09_Fw__3D_Model_haya_morsi_001023_revison_.ply
# 371
# ../experimentation_scripts/data_samples/corrupted/hatice ceylin doğan.ply
# 372
# ../experimentation_scripts/data_samples/corrupted/2024-05-09_09-39-28_Data_patient_Esther.ply
# 373
# ../experimentation_scripts/data_samples/corrupted/2024-07-01_09-52-11_Patient_Data_Heloísa_Goncalves.ply
# 374
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_SEZIN_IDER_(_AKTIF_).ply
# 375
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_EGEM_DENIZLI_Arda_Cihan.ply
# 376
# ../experimentation_scripts/data_samples/corrupted/2024-03-01_10-27-03_Fw__Patient_Data_hafsa__2324_.ply
# 377
# ../experimentation_scripts/data_samples/corrupted/AKTIF_AZRA_VARDAR_2.ply
# 378
# ../experimentation_scripts/data_samples/corrupted/Hatice Betül Bağcı.ply
# 379
# ../experimentation_scripts/data_samples/corrupted/2023-05-12_11-25-01_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply
# 380
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ZEYNEP_AKDENIZ_(_AKTIF_).ply
# 381
# ../experimentation_scripts/data_samples/corrupted/2024-03-31_12-43-00_Fw__Patient_Data_Arwa_Ahmed__3424.ply
# 382
# ../experimentation_scripts/data_samples/corrupted/2023-06-17_01-22-25_Fw__3D_Model_Clara_John_7723.ply
# 383
# ../experimentation_scripts/data_samples/corrupted/Muhammed Ali tekinerKALECAN.ply
# 384
# ../experimentation_scripts/data_samples/corrupted/pakize Akkurt.ply
# 385
# ../experimentation_scripts/data_samples/corrupted/2023-06-25_19-00-59_Fw__3D_Model_Mariam_Romany_10723__she_will__do_new_xray_this_week_.ply
# 386
# ../experimentation_scripts/data_samples/corrupted/tugce birinci.ply
# 387
# ../experimentation_scripts/data_samples/corrupted/AKTIF_elif_korkmaz_2.ply
# 388
# ../experimentation_scripts/data_samples/corrupted/2024-07-05_15-51-08_Fwd__Fw__Patient_Data_Mariam_Ahmed_3724.ply
# 389
# ../experimentation_scripts/data_samples/corrupted/ARTI_naz_yagmur_ustuncan.ply
# 390
# ../experimentation_scripts/data_samples/corrupted/AKTIF_eren_aktas.ply
# 391
# ../experimentation_scripts/data_samples/corrupted/leyla gunes.ply
# 392
# ../experimentation_scripts/data_samples/corrupted/2024-09-22_19-00-33_Fwd__Fw__Patient_Data_Adam_2924.ply
# 393
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Arda_Deniz_Oda.ply
# 394
# ../experimentation_scripts/data_samples/corrupted/ANKARA_GAZI_MAHMUT_ESAT_HARACA.ply
# 395
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Ahsen_Aykac.ply
# 396
# ../experimentation_scripts/data_samples/corrupted/2024-03-31_12-47-04_Fw__Patient_Data_1__Dan_Haytham_4424__her_4th_brace_.ply
# 397
# ../experimentation_scripts/data_samples/corrupted/Nehir Murat 2.ply
# 398
# ../experimentation_scripts/data_samples/corrupted/Nazlı Nehir Kaymakcilar.ply
# 399
# ../experimentation_scripts/data_samples/corrupted/2024-06-20_10-13-09_Fwd__Patient_Data_Isabela_Mihitarian.ply
# 400
# ../experimentation_scripts/data_samples/corrupted/ARTI_Defne_Aygun.ply
# 401
# ../experimentation_scripts/data_samples/corrupted/2024-07-05_15-24-55_Fwd__Maria_Eduarda_Rohde_de_Oliveira_5_07_2024.ply
# 402
# ../experimentation_scripts/data_samples/corrupted/Eymen yılmaz.ply
# 403
# ../experimentation_scripts/data_samples/corrupted/2024-06-21_10-57-26_Fwd__Fw__Patient_Data_Ibrahim_Mohamed_2___5624.ply
# 404
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ALI_BURAK_KARACASOY_(_AKTIF_).ply
# 405
# ../experimentation_scripts/data_samples/corrupted/karan aleviKALECAN.ply
# 406
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Alara_Hizlan_2.ply
# 407
# ../experimentation_scripts/data_samples/corrupted/2023-07-13_13-59-58_Fw__3D_Model_jumana_aish_4823___full_service_.ply
# 408
# ../experimentation_scripts/data_samples/corrupted/2024-09-30_13-16-09_Fwd__Fw__Patient_Data_jouly_Maged_5924.ply
# 409
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_17_Elif_Naz_Yildiz_(Aktif).ply
# 410
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_Zeynep_Saliha_Akdemir2.ply
# 411
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Deniz_Cavus.ply
# 412
# ../experimentation_scripts/data_samples/corrupted/2023-06-17_01-26-13_Fw__3D_Model_joudi_emad_8723__pls_cheack_the_quality_of_xray_.ply
# 413
# ../experimentation_scripts/data_samples/corrupted/2024-08-23_13-54-54_Fwd__Fw__Patient_Data_Malak_Rabee_1_case___2824.ply
# 414
# ../experimentation_scripts/data_samples/corrupted/2024-10-02_09-56-42_John_Tunney_call.ply
# 415
# ../experimentation_scripts/data_samples/corrupted/hande turan.ply
# 416
# ../experimentation_scripts/data_samples/corrupted/2024-03-09_13-53-46_Fw__Patient_Data_basmala_essam_4324_another_charity.ply
# 417
# ../experimentation_scripts/data_samples/corrupted/AKTIF__beyca_babacan_+2cm.ply
# 418
# ../experimentation_scripts/data_samples/corrupted/KONFOR_sila_cakmak.ply
# 419
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Defne_Kazanci.ply
# 420
# ../experimentation_scripts/data_samples/corrupted/KALECAN_Beyza_Hatice_Ildir_KCO.ply
# 421
# ../experimentation_scripts/data_samples/corrupted/2023-06-16_12-03-55_Fw__3D_Model_jana_Amir_6723.ply
# 422
# ../experimentation_scripts/data_samples/corrupted/Elif Uzun KCOKALECAN.ply
# 423
# ../experimentation_scripts/data_samples/corrupted/2023-10-06_09-49-49_Fw__3D_Model_ziad_11023__i_will_send_another_2_scans_for_him___i__donot_have_new_xray_yet___.ply
# 424
# ../experimentation_scripts/data_samples/corrupted/ARTI_Ece_Imdat_+.ply
# 425
# ../experimentation_scripts/data_samples/corrupted/2023-08-05_11-02-03_FW__Re__Nicole.ply
# 426
# ../experimentation_scripts/data_samples/corrupted/MEHMET EMİN ÖZKAN.ply
# 427
# ../experimentation_scripts/data_samples/corrupted/muge denktas.ply
# 428
# ../experimentation_scripts/data_samples/corrupted/Sebnem Yenici.ply
# 429
# ../experimentation_scripts/data_samples/corrupted/ANKARA_GAZI_NISANUR_ORHAN.ply
# 430
# ../experimentation_scripts/data_samples/corrupted/2023-08-14_11-13-16_Fw__3D_Model_Rawan_Magdy_12823_from_Greece__her_2nd_brace___father_is__oncologist___full_service_by_you___proritty_fly_to_saudia_end_of_aug.ply
# 431
# ../experimentation_scripts/data_samples/corrupted/2024-05-01_15-16-32_01_05_24.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 432
# ../experimentation_scripts/data_samples/corrupted/2024-03-09_13-57-09_Fw__Patient_Data_karma_walked__5324_.ply
# 433
# ../experimentation_scripts/data_samples/corrupted/Zeynep Erva sercan.ply
# 434
# ../experimentation_scripts/data_samples/corrupted/2024-01-27_11-09-21_Fwd__3D_Andressa_moura_Batista.ply
# 435
# ../experimentation_scripts/data_samples/corrupted/ANKARA_GAZI_BADE_DENIZ.ply
# 436
# ../experimentation_scripts/data_samples/corrupted/Rüyanur Özfırat.ply
# 437
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_54_Nisagul_Yalcin_(Aktif).ply
# 438
# ../experimentation_scripts/data_samples/corrupted/2024-09-02_20-14-12_Fwd__Fw__Patient_Data_sara_Ahmed_Kena_9824.ply
# 439
# ../experimentation_scripts/data_samples/corrupted/selim erol gurbuzKALECAN.ply
# 440
# ../experimentation_scripts/data_samples/corrupted/talya ersagun-korseKALECAN.ply
# 441
# ../experimentation_scripts/data_samples/corrupted/AKTIF__ayse_zehra_say.ply
# 442
# ../experimentation_scripts/data_samples/corrupted/ARTI_masal_duymaz.ply
# 443
# ../experimentation_scripts/data_samples/corrupted/2024-08-20_11-29-00_FW__Patient_Data.ply
# 444
# ../experimentation_scripts/data_samples/corrupted/2024-09-11_13-32-44_FW__Patient_Data.ply
# 445
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_DOGA_GUNEN_(_AKTIF_).ply
# 446
# ../experimentation_scripts/data_samples/corrupted/2024-07-08_10-27-11_Fwd__Patient_Data_Martina_Ortiz_Aguilera.ply
# 447
# ../experimentation_scripts/data_samples/corrupted/mina azra inci.ply
# 448
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ELA_NUR_PAMUKCU.ply
# 449
# ../experimentation_scripts/data_samples/corrupted/irem demir-korseKALECAN.ply
# 450
# ../experimentation_scripts/data_samples/corrupted/2023-08-14_08-38-41_Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply
# 451
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_Humeyra_ciftci.ply
# 452
# ../experimentation_scripts/data_samples/corrupted/AKTIF__ayse_nihal_yazili.ply
# 453
# ../experimentation_scripts/data_samples/corrupted/KALECAN_dogukan_ata_2.ply
# 454
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_UTKU_RAFET_TAS_(_AKTIF_).ply
# 455
# ../experimentation_scripts/data_samples/corrupted/saida Huseyinova.ply
# 456
# ../experimentation_scripts/data_samples/corrupted/AKTIF__Acelya_Acar.ply
# 457
# ../experimentation_scripts/data_samples/corrupted/şeyma yaşar 1.ply
# 458
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_30_Alperen_Adali_(Aktif).ply
# 459
# ../experimentation_scripts/data_samples/corrupted/EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan_2.ply
# 460
# ../experimentation_scripts/data_samples/corrupted/KALECAN_aylin_bayir-korse.ply
# 461
# ../experimentation_scripts/data_samples/corrupted/ARTI_sumeyye_ecem_akay_(+).ply
# 462
# ../experimentation_scripts/data_samples/corrupted/LIV_HOSPITAL_gulser_unlui.ply
# 463
# ../experimentation_scripts/data_samples/corrupted/furkan sefer.ply
# 464
# ../experimentation_scripts/data_samples/corrupted/irem dundar.ply
# 465
# ../experimentation_scripts/data_samples/corrupted/KALECAN_Ceyda_Sare_Kaplan_100621.ply
# 466
# ../experimentation_scripts/data_samples/corrupted/2023-07-13_12-48-18_Fw__3D_Model_Malak_samir_0823_charity___i_print_it_at_home___very__grateful_for__free_design_.ply
# 467
# ../experimentation_scripts/data_samples/corrupted/2023-09-11_20-58-46_Fw__3D_Model_Joudi_moh_with_polls__7923___her_2nd_brace_with_us___no__period_.ply
# 468
# ../experimentation_scripts/data_samples/corrupted/Nazli Belis Çavuş.ply
# 469
# ../experimentation_scripts/data_samples/corrupted/KONFOR_muhammed_demlahi.ply
# 470
# ../experimentation_scripts/data_samples/corrupted/Furkan Sarı KALECAN.ply
# 471
# ../experimentation_scripts/data_samples/corrupted/2024-07-05_15-52-18_Fwd__Fw__Patient_Data_Nour_Maysara_1_____2724.ply
# 472
# ../experimentation_scripts/data_samples/corrupted/2023-05-12_10-34-17_this_is_hana_baha_file_2123_that_was_send_on_december_30_2022_.ply
# 473
# ../experimentation_scripts/data_samples/corrupted/KALECAN_alina_sterkhova.ply
# 474
# ../experimentation_scripts/data_samples/corrupted/2024-08-19_10-02-26_Pacient_Savine_data_s.ply
# 475
# ../experimentation_scripts/data_samples/corrupted/2024-08-23_13-55-10_Fwd__Fw__Patient_Data_Farida_Katat_case_4824___she_had_2_braces__before_last_one_was_6823.ply
# 476
# ../experimentation_scripts/data_samples/corrupted/2024-07-03_15-12-40_Patient_Data.ply
# 477
# ../experimentation_scripts/data_samples/corrupted/2024-06-08_08-48-14_08_06_2024.ply
# 478
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ELANUR_TOPCU_(_AKTIF_).ply
# 479
# ../experimentation_scripts/data_samples/corrupted/kerem sekman.ply
# 480
# ../experimentation_scripts/data_samples/corrupted/2024-08-24_16-33-37_Fwd__Fw__Patient_Data_Rital_Ibrahim_6824.ply
# 481
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_ELIF_OZBAY_(_AKTIF_).ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 482
# ../experimentation_scripts/data_samples/corrupted/AKTIF_2021_-_47_Ahmet_Can_Kahraman_(Aktif).ply
# 483
# ../experimentation_scripts/data_samples/corrupted/AKTIF_ela_nur_pamukcu_2.ply
# 484
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_INCI_DIKICI.ply
# 485
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_muhammed_emin_bicakci.ply
# 486
# ../experimentation_scripts/data_samples/corrupted/KALECAN_Ceren_Akinci_KCO_051021.ply
# 487
# ../experimentation_scripts/data_samples/corrupted/2023-06-02_10-00-20_Fw__3D_Model_kisha_Nadine_1723_.ply
# 488
# ../experimentation_scripts/data_samples/corrupted/AKTIF_yagmur cekic.ply
# 489
# ../experimentation_scripts/data_samples/corrupted/KONFOR_Maria_konfor.ply
# 490
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Duru_Eda_Morgil.ply
# 491
# ../experimentation_scripts/data_samples/corrupted/2023-08-14_11-50-24_Fw__3D_Model_Malk_Saadi_13823___print_in_USA_.ply
# 492
# ../experimentation_scripts/data_samples/corrupted/2023-12-04_13-34-05_Fw__Patient_Data_engy_bassam__12123____pls_design_only__today_or__tomorrow___thx_.ply
# 493
# ../experimentation_scripts/data_samples/corrupted/serra aysel-korseKALECAN.ply
# 494
# ../experimentation_scripts/data_samples/corrupted/nisa sert.ply
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# Warning: Patch has only 0 vertices, need at least 3 for reliable PCA
# 495
# ../experimentation_scripts/data_samples/corrupted/ECE_ORTOPEDI_KONYA_Yusa_Ozdemir.ply
# 496
# ../experimentation_scripts/data_samples/corrupted/kerem çeliker-korseKALECAN.ply
# 497
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_CEVHER_FIRAT_(_AKTIF_).ply
# 498
# ../experimentation_scripts/data_samples/corrupted/2024-09-09_05-30-23_FW__Patient_Data-_Gaya.ply
# 499
# ../experimentation_scripts/data_samples/corrupted/2021 - 32 Ömer Albayrak (Aktif).ply
# 500
# ../experimentation_scripts/data_samples/corrupted/2024-06-11_14-12-03_Possibly_K5__please_check_rotation.ply
# 501
# ../experimentation_scripts/data_samples/corrupted/2024-08-31_07-49-09_Fwd__Fw__Patient_Data_mariam_George___8824.ply
# 502
# ../experimentation_scripts/data_samples/corrupted/KALECAN_DURU_YAHCI-KORSE.ply
# 503
# ../experimentation_scripts/data_samples/corrupted/AKTIF_Eslem_Horuz.ply
# 504
# ../experimentation_scripts/data_samples/corrupted/Peral akcalı.ply
# 505
# ../experimentation_scripts/data_samples/corrupted/2024-08-23_14-00-38_Fwd__Fw__Patient_Data_Jana_Abd_El_Ghany_1_case___3824_she_had_a_brace__before___3124.ply
# 506
# ../experimentation_scripts/data_samples/corrupted/İrem Hilal Barucu.ply
# 507
# ../experimentation_scripts/data_samples/corrupted/AKTIF_erva_agiralioglu.ply
# 508
# ../experimentation_scripts/data_samples/corrupted/KONFOR_ali_yusuf.ply
# 509
# ../experimentation_scripts/data_samples/corrupted/2024-04-30_09-56-39_Patient_Data_Maysa_B_de_Oliveira.ply
# 510
# ../experimentation_scripts/data_samples/corrupted/2023-07-13_13-24-24_Fw__3D_Model_gana_tamer__3823__full_service_.ply
# 511
# ../experimentation_scripts/data_samples/corrupted/FIZIMED_INCI_SU_KALDIRIM_(_AKTIF_).ply
# 512
# ../experimentation_scripts/data_samples/corrupted/2023-07-13_12-44-10_Fw__3D_Model_Mona_Ashraf__1823___just_design_pls___we_do_fitting_.ply
# 513

# %%
# features[17] = (features[17][0], np.nan_to_num(features[17][1]))

# %%
features[293][1]
# Out:
# array([[ 9.21690895e-01, -1.89708578e-01,  3.38373388e-01],
#        [ 9.16548315e-01, -2.64743872e-01,  2.99749677e-01],
#        [ 9.97222801e-01, -2.92462576e-02, -6.84933639e-02],
#        [ 6.16545871e-01,  6.78545813e-01, -3.99307863e-01],
#        [ 9.44386483e-01,  3.19225679e-01, -7.89248794e-02],
#        [ 9.94707859e-01, -9.36058920e-02, -4.23581500e-02],
#        [ 9.62330852e-01, -2.22343823e-01, -1.56469026e-01],
#        [ 9.99652565e-01, -1.78987380e-02, -1.93490064e-02],
#        [ 7.49070047e-01, -2.97743046e-01, -5.91813436e-01],
#        [ 8.96009880e-01, -6.15451295e-02,  4.39748215e-01],
#        [ 6.56902768e-01, -6.97743590e-01,  2.85714256e-01],
#        [ 5.46122903e-01, -7.72252629e-01, -3.24616161e-01],
#        [ 1.39718471e-01, -2.04561965e-01, -9.68830817e-01],
#        [ 2.82103944e-01, -2.26845478e-02, -9.59115622e-01],
#        [ 4.79398288e-01, -2.31186698e-01, -8.46599074e-01],
#        [ 5.98220139e-01, -3.79824063e-02, -8.00431135e-01],
#        [ 6.05561746e-01,  2.89722826e-01, -7.41185305e-01],
#        [ 5.00250386e-01,  4.81993462e-01, -7.19327362e-01],
#        [ 3.48138741e-01,  5.92147797e-01, -7.26746451e-01],
#        [ 9.71257103e-01,  2.09403948e-01,  1.13179621e-01],
#        [ 4.52371703e-01, -8.36233004e-01,  3.09958393e-01],
#        [ 4.69034797e-01, -7.63069481e-01, -4.44669908e-01],
#        [ 2.35512530e-01, -1.71212988e-01, -9.56671292e-01],
#        [ 5.30548312e-02, -5.49333049e-02, -9.97079494e-01],
#        [-4.09391706e-03, -3.52270607e-01, -9.35889235e-01],
#        [ 9.56766046e-02, -2.81393536e-01, -9.54810801e-01],
#        [ 3.93693546e-01,  2.71399532e-01, -8.78264018e-01],
#        [ 3.93060086e-01,  6.09424208e-01, -6.88553486e-01],
#        [ 1.39312107e-01,  7.78881165e-01, -6.11503285e-01],
#        [-1.19567720e-01,  9.88596988e-01, -9.15399161e-02],
#        [ 7.73255437e-01, -5.75724585e-01,  2.65739027e-01],
#        [ 6.84216469e-01, -6.01510285e-01, -4.12350823e-01],
#        [ 4.37492702e-01, -3.26702562e-01, -8.37774177e-01],
#        [ 1.80072046e-01,  2.06626710e-01, -9.61706536e-01],
#        [-5.20730240e-02, -1.66135333e-03, -9.98641898e-01],
#        [-1.57851410e-01, -3.38376519e-01, -9.27676810e-01],
#        [-8.86891059e-02, -3.15603422e-01, -9.44737383e-01],
#        [ 2.98821325e-01,  5.22753751e-01, -7.98394847e-01],
#        [ 2.06460935e-01,  8.77488143e-01, -4.32883867e-01],
#        [-3.99319408e-01,  8.67010239e-01,  2.98055794e-01],
#        [ 5.06909341e-01, -8.45399229e-01,  1.68353983e-01],
#        [ 3.76565207e-01, -6.42362259e-01, -6.67509830e-01],
#        [ 1.28678152e-01, -3.65208287e-01, -9.21989610e-01],
#        [ 8.90487801e-02,  2.31312783e-01, -9.68795495e-01],
#        [-1.03409376e-02,  2.74864204e-01, -9.61427446e-01],
#        [-9.54253217e-02, -1.24220771e-01, -9.87655409e-01],
#        [-1.23931620e-01, -4.10469337e-01, -9.03413459e-01],
#        [-3.63777297e-02,  1.35688717e-01, -9.90083447e-01],
#        [ 2.15116410e-01,  8.94555350e-01, -3.91785216e-01],
#        [ 3.40511677e-01,  9.03002713e-01,  2.61988354e-01],
#        [-4.30454738e-01, -9.02612140e-01, -2.10061676e-04],
#        [-4.25596535e-01, -5.92736380e-01, -6.83762513e-01],
#        [-2.28611386e-01, -2.97590255e-01, -9.26917944e-01],
#        [-8.54571302e-02,  2.99586732e-01, -9.50234113e-01],
#        [-1.19009869e-01,  2.30205255e-01, -9.65837560e-01],
#        [-1.84059222e-01, -1.73955595e-01, -9.67399428e-01],
#        [-1.19391292e-01, -4.25705898e-01, -8.96950505e-01],
#        [-9.73247813e-02,  1.59665163e-01, -9.82361910e-01],
#        [ 1.73183518e-01,  8.94291822e-01, -4.12613143e-01],
#        [ 2.87781287e-01,  9.50725401e-01,  1.15339255e-01],
#        [-6.22959181e-01, -7.76006661e-01,  9.86687429e-02],
#        [-5.64460247e-01, -4.98186008e-01, -6.58175760e-01],
#        [-3.95498060e-01, -3.01467749e-01, -8.67581973e-01],
#        [-1.04396973e-01,  3.74042006e-01, -9.21517146e-01],
#        [-1.34302473e-01,  1.16765368e-01, -9.84036938e-01],
#        [-1.82141368e-01, -3.07436485e-01, -9.33973945e-01],
#        [-1.80258991e-01, -3.99304959e-01, -8.98922825e-01],
#        [-1.19703536e-01,  2.12610216e-01, -9.69777273e-01],
#        [ 4.38251088e-02,  9.01700983e-01, -4.30133347e-01],
#        [ 1.88982903e-01,  9.81978196e-01,  2.06981679e-03],
#        [-7.15561978e-01, -6.94872827e-01,  7.15738095e-02],
#        [-6.77609348e-01, -4.87857552e-01, -5.50309532e-01],
#        [-5.09450981e-01, -2.45042192e-01, -8.24872125e-01],
#        [-2.90982201e-01,  2.99911353e-01, -9.08505663e-01],
#        [-1.55803212e-01,  5.34788631e-04, -9.87787970e-01],
#        [-1.73121682e-01, -4.38046564e-01, -8.82124759e-01],
#        [-2.19740925e-01, -3.23184187e-01, -9.20470481e-01],
#        [-2.07842929e-01,  2.29957246e-01, -9.50747591e-01],
#        [-9.68562318e-02,  8.92010740e-01, -4.41515242e-01],
#        [ 3.09420188e-02,  9.92404663e-01, -1.19061231e-01],
#        [-2.70730292e-01, -8.91656958e-01, -3.62840155e-01],
#        [-4.10375800e-01, -5.80025446e-01, -7.03677614e-01],
#        [-3.15812860e-01, -6.31200603e-02, -9.46719650e-01],
#        [-1.70476201e-01,  6.43698205e-02, -9.83257032e-01],
#        [-2.10849369e-01, -2.13927907e-01, -9.53822517e-01],
#        [-2.25989475e-01, -4.53973477e-01, -8.61879829e-01],
#        [-3.08569221e-01, -1.91175918e-01, -9.31792254e-01],
#        [-3.37000746e-01,  2.88971517e-01, -8.96061359e-01],
#        [-1.88227222e-01,  8.63492878e-01, -4.67921534e-01],
#        [-8.01578500e-02,  9.75026393e-01, -2.07118932e-01],
#        [-1.10501540e-01, -8.79680552e-01, -4.62548956e-01],
#        [-5.56697000e-02, -5.66631472e-01, -8.22088596e-01],
#        [-2.99770481e-02, -1.17693178e-01, -9.92597447e-01],
#        [-1.33507520e-01,  1.55067901e-01, -9.78840992e-01],
#        [-1.47885132e-01, -2.66969608e-01, -9.52290510e-01],
#        [-2.54394197e-01, -3.27709762e-01, -9.09884556e-01],
#        [-3.73164026e-01, -1.55896552e-01, -9.14573603e-01],
#        [-4.53470343e-01,  1.87871175e-01, -8.71245700e-01],
#        [-3.64122962e-01,  7.17235676e-01, -5.94127473e-01],
#        [-2.05236383e-01,  9.49018248e-01, -2.39253823e-01],
#        [ 1.63580676e-01, -8.90800209e-01, -4.23929652e-01],
#        [ 7.43134335e-02, -5.64824935e-01, -8.21857839e-01],
#        [-3.39464047e-02, -8.69627265e-02, -9.95633028e-01],
#        [-2.94690190e-02,  1.85012520e-01, -9.82294225e-01],
#        [-3.70237159e-02, -1.30311943e-01, -9.90781531e-01],
#        [-1.66326527e-01, -1.25343143e-01, -9.78071870e-01],
#        [-3.13968894e-01, -5.48258125e-02, -9.47848967e-01],
#        [-4.34253892e-01,  7.90244697e-02, -8.97317497e-01],
#        [-5.04011361e-01,  5.33199397e-01, -6.79463723e-01],
#        [-3.93336796e-01,  8.31824284e-01, -3.91605062e-01],
#        [ 2.33784155e-01, -8.87864389e-01, -3.96284994e-01],
#        [ 1.25848829e-01, -5.30516070e-01, -8.38280843e-01],
#        [ 1.05176761e-01, -1.67073390e-01, -9.80318485e-01],
#        [ 1.73203630e-01,  9.06419412e-02, -9.80706144e-01],
#        [ 2.38622165e-01, -4.47752045e-03, -9.71102165e-01],
#        [ 2.24183493e-01, -2.85443834e-02, -9.74128831e-01],
#        [ 2.07236268e-01,  9.27693209e-02, -9.73882427e-01],
#        [ 1.12224914e-01,  1.73445704e-01, -9.78428412e-01],
#        [-9.06653289e-03,  4.73792226e-01, -8.80589987e-01],
#        [ 4.08298164e-02,  7.99586210e-01, -5.99161763e-01],
#        [ 2.01475877e-01, -8.95821363e-01, -3.96120635e-01],
#        [ 2.82218783e-01, -5.56021314e-01, -7.81788243e-01],
#        [ 3.10829202e-01, -2.25391429e-01, -9.23354705e-01],
#        [ 3.33002836e-01, -5.29883635e-02, -9.41435789e-01],
#        [ 3.80732472e-01, -1.75205717e-03, -9.24683576e-01],
#        [ 3.61501157e-01,  2.72073027e-02, -9.31974611e-01],
#        [ 3.48074717e-01,  9.93217576e-02, -9.32190528e-01],
#        [ 4.03240743e-01,  1.98091092e-01, -8.93396229e-01],
#        [ 4.18999744e-01,  5.32684918e-01, -7.35313534e-01],
#        [ 2.50679736e-01,  8.44321753e-01, -4.73582567e-01],
#        [ 1.50534534e-01, -9.35936518e-01, -3.18374291e-01],
#        [ 3.40944410e-01, -6.72280508e-01, -6.57111732e-01],
#        [ 4.78709477e-01, -2.97372691e-01, -8.26079124e-01],
#        [ 5.04188349e-01, -5.99036480e-02, -8.61513588e-01],
#        [ 4.79073774e-01, -1.84151150e-03, -8.77772709e-01],
#        [ 5.08663929e-01,  2.60557848e-02, -8.60570801e-01],
#        [ 5.27227149e-01,  6.32817196e-02, -8.47364713e-01],
#        [ 4.47393523e-01,  3.06949233e-01, -8.40012621e-01],
#        [ 3.31472242e-01,  6.71947361e-01, -6.62278565e-01],
#        [ 2.01660070e-01,  9.31591267e-01, -3.02441608e-01],
#        [ 3.49633380e-03, -9.72191495e-01, -2.34161210e-01],
#        [ 8.25124593e-02, -7.96262797e-01, -5.99297299e-01],
#        [ 2.59512015e-01, -4.80822703e-01, -8.37533905e-01],
#        [ 4.23058836e-01, -1.49992463e-01, -8.93601411e-01],
#        [ 5.01299607e-01, -1.65863728e-02, -8.65114788e-01],
#        [ 5.27129436e-01, -4.16498605e-03, -8.49774800e-01],
#        [ 5.62977961e-01,  1.45128466e-01, -8.13629856e-01],
#        [ 5.10956417e-01,  4.75617186e-01, -7.16038988e-01],
#        [ 3.97458424e-01,  7.39499835e-01, -5.43292551e-01],
#        [ 3.33986834e-01,  9.25885031e-01, -1.76606072e-01],
#        [ 1.00075348e-01, -9.73629572e-01, -2.05013126e-01],
#        [ 2.19060834e-01, -8.39324266e-01, -4.97541081e-01],
#        [ 4.01687300e-01, -5.84890195e-01, -7.04663588e-01],
#        [ 4.50122103e-01, -2.37510076e-01, -8.60801403e-01],
#        [ 4.26993559e-01, -3.27724934e-02, -9.03660591e-01],
#        [ 3.79842790e-01,  6.72782878e-03, -9.25026589e-01],
#        [ 3.94150295e-01,  2.42170176e-01, -8.86565931e-01],
#        [ 3.91715077e-01,  6.04289459e-01, -6.93825301e-01],
#        [ 3.11684834e-01,  8.12532469e-01, -4.92588622e-01],
#        [ 2.53651069e-01,  9.59581522e-01, -1.21919802e-01],
#        [-8.64828896e-02, -9.78185549e-01, -1.88874936e-01],
#        [-1.10681971e-01, -8.81994750e-01, -4.58077245e-01],
#        [-3.21366404e-02, -6.66750297e-01, -7.44587992e-01],
#        [ 1.23777886e-02, -2.21799370e-01, -9.75013759e-01],
#        [ 1.20689326e-02, -1.17821486e-02, -9.99857751e-01],
#        [ 2.78123348e-02, -3.96543829e-03, -9.99605297e-01],
#        [ 8.69620385e-02,  2.62608217e-01, -9.60975821e-01],
#        [ 2.45373964e-01,  6.34585137e-01, -7.32866510e-01],
#        [ 3.45204226e-01,  8.20346458e-01, -4.55922944e-01],
#        [ 2.65037577e-01,  9.63688996e-01, -3.25361587e-02]])

# %%
print(len(features[100][1]))
# Out:
# 170

# %%
print(features[0][0])
# Out:
# ARTI_ali_riza_ersin_(+).ply

# %%
meshPathes
# Out:
# ['ARTI_ali_riza_ersin_(+).ply',
#  '2024-09-16_14-55-22_回复__visit_to_Germany.ply',
#  'ARTI_Sebnem_Ela_Cengizhan_(+).ply',
#  'AKTIF__azra_duru_yildiz.ply',
#  '2024-07-05_18-59-35_Fwd__Fw__Patient_Data_ziad_Kareem_3_case_5724.ply',
#  '2024-09-20_16-42-31_Fwd__Fw__Patient_Data_Maria_charity_1924.ply',
#  'ilkim cemal kara 140921KALECAN.ply',
#  'ARTI_yigit_ali_boz_2_(+).ply',
#  'KALECAN_ecrin_ada_sener-_korse.ply',
#  'ARTI_ayse_beren_nebil.ply',
#  '2023-10-06_10-11-52_Fw__3D_Model_Jana_sherif_21023__her_2nd_brace___no_new_xray_yet_.ply',
#  'FIZIMED_ZEYNEP_BAHSI_(_AKTIF_).ply',
#  '2024-01-18_18-28-46_Patient_Data.ply',
#  '2024-09-13_10-55-45_Patient_Data_Estela_Soares.ply',
#  'FIZIMED_AHMET_KAYA_(_AKTIF_).ply',
#  'KALECAN_defne_bekar.ply',
#  'KALECAN_asya_guven.ply',
#  'KALECAN_deniz_sukruogullari-korse.ply',
#  'ozgu ergin.ply',
#  'ARTI_Eylul_Acar.ply',
#  'LIV_HOSPITAL_Elif_Irem_Sercin.ply',
#  'AKTIF_deniz_kiran.ply',
#  'Tugba Naz Korkmaz 3.ply',
#  'ARTI_sila_dogan.ply',
#  'FIZIMED_FURKAN_OZDEN_(_AKTIF_).ply',
#  '2024-05-15_10-24-54_14_05_24.ply',
#  'ARTI_Harun_gungeldi_Arti_PO.ply',
#  '2024-01-13_01-57-49_Fw__Patient_Data_Mirna_Abd_el_Ghany_4124.ply',
#  'AKTIF_2021_-_59_Beyza_Sevimli_(Aktif).ply',
#  '2023-08-25_11-28-30_Fw__3D_Model_Hana_tamer_2923__design_and_fitting_.ply',
#  '2023-10-06_11-28-48_Fw__3D_Model__Juli_nashed_51023___we_revise_orthomedix_brace_._.ply',
#  '2023-09-08_13-29-53_Fw__3D_Model_salma_Salah_6923.ply',
#  '2021 - 21 Pelinsu Özkan (Aktif).ply',
#  'AKTIF__Alya_Akalin.ply',
#  'KALECAN_Ali_Ihsan_Ayanlar_KCO.ply',
#  'LIV_HOSPITAL_Ilke_Deren_Zafer.ply',
#  '2023-07-24_12-44-30_Fw__3D_Model_Omar_Hatem_7823_full_service_.ply',
#  'KALECAN_ECRIN_PANCAROGLU.ply',
#  'mert altınay.ply',
#  'murathan ateş.ply',
#  '2023-10-06_10-34-28_Fw__3D_Model_Clara__01023__free_revision_.ply',
#  'KALECAN_basak_ela_ceyani-korse.ply',
#  'KONFOR_sila_elmas.ply',
#  '2024-08-29_08-29-13_New_patient._.ply',
#  'ARTI_Sude_Kara.ply',
#  'KALECAN_batuhan_okan.ply',
#  '2024-05-25_13-55-46_25_05_24-3.ply',
#  'EGEM_DENIZLI_hilkmet_can_kaya.ply',
#  'KONFOR_Sema_nur_Gultekin.ply',
#  '2024-03-01_13-48-01_Fw__Patient_Data_Lana_3324.ply',
#  'KALECAN_Asel_Yildirim.ply',
#  '2024-08-23_13-54-34_Fwd__Fw__Patient_Data_Malak_Mohamed_1824.ply',
#  'ARTI_sila_dogru.ply',
#  'ECE_ORTOPEDI_KONYA_Enes_Doruk_ECE.ply',
#  'LIV_HOSPITAL_ela_yuksel.ply',
#  'CEYLAN_Tuana_Gursoy_(ceylan).ply',
#  'Yusuf Yanmaz.ply',
#  '2024-01-20_11-02-56_Fw__Patient_Data_Mohamed_Fareed_2.ply',
#  'Zeynep Naz Pınar KlinikSport.ply',
#  'mustafa koc.ply',
#  'KALECAN_dide_gazel_abakay.ply',
#  'irem su dikmenKALECAN.ply',
#  'FIZIMED_ELIZ_OZDOGAN.ply',
#  'KALECAN_asel_kucukcoban.ply',
#  'ECE_ORTOPEDI_KONYA_Ahmet_Talha_Saracoglu_ECE.ply',
#  'tugce birinci2.ply',
#  'CEYLAN_aysegul_toker.ply',
#  'zeynep ilhan.ply',
#  '2024-03-19_09-40-42_Patient_Data_Vitor_Romagnoli_Alves._March_19_24.ply',
#  'AKTIF_emir_ay.ply',
#  '2023-06-16_11-06-59_Fw__3D_Model_Mariam_Qatar__the_right_scan_4723.ply',
#  'Melisa Nur Acar kalecan.ply',
#  '2024-03-31_12-49-50_Fw__Patient_Data_adam_Karim_5424.ply',
#  '2024-06-07_13-48-24_Another_measurement.ply',
#  'ECE_ORTOPEDI_KONYA_Eymen_Talip_Taskin.ply',
#  'LIV_HOSPITAL_Ilke_Cemre_Kilincarslan.ply',
#  'FIZIMED_ECEM_SU_KUNT_(_AKTIF_).ply',
#  'Furkan Keleş.ply',
#  '2023-08-14_08-32-16_Fw__3D_Model_Reem_Ibrahim_9823_.ply',
#  '2024-05-25_13-49-15_25_05_24-2.ply',
#  '2023-11-16_10-54-45_Fw__3D_Model_haad_Libya__31123_.ply',
#  'nil yuruk.ply',
#  '2023-08-14_09-07-25_Fw__3D_Model_karma_Assam_11823_full_service_by_eric_.ply',
#  'AKTIF__can_efe_baki.ply',
#  '2023-04-09_15-52-41_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply',
#  'LIV_HOSPITAL_Irem_Temizel.ply',
#  'DIYAMER_Yigitcan_Caglar.ply',
#  '2024-05-06_10-48-52_Patient_Data_isis_Castanheira.ply',
#  '2023-11-26_09-23-30_Re__3D_Model_colored_again___51123.ply',
#  'AKTIF_2021_-_13_Defne_Kaya_(Aktif).ply',
#  'gözde nur maraşlı.ply',
#  'AKTIF_eylul_deniz_kadas.ply',
#  'Realeboha Kevin Kao.ply',
#  'FIZIMED_EGE_OZKAYA_(_AKTIF_).ply',
#  'AKTIF_elif_guler.ply',
#  '2024-03-13_01-18-59_Fw__Patient_Data_Rosetta_6324.ply',
#  'FIZIMED_KEMAL_YIGIT_TORER_(_AKTIF_).ply',
#  '2024-08-07_15-17-01_Patient_Data_Raphael_Rodrigues.ply',
#  'ARTIrabia gursoy.ply',
#  'halim durnaKALECAN.ply',
#  'tugbanaz Korkmaz.ply',
#  '2024-02-02_06-48-33_Fw__moaz_1224.ply',
#  'FIZIMED_EMRE_SARP_ZEYTINOGLU_2.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_cem_kayman.ply',
#  'Sude Durmaz (Aynur).ply',
#  '2023-08-25_11-13-10_Fw__3D_Model_febronia_1st_polls_1923__just_G_code__pls____fitting_and__print_will_be_done_locally___charity_.ply',
#  'ömer hamza lafcı.ply',
#  'ARTI_beyza_isil_yildirim_+.ply',
#  'kerem celik.ply',
#  'mikail acar.ply',
#  'zumra sancaktepe.ply',
#  'FIZIMED_TUANA_KENDIRCI_(_AKTIF_).ply',
#  'yasemin kıvrak.ply',
#  'AKTIF_elif_duru_zengin.ply',
#  'CEYLAN_berrak_ozturk.ply',
#  '2023-12-18_10-55-26_Maria_Fernanda_new_Brace.ply',
#  'AKTIF_ecenur_tuysuz.ply',
#  '2024-09-22_19-24-35_Fwd__Fw__Patient_Data_Martina_4924___pls_read_my_notes_first.ply',
#  '2023-08-09_14-36-59_Patient_Iasmin_Stucki.ply',
#  'AKTIF_elif_korkmaz.ply',
#  'FIZIMED_AYSENAZ_BALABAN_(_AKTIF_).ply',
#  'AKTIF__Belinay_Keskin.ply',
#  '2024-07-05_14-34-36_Fwd__Fw__Patient_Data_Omar_zakarya_1_case_1724___will_do_new_xray.ply',
#  'AKTIF__buglem_karaca.ply',
#  'LIV_HOSPITAL_Victoria_Blatskaya.ply',
#  'AKTIF_2021_-_10_Alp_Doganer_(Aktif).ply',
#  'Omer faruk Yanas.ply',
#  '2024-02-04_19-52-34_Fw__Patient_Data_karas_Tamer_2224_.ply',
#  'CITAY_IZMIR_A_R_D_KORSE.ply',
#  '2023-05-12_10-32-48_Fw__3D_Model_Hana_bahaa_revison__2523.ply',
#  'FIZIMED_NISA_TUANA_YUMRUTAS_(_AKTIF_).ply',
#  'ARTI_hatice_eceylan_+05_04_2022.ply',
#  '2023-10-29_21-37-27_Fw__3D_Model_firial__11123_pls_print_in_USA_.ply',
#  'CITAY_IZMIR_so_citay.ply',
#  'esin ünlü kalecan.ply',
#  'lara ada bıldır.ply',
#  'LIV_HOSPITAL_Ayben_Armina_Temel.ply',
#  'AKTIF__asmin_cetin.ply',
#  'KALECAN_ayse_barut_14-05-22.ply',
#  '2024-08-03_12-33-49_New_Scans_and_order._.ply',
#  '2024-06-11_13-40-00_FW__Patient_Data_.ply',
#  '2023-05-12_10-45-30_Fw__3D_Model_basmala_walid_3523.ply',
#  'LIV_HOSPITAL_zeren_boz.ply',
#  'FIZIMED_FATMA_MOLLA_(_AKTIF_).ply',
#  '2024-06-12_09-42-53_Fwd__Patient_Data_Giovana_Dantas.ply',
#  'KALECAN_adem_unal.ply',
#  'fatma zumra aydın.ply',
#  '2024-05-22_09-24-28_Fwd__Patient_Data.ply',
#  'AKTIF_Elif_Guler_2.ply',
#  '2024-05-25_09-53-09_New_Scan_.ply',
#  'nil yürük 3.ply',
#  'AKTIF__Buse_Goksel.ply',
#  'AKTIF__alara_hizlan.ply',
#  'saliha zeynep akdemir.ply',
#  'Yasemin Guney.ply',
#  'AKTIF__Berra_Tilaver.ply',
#  'AKTIF__ada_onur.ply',
#  'Hicran Durak.ply',
#  '2023-10-06_10-15-34_Fw__3D_Model_farida_sedky_31023__i_donot_need_Menna_to_be_in_the_room__or_get_close_to_her_mom___fitting_by_y_and_mariam__thx__.ply',
#  'KONFOR_Meyz_Al_Ali.ply',
#  'KALECAN_celal_cinar_coksoy.ply',
#  'ARTI_tuncer_erdogan.ply',
#  '2024-03-25_10-10-40_Fwd__Patient_Data_Lays_.ply',
#  'reyyan komurcuKALECAN.ply',
#  'AKTIF__Alp_Ceyhan.ply',
#  '2024-09-04_09-32-55_Fwd__Patient_Data.ply',
#  'Elif Sümeyye Gül.ply',
#  'KALECAN_defne_yaliguluhep.ply',
#  'ARTI_irem_badurlar_(+).ply',
#  'LIV_HOSPITAL_derya_arbabham.ply',
#  'AKTIF_ecrin_nil_yavuzaslan.ply',
#  'LIV_HOSPITAL_Lutfu_ege_bodur.ply',
#  'AKTIF_evrim_yilmaz.ply',
#  'melek çakırKALECAN.ply',
#  'AKTIF__Aylin_guliyeva23.ply',
#  'tufan emre aydın2.ply',
#  'AKTIF__Ada_Serindere.ply',
#  'Ezgi karatepe.ply',
#  '2024-04-10_08-58-29_Clara_s_data.ply',
#  'KALECAN_DERIN_KAPLAN-KCO.ply',
#  'tanem harputluKALECAN.ply',
#  'AKTIF__berfin_gunduz.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan.ply',
#  'ANKA_DUZCE_merve_nur_tureli.ply',
#  'ARTI_ela_kilic.ply',
#  'Sura Soyak 05042022.ply',
#  'ARTI_Irem_macit.ply',
#  'sevval nuran cavdar.ply',
#  'meryem zehra demir.ply',
#  'KALECAN_beray_tokatlioglu.ply',
#  '2024-06-08_14-08-00_Fwd__Fw__Patient_Data_Ziad_2_3624.ply',
#  'AKTIF__aysegul_benek.ply',
#  '2023-08-08_09-33-25_Fw__3D_Model_omar_moataz_8823_design_and_fitting_by_eric__print_in__usa___son_of_special_force_.ply',
#  'FIZIMED_ELIZ_OZDOGAN_(_AKTIF_).ply',
#  'FIZIMED_AZRA_SEKER_fizimed.ply',
#  'ARTI_tugba_nur_coban.ply',
#  'ARTI_cafer_ali_yesiltas_arti.ply',
#  'ARTI_tuana_deniz_(arti).ply',
#  '2024-06-05_18-02-55_John_Tunney_patients.ply',
#  '2024-05-01_06-29-16_Patient_File_-_ACMC1.ply',
#  'FIZIMED_DICLENAZ_ISBILEN_(_AKTIF_).ply',
#  'ilayda saygı.ply',
#  'fatma genç-korseKALECAN.ply',
#  'AKTIF_ceylin_ece_tektas.ply',
#  '2024-03-13_11-20-50_Patient_Data_Malásia_.ply',
#  'AKTIF__aylin_guliyeva.ply',
#  '2024-03-27_14-14-06_Fw__Patient_Data_Malak_saada__2424___her_2nd_brace_in_7_month_____her__old_file___13823__.ply',
#  'Ömer Hamza Lafcı 2.ply',
#  '2023-11-16_14-14-44_Fw__3D_Model_nahed_el_Amir__41123_design_only___look_at_y_notes_.ply',
#  'nevanur govec.ply',
#  '2024-03-27_15-08-44_Fwd__Luana_Cavalca_27_3_2024.ply',
#  'Çağlar Günerkaya KCO_KALECAN.ply',
#  'AKTIF__ahsen_ismetogullari.ply',
#  'zeynep saliha akdemir.ply',
#  'metehan er.ply',
#  'Pelin Kurtulus.ply',
#  'mirac kockaya.ply',
#  'inci defne yunlu.ply',
#  'ARTI_tugba_nur_acar_+.ply',
#  '2024-01-13_14-23-31_Re__Patient_DataTouline_1____6124.ply',
#  'Toprak su demir.ply',
#  'ARTI_ahmet_hosgor_(+).ply',
#  '2023-08-30_18-51-11_Fw__3D_Masoud_with_poles_5923__his_2nd_brace______pervious_brace_was__from_Greece___pls__design_and_fitting_only.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_ahmet_ahlat.ply',
#  'AKTIF_AZRA VARDAR.ply',
#  'ECE_ORTOPEDI_KONYA_Kezban_Irem_Icoz.ply',
#  '2024-05-30_16-47-40_Fwd__Patient_Data.ply',
#  'AKTIF__arda_gul_2.ply',
#  'AKTIF_eren_hicyilmaz.ply',
#  'DENIZ_OKE_Irem_Kose.ply',
#  'KONFOR_Alperen__Karaca_konfor.ply',
#  'LUXMED_Defne_Dagistanli_luxmed.ply',
#  '2024-04-10_07-51-07_Camila_s_data.ply',
#  '2023-10-06_11-25-01_Fw__3D_Model_menna_husky_41023___her_2nd_brace_.ply',
#  'AKTIF_Derya_Deniz_Varol.ply',
#  'AKTIF_2021_-_40_Selen_Baydar_(Aktif).ply',
#  'ARTI_meyranur_karagoz.ply',
#  'mikail acar 2.ply',
#  'AKTIF_ELIF_TUANA_SAVCI.ply',
#  'AKTIF__arya_fakirzade.ply',
#  '2023-08-14_12-02-55_Fwd__Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply',
#  'AKTIF_2021_-_51_Hiranur_Sekban_(Aktif).ply',
#  'ezgi nur aydemir.ply',
#  '2024-08-01_10-11-30_Fwd__Patient_Data_Felipe_4.ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_Defne_Enli.ply',
#  'AKTIF__cagla_bade_kiyak_2.ply',
#  'rumeysa gocmen.ply',
#  'AKTIF__Beril_Yilmazer.ply',
#  'AKTIF_durudeniz_turan_2.ply',
#  'eylül kutu KCO 041021KALECAN.ply',
#  'sinem ünlüerKALECAN.ply',
#  'LIV_HOSPITAL_Dersim_Toptas.ply',
#  'EGEM_DENIZLI_Mustafa_Elvan_egem.ply',
#  'AKTIF_ege_elibol.ply',
#  'ırmak tuğla.ply',
#  'ARTI_emircan_tursun_(+).ply',
#  'Ada Çalışkan ksKLINIKSPORT.ply',
#  'AKTIF_esma_bahtiyar.ply',
#  '2024-01-13_01-56-38_Fw__Patient_Data_Jana_Abd_El_Ghany_3124.ply',
#  'AKTIF_2021_-_18_Azra_Yigitoglu_(Aktif).ply',
#  '2024-03-15_12-54-25_150324.ply',
#  'melisa nur acar 2KALECAN.ply',
#  'Kaan Kubilay Çetinkaya.ply',
#  '2024-03-24_08-35-01_Fw_mariam_Fouad_1424.ply',
#  '2024-06-05_11-36-36_Fwd__Patient_Data_Misha_24.ply',
#  'KALECAN_avsin_somer-korse.ply',
#  'FIZIMED_DOGA_CIVELEK_(_fizimed_).ply',
#  'sevval nur guzeltepe.ply',
#  'AKTIF__Beren_Bay.ply',
#  'Ilgar Güzel 240921KALECAN.ply',
#  '2024-07-08_12-10-30_Fwd__Fw__Patient_Data_omar_Motaz_6724___his_2nd_brace.ply',
#  'ECE_ORTOPEDI_KONYA_Sedef_OzCelik_ECE.ply',
#  'İclal Rukiye Karaca.ply',
#  'İsik Sezer Saridede.ply',
#  'KONFOR_lemar_alheyek.ply',
#  'Miraz Nisa Nakci.ply',
#  'LIV_HOSPITAL_Ela_Yuksel_2.ply',
#  'LIV_HOSPITAL_Tuana_Celik.ply',
#  'tuğba naz korkmaz 2.ply',
#  '2023-08-25_11-38-13_Fw__3D_Model_nouran__4923_design_and_fitting___her_2nd_brace_in_8__month___dad_is_cardio_in_UK_.ply',
#  'KARTAL YİLMAZKALECAN.ply',
#  'TALA ABUGAHALİ.ply',
#  'AKTIF_2021_-_23_Halim_Burak_Nilifikra_(Aktif).ply',
#  'AKTIF__Ayse_Melis_Yalcin.ply',
#  'ARTI_vedat_daglik_(+).ply',
#  'FIZIMED_NEHIR_DURU_CELIK_(AKTIF_).ply',
#  'AKTIF__Azra_Karacaoglu.ply',
#  'FIZIMED_ECE_GULERSEN_(_AKTIF_).ply',
#  'ARTI_Busra_Karaca_+.ply',
#  'AKTIF_Elif_Korkmaz_04-23.ply',
#  '2024-09-22_18-59-51_Fwd__Fw__Patient_Data_Malak_bashir_3924.ply',
#  '2023-06-22_12-38-29_Fw__3D_Model_Maya_9723__her_3rd_brace_in_2_years____are_y_S3_.ply',
#  '2024-05-09_12-52-03_SA0905.ply',
#  '2023-12-04_22-12-18_Fw__Patient_Data_Noha_21223__design_pls____p.ply',
#  'AKTIF_Elif_Eylul_Demir.ply',
#  'AKTIF_elif_naz_keles.ply',
#  'AKTIF_can_seker.ply',
#  'FIZIMED_ATILLA_ALLAHVERDI_(_AKTIF_).ply',
#  'UMUT_azranur_yetim.ply',
#  'Sadık Bilal Son 090621KALECAN.ply',
#  'AKTIF__Alya_Doga_senlik.ply',
#  'AKTIF__ahmet_erdem.ply',
#  '2024-08-24_11-30-01_FW__Patient_Data.ply',
#  'çağla bade kıyak.ply',
#  'AKTIF_Dila_Zeynep_Bayat.ply',
#  '2024-05-27_10-11-43_Fwd__Fw__Patient_Data_Silvia_1624.ply',
#  'FIZIMED_ECRIN_CAPACI_(_AKTIF_).ply',
#  'AKTIF__Alya_Dua_Senlik_2.ply',
#  '2024-06-15_08-44-25_Fwd__Fw__Patient_Data_Jana_Mohamed_4624.ply',
#  'ARTI_yigit_ali_boz.ply',
#  '2024-09-15_13-33-28_Fwd__Fw__Patient_Data_Noor_10824.ply',
#  'Hatice Duman.ply',
#  'AKTIF__beyza_atak.ply',
#  'CIGDEM_DR_Arda_Yalcindag.ply',
#  'AKTIF_2021_-_48_Ilyas_Kadir_Saribas_(Aktif).ply',
#  'AKTIF_2021_-_39_Kemal_Efe_Alakavuk_(Aktif).ply',
#  'CEYLAN_sude_gul_guvenc.ply',
#  'EGEM_DENIZLI_nehir_acar.ply',
#  '2023-08-06_12-54-34_Fwd__Fw__3D_Model_jumana_aish_4823___full_service.ply',
#  'AKTIF_elif_guler3.ply',
#  'Eda Ozturk KALECAN.ply',
#  'şura soyak.ply',
#  'AKTIF_Ebrar_Kazan.ply',
#  'SIFA_ORTOPEDI_D_BAKIR.ply',
#  'ayse zehra say 3.ply',
#  '2024-07-25_14-52-35_Fwd__Patient_Data_Olívia_Rocha_2.ply',
#  'Yağmur Sena Çalışkan.ply',
#  'AKTIF__Can_Seker_2.ply',
#  'Melis Kargaci.ply',
#  'kartal yìlmaz-korseKALECAN.ply',
#  'AKTIF_ceylin_arslan.ply',
#  'AKTIF_Duru_Deniz_Turan.ply',
#  '2023-09-13_11-33-13_Re__3D_Model_sajda_3923_design_and_fitting_.ply',
#  '2023-11-25_13-52-28_Fwd__Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much.ply',
#  'jouman elsalti.ply',
#  'KALECAN_ayse_azra_temiz.ply',
#  'sinem topcu.ply',
#  'AKTIF_elif_nisa_celebi.ply',
#  'fatma alhac avad.ply',
#  'AKTIF_defne_sisli.ply',
#  'ARTI_kivanc_yasar_(+).ply',
#  'tufan emre aydin.ply',
#  'EGEM_DENIZLI_Safiye_Berra_Sirinal.ply',
#  'KALECAN_azra_aydin.ply',
#  '2024-07-31_11-00-51_Fwd__Patient_Data_Gabriel.ply',
#  '2024-08-23_13-59-22_Fwd__Fw__Patient_Data_Login_Ihab_case_5824.ply',
#  'melisa nur acar-korseKALECAN.ply',
#  'AKTIF__arda_gul.ply',
#  'ARTI_Ecrin_Cagan.ply',
#  'AKTIF_2021_-_6_Arda_Darici(Aktif).ply',
#  '2024-05-27_10-11-25_Fwd__Fw__Patient_Data_engy_melad_2624.ply',
#  '2024-06-05_11-50-56_Fwd__Beatriz_Savegnago_Ganzala_4_6_2024.ply',
#  'Nisanur Salman.ply',
#  '2023-07-13_18-56-27_Fw__3D_Model_hoor__5823___pls_design_only___thank_y_very_much_.ply',
#  'AKTIF__Alp_Doganer.ply',
#  'CEYLAN_uveys_sevim.ply',
#  '2024-01-20_11-06-02_Fw__Patient_Data_Mohamed_Fareed_with_images_from_old_brace_.ply',
#  '2024-05-01_15-20-12_01_05_24-3rd_Scan.ply',
#  'nil yürük 2.ply',
#  'FIZIMED_EMRE_SARP_ZEYTINOGLU_(_AKTIF_).ply',
#  'FIZIMED_Ela_Mollavelioglu_FIZIMED.ply',
#  '2024-04-08_01-42-27_Fw__Patient_Data_yousef_3_____7424__design_only____fitting_by_me_.ply',
#  'AKTIF__aydan_yagmur_kose.ply',
#  'KALECAN_batuhan_kasap.ply',
#  '2023-11-25_13-46-11_Fwd__Fw__3D_Model_kisha_Nadine.ply',
#  '2024-01-07_13-18-49_Fw__3D_Model_yehia_2nd_scan___2124.ply',
#  'AKTIF__Ada_Nil_Cekem_082021.ply',
#  'nevanur govec 2.ply',
#  'ANKARA_GAZI_ELIF_TUANA_SAVCI.ply',
#  '2024-02-28_12-48-34_Re__Patient_Data_hanin_Sameh_1324.ply',
#  '2023-10-06_11-34-09_Fw__3D_Model_haya_morsi_001023_revison_.ply',
#  'hatice ceylin doğan.ply',
#  '2024-05-09_09-39-28_Data_patient_Esther.ply',
#  '2024-07-01_09-52-11_Patient_Data_Heloísa_Goncalves.ply',
#  'FIZIMED_SEZIN_IDER_(_AKTIF_).ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_Arda_Cihan.ply',
#  '2024-03-01_10-27-03_Fw__Patient_Data_hafsa__2324_.ply',
#  'AKTIF_AZRA_VARDAR_2.ply',
#  'Hatice Betül Bağcı.ply',
#  '2023-05-12_11-25-01_Fw__3D_Model_Mohamed_yaser_vip__1523__pls_no_production_till_we__talk_after_y_come_from_Australia.ply',
#  'FIZIMED_ZEYNEP_AKDENIZ_(_AKTIF_).ply',
#  '2024-03-31_12-43-00_Fw__Patient_Data_Arwa_Ahmed__3424.ply',
#  '2023-06-17_01-22-25_Fw__3D_Model_Clara_John_7723.ply',
#  'Muhammed Ali tekinerKALECAN.ply',
#  'pakize Akkurt.ply',
#  '2023-06-25_19-00-59_Fw__3D_Model_Mariam_Romany_10723__she_will__do_new_xray_this_week_.ply',
#  'tugce birinci.ply',
#  'AKTIF_elif_korkmaz_2.ply',
#  '2024-07-05_15-51-08_Fwd__Fw__Patient_Data_Mariam_Ahmed_3724.ply',
#  'ARTI_naz_yagmur_ustuncan.ply',
#  'AKTIF_eren_aktas.ply',
#  'leyla gunes.ply',
#  '2024-09-22_19-00-33_Fwd__Fw__Patient_Data_Adam_2924.ply',
#  'AKTIF__Arda_Deniz_Oda.ply',
#  'ANKARA_GAZI_MAHMUT_ESAT_HARACA.ply',
#  'AKTIF__Ahsen_Aykac.ply',
#  '2024-03-31_12-47-04_Fw__Patient_Data_1__Dan_Haytham_4424__her_4th_brace_.ply',
#  'Nehir Murat 2.ply',
#  'Nazlı Nehir Kaymakcilar.ply',
#  '2024-06-20_10-13-09_Fwd__Patient_Data_Isabela_Mihitarian.ply',
#  'ARTI_Defne_Aygun.ply',
#  '2024-07-05_15-24-55_Fwd__Maria_Eduarda_Rohde_de_Oliveira_5_07_2024.ply',
#  'Eymen yılmaz.ply',
#  '2024-06-21_10-57-26_Fwd__Fw__Patient_Data_Ibrahim_Mohamed_2___5624.ply',
#  'FIZIMED_ALI_BURAK_KARACASOY_(_AKTIF_).ply',
#  'karan aleviKALECAN.ply',
#  'LIV_HOSPITAL_Alara_Hizlan_2.ply',
#  '2023-07-13_13-59-58_Fw__3D_Model_jumana_aish_4823___full_service_.ply',
#  '2024-09-30_13-16-09_Fwd__Fw__Patient_Data_jouly_Maged_5924.ply',
#  'AKTIF_2021_-_17_Elif_Naz_Yildiz_(Aktif).ply',
#  'LIV_HOSPITAL_Zeynep_Saliha_Akdemir2.ply',
#  'AKTIF_Deniz_Cavus.ply',
#  '2023-06-17_01-26-13_Fw__3D_Model_joudi_emad_8723__pls_cheack_the_quality_of_xray_.ply',
#  '2024-08-23_13-54-54_Fwd__Fw__Patient_Data_Malak_Rabee_1_case___2824.ply',
#  '2024-10-02_09-56-42_John_Tunney_call.ply',
#  'hande turan.ply',
#  '2024-03-09_13-53-46_Fw__Patient_Data_basmala_essam_4324_another_charity.ply',
#  'AKTIF__beyca_babacan_+2cm.ply',
#  'KONFOR_sila_cakmak.ply',
#  'AKTIF_Defne_Kazanci.ply',
#  'KALECAN_Beyza_Hatice_Ildir_KCO.ply',
#  '2023-06-16_12-03-55_Fw__3D_Model_jana_Amir_6723.ply',
#  'Elif Uzun KCOKALECAN.ply',
#  '2023-10-06_09-49-49_Fw__3D_Model_ziad_11023__i_will_send_another_2_scans_for_him___i__donot_have_new_xray_yet___.ply',
#  'ARTI_Ece_Imdat_+.ply',
#  '2023-08-05_11-02-03_FW__Re__Nicole.ply',
#  'MEHMET EMİN ÖZKAN.ply',
#  'muge denktas.ply',
#  'Sebnem Yenici.ply',
#  'ANKARA_GAZI_NISANUR_ORHAN.ply',
#  '2023-08-14_11-13-16_Fw__3D_Model_Rawan_Magdy_12823_from_Greece__her_2nd_brace___father_is__oncologist___full_service_by_you___proritty_fly_to_saudia_end_of_aug.ply',
#  '2024-05-01_15-16-32_01_05_24.ply',
#  '2024-03-09_13-57-09_Fw__Patient_Data_karma_walked__5324_.ply',
#  'Zeynep Erva sercan.ply',
#  '2024-01-27_11-09-21_Fwd__3D_Andressa_moura_Batista.ply',
#  'ANKARA_GAZI_BADE_DENIZ.ply',
#  'Rüyanur Özfırat.ply',
#  'AKTIF_2021_-_54_Nisagul_Yalcin_(Aktif).ply',
#  '2024-09-02_20-14-12_Fwd__Fw__Patient_Data_sara_Ahmed_Kena_9824.ply',
#  'selim erol gurbuzKALECAN.ply',
#  'talya ersagun-korseKALECAN.ply',
#  'AKTIF__ayse_zehra_say.ply',
#  'ARTI_masal_duymaz.ply',
#  '2024-08-20_11-29-00_FW__Patient_Data.ply',
#  '2024-09-11_13-32-44_FW__Patient_Data.ply',
#  'FIZIMED_DOGA_GUNEN_(_AKTIF_).ply',
#  '2024-07-08_10-27-11_Fwd__Patient_Data_Martina_Ortiz_Aguilera.ply',
#  'mina azra inci.ply',
#  'AKTIF_ELA_NUR_PAMUKCU.ply',
#  'irem demir-korseKALECAN.ply',
#  '2023-08-14_08-38-41_Fw__3D_Model_Hoda_mostafa_10823_full_service_by_you__.ply',
#  'EGEM_DENIZLI_Humeyra_ciftci.ply',
#  'AKTIF__ayse_nihal_yazili.ply',
#  'KALECAN_dogukan_ata_2.ply',
#  'FIZIMED_UTKU_RAFET_TAS_(_AKTIF_).ply',
#  'saida Huseyinova.ply',
#  'AKTIF__Acelya_Acar.ply',
#  'şeyma yaşar 1.ply',
#  'AKTIF_2021_-_30_Alperen_Adali_(Aktif).ply',
#  'EGEM_DENIZLI_EGEM_DENIZLI_deniz_aslan_2.ply',
#  'KALECAN_aylin_bayir-korse.ply',
#  'ARTI_sumeyye_ecem_akay_(+).ply',
#  'LIV_HOSPITAL_gulser_unlui.ply',
#  'furkan sefer.ply',
#  'irem dundar.ply',
#  'KALECAN_Ceyda_Sare_Kaplan_100621.ply',
#  '2023-07-13_12-48-18_Fw__3D_Model_Malak_samir_0823_charity___i_print_it_at_home___very__grateful_for__free_design_.ply',
#  '2023-09-11_20-58-46_Fw__3D_Model_Joudi_moh_with_polls__7923___her_2nd_brace_with_us___no__period_.ply',
#  'Nazli Belis Çavuş.ply',
#  'KONFOR_muhammed_demlahi.ply',
#  'Furkan Sarı KALECAN.ply',
#  '2024-07-05_15-52-18_Fwd__Fw__Patient_Data_Nour_Maysara_1_____2724.ply',
#  '2023-05-12_10-34-17_this_is_hana_baha_file_2123_that_was_send_on_december_30_2022_.ply',
#  'KALECAN_alina_sterkhova.ply',
#  '2024-08-19_10-02-26_Pacient_Savine_data_s.ply',
#  '2024-08-23_13-55-10_Fwd__Fw__Patient_Data_Farida_Katat_case_4824___she_had_2_braces__before_last_one_was_6823.ply',
#  '2024-07-03_15-12-40_Patient_Data.ply',
#  '2024-06-08_08-48-14_08_06_2024.ply',
#  'FIZIMED_ELANUR_TOPCU_(_AKTIF_).ply',
#  'kerem sekman.ply',
#  '2024-08-24_16-33-37_Fwd__Fw__Patient_Data_Rital_Ibrahim_6824.ply',
#  'FIZIMED_ELIF_OZBAY_(_AKTIF_).ply',
#  'AKTIF_2021_-_47_Ahmet_Can_Kahraman_(Aktif).ply',
#  'AKTIF_ela_nur_pamukcu_2.ply',
#  'FIZIMED_INCI_DIKICI.ply',
#  'FIZIMED_muhammed_emin_bicakci.ply',
#  'KALECAN_Ceren_Akinci_KCO_051021.ply',
#  '2023-06-02_10-00-20_Fw__3D_Model_kisha_Nadine_1723_.ply',
#  'AKTIF_yagmur cekic.ply',
#  'KONFOR_Maria_konfor.ply',
#  'AKTIF_Duru_Eda_Morgil.ply',
#  '2023-08-14_11-50-24_Fw__3D_Model_Malk_Saadi_13823___print_in_USA_.ply',
#  '2023-12-04_13-34-05_Fw__Patient_Data_engy_bassam__12123____pls_design_only__today_or__tomorrow___thx_.ply',
#  'serra aysel-korseKALECAN.ply',
#  'nisa sert.ply',
#  'ECE_ORTOPEDI_KONYA_Yusa_Ozdemir.ply',
#  'kerem çeliker-korseKALECAN.ply',
#  'FIZIMED_CEVHER_FIRAT_(_AKTIF_).ply',
#  '2024-09-09_05-30-23_FW__Patient_Data-_Gaya.ply',
#  '2021 - 32 Ömer Albayrak (Aktif).ply',
#  '2024-06-11_14-12-03_Possibly_K5__please_check_rotation.ply',
#  '2024-08-31_07-49-09_Fwd__Fw__Patient_Data_mariam_George___8824.ply',
#  'KALECAN_DURU_YAHCI-KORSE.ply',
#  'AKTIF_Eslem_Horuz.ply',
#  'Peral akcalı.ply',
#  '2024-08-23_14-00-38_Fwd__Fw__Patient_Data_Jana_Abd_El_Ghany_1_case___3824_she_had_a_brace__before___3124.ply',
#  'İrem Hilal Barucu.ply',
#  'AKTIF_erva_agiralioglu.ply',
#  'KONFOR_ali_yusuf.ply',
#  '2024-04-30_09-56-39_Patient_Data_Maysa_B_de_Oliveira.ply',
#  '2023-07-13_13-24-24_Fw__3D_Model_gana_tamer__3823__full_service_.ply',
#  'FIZIMED_INCI_SU_KALDIRIM_(_AKTIF_).ply',
#  '2023-07-13_12-44-10_Fw__3D_Model_Mona_Ashraf__1823___just_design_pls___we_do_fitting_.ply']
